# %% [markdown]
# linear regression ma two technqiues hoti ha ols and gradient descent
# ols we study this week and gradient descent on next week

# %% [markdown]
# yadi aap simple linear regression padta ho tho multiple linear regression padna asan ho jata ha

# %% [markdown]
#  simple linear regression : one cause -> one effect
# multiple linear regression : many cause -> one effect

# %% [markdown]
# Recap
# simple linear regression : one input (x) one output (y)
# multiple linear regression : multiple input (x1,x2,...xn) and one output

# %% [markdown]
# example
# experience (x) salary (y) sa simple linear regression model

# %% [markdown]
# aap usko graph ma plot karta ho  agar ya sort of linear ho jesa jesa salry badti ha vasa experience badta ha
# aap ek line draw karta ho aor ya line sabi points sa pass hokar gujarti ha
# fir aap us line ki equation likata ho
# $y = mx + b$
# apka basically m or b ka value chaya hota ha
# now aap kisi ka bhi x (experience) provide karta ho then uska correspoinding apko y (salary) calcuate kar ke deta ha

# %% [markdown]
# humna kal ki video ma yahi sika ki m and b kesa nikal sakta ha aor humna pura mathematical formulation draw kiya

# %% [markdown]
# ## what is multiple linear regresssion

# %% [markdown]
# real life ma jab apka paas data hota ha tho tho usma 1 input column nahi hota jesa experieence | salary .
# hamara pass ek sa jada predicator hoti ha
# ek sa jada
# city| age| gender | education  | salary

# %% [markdown]
# we study
# - what is MLR
# -  python code
# - mathematical formulation
# - code from scratch
# - problem with OLS solution

# %% [markdown]
# example
# | cgpa | iq |  package |
# |----------|----------|----------|
# | 7.1 | 80|  8
# | 6.89 |90 |9
# | ... |...|...|

# %% [markdown]
# aesa hamra pass 1000 students ka data ha

# %% [markdown]
# ```mermaid
# flowchart LR
#   node_1["cgpa"]
#   node_2['iq']
#   node_3["model"]
#   node_4["placement"]
#   node_1 --> node_3
#   node_2 --> node_3
#   node_3 --> node_4
# ```

# %% [markdown]
# ```mermaid
# flowchart LR
#   node_1["cgpa"]
#   node_2['iq']
#   node_3["model"]
#   node_4["placement"]
#   node_1 --inp1--> node_3
#   node_2 --inp1--> node_3
#   node_3 --1out--> node_4
# ```

# %% [markdown]
# yadi aap simple linear ha hota tho aap line ka equation nikalna ki koshish karta apka data 2d plane ma hota

# %% [markdown]
# abhi hamra data 3d space ma tho ab hum plance draw kareaga

# %% [markdown]
# ab ya hamra weights bo,b1,,b2,---bn

# %% [markdown]
# ## python

# %% [markdown]
# hum ek 3d data lega

# %%
# import libraries 
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
# create dataset
X,y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature1':X[:,0],'feature2':X[:,1],'target':y})

# %%
df.shape
# Out:
# (100, 3)

# %%
df
# Out:
#     feature1  feature2      target
# 0  -0.445741 -1.997791  -80.896131
# 1  -1.634687 -0.104104 -110.995651
# 2  -0.168618  0.944813    5.156919
# 3   0.473161  1.269235  121.983612
# 4  -0.700978 -0.673094 -164.370547
# ..       ...       ...         ...
# 95  0.299661  0.016166   30.685322
# 96  1.159020 -0.776302   10.378080
# 97  0.167966  0.430395   48.998885
# 98 -0.220599 -1.042850 -151.409168
# 99 -0.606137 -1.568556  -97.437904
#
# [100 rows x 3 columns]

# %%
# 3d plot 
px.scatter_3d(df, x='feature1', y='feature2', z='target')

# %%
# do the train test split
from sklearn.model_selection  import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
# Out:
# MAE 46.99329159310292
# MSE 3722.3874087428376
# R2 score 0.4104686327374655

# %%
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
xGrid, yGrid = np.meshgrid(y, x)

final = np.vstack((xGrid.ravel().reshape(1,100),yGrid.ravel().reshape(1,100))).T

z_final = model.predict(final).reshape(10,10)

z = z_final

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.add_trace(go.Surface(x = x, y = y, z =z ))

fig.show()

# %% [markdown]
# model is trying  to plot a plance jo har paoints sa kam distance sa gajura

# %%
model.coef_
# Out:
# array([66.3395235 , 40.95007894])

# %% [markdown]
# observe hamra pass ab two coefficient aa raha ha

# %%
model.intercept_
# Out:
# -4.936037333733635

# %% [markdown]
# what level par humna cheeza clear kar di ab how level par cheeza dekni ha

# %% [markdown]
# how level par = hum mathematical formulation karega ki is b0,b1,b2 ...bn ki values kesa calculate kareii

# %% [markdown]
# weigths are strength of input and output column

# %%
# import libraries 
import numpy as np
import pandas as pd
from sklearn.datasets import load_diabetes

X,y = load_diabetes(return_X_y=True)

# %%
load_diabetes(as_frame=True)['data']
# deko pahala hi hamra sara columns numerical ha 
# hamara pass 442 patients ka data ha
# Out:
#           age       sex       bmi  ...        s4        s5        s6
# 0    0.038076  0.050680  0.061696  ... -0.002592  0.019907 -0.017646
# 1   -0.001882 -0.044642 -0.051474  ... -0.039493 -0.068332 -0.092204
# 2    0.085299  0.050680  0.044451  ... -0.002592  0.002861 -0.025930
# 3   -0.089063 -0.044642 -0.011595  ...  0.034309  0.022688 -0.009362
# 4    0.005383 -0.044642 -0.036385  ... -0.002592 -0.031988 -0.046641
# ..        ...       ...       ...  ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  ... -0.002592  0.031193  0.007207
# 438 -0.005515  0.050680 -0.015906  ...  0.034309 -0.018114  0.044485
# 439  0.041708  0.050680 -0.015906  ... -0.011080 -0.046883  0.015491
# 440 -0.045472 -0.044642  0.039062  ...  0.026560  0.044529 -0.025930
# 441 -0.045472 -0.044642 -0.073030  ... -0.039493 -0.004222  0.003064
#
# [442 rows x 10 columns]

# %%
# see the input data (matrix)
X
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
# check shape 
X.shape
# Out:
# (442, 10)

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
y.shape
# Out:
# (442,)

# %% [markdown]
# ## using sklearn

# %%
from sklearn.model_selection import train_test_split
X_train,X_test , y_train , y_test = train_test_split(X,y ,test_size=0.2,random_state=2)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (353, 10)
# (89, 10)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X=X_train,y=y_train)
# Out:
# LinearRegression()

# %% [markdown]
# our equation
# $Y = XB$

# %%
y_pred = model.predict(X_test)

# %%
# now check the r2 score
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.439933866156897

# %%
# our 10 beta values
model.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
# our b_0 intercept values
model.intercept_
# Out:
# 151.88331005254167

# %% [markdown]
# ## making our own linear regresion

# %%
# humna linear regression class banyega fir us par run karega apna data ko aor verify karega
class MeraLR:
    
    def __init__(self):
        self.coef_ = None
        self.intercept_ = None
        
    def fit(self,X_train,y_train):
        X_train = np.insert(X_train,0,1,axis=1)
        
        # calcuate the coeffs
        betas = np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)
        self.intercept_ = betas[0]
        self.coef_ = betas[1:]
    
    def predict(self,X_test):
        y_pred = np.dot(X_test,self.coef_) + self.intercept_
        return y_pred

# %%
# create a object name our_model 
our_model = MeraLR()

# %%
our_model.fit(X_train,y_train)

# %%
X_train.shape
# Out:
# (353, 10)

# %%
np.insert(X_train,0,1,axis=1).shape
# Out:
# (353, 11)

# %%
y_pred = our_model.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568972

# %%
# check the coefficinet by our model
our_model.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
our_model.intercept_
# Out:
# 151.88331005254167

# %% [markdown]
# observe deko sab kuch same aa raha ha
# that proves ya jo harma code ha aor sklearn library ma jo code dono same ha  matlab sklearn ki linear regression class ma same to same code likha hua ha

# %% [markdown]
# tho hamna sctrach sa linear regression sa code ma lika

# %% [markdown]
# deko hamna khud sa mathematical formula kiya fir usko python code ma convert kiya is sa bhar aor kuch nahi puch skata
# imagaine aap khud ki library bana raha ho
