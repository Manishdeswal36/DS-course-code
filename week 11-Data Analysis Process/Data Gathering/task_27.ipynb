# %%
import pandas as pd
import requests
from io import StringIO

# %% [markdown]
# ### Problem-1:
#
# You are given a SQL file link: https://drive.google.com/file/d/1WFt7B84LTHhMueoKmz8W-PRo7xXqmZf3/view?usp=share_link. Read the data by using the file and store it in a excel file. In this data, there are 3 tables named "invoices", "order_leads" and "sales_sql". So create 3 sheets to your excel file.

# %% [markdown]
# ### Problem-2
#
# Go to the site: https://rapidapi.com/wirefreethought/api/geodb-cities. From here, you have to grab the API and have to choose proper routes to get the cities of different countries. After getting the right API, hit that API and create a dataframe of all the cities that you can get by using the API. Then store the dataframe to a SQL. If you need to create an account or have to subscribe, then do that (it has free subscription but has some limitations. Use that free subscription and modify your accordingly to get all the data).

# %%
# login your account 
# What data you want
# choose proper routes to 

# we use the cities details api

# %%
import requests

url = "https://wft-geo-db.p.rapidapi.com/v1/geo/adminDivisions/Q104994/nearbyCities"

querystring = {"radius":"100"}

headers = {
	"x-rapidapi-key": "a525d514bcmsh4d42399e1476d98p1c2a66jsn250b126101c6",
	"x-rapidapi-host": "wft-geo-db.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'links': [{'rel': 'first', 'href': '/v1/geo/adminDivisions/Q104994/nearbyCities?offset=0&limit=5&radius=100'}, {'rel': 'next', 'href': '/v1/geo/adminDivisions/Q104994/nearbyCities?offset=5&limit=5&radius=100'}, {'rel': 'last', 'href': '/v1/geo/adminDivisions/Q104994/nearbyCities?offset=770&limit=5&radius=100'}], 'data': [{'id': 3446973, 'wikiDataId': 'Q2928231', 'type': 'CITY', 'city': 'Bunker Hill', 'name': 'Bunker Hill', 'country': 'United States of America', 'countryCode': 'US', 'region': 'California', 'regionCode': 'CA', 'regionWdId': 'Q99', 'latitude': 34.05204, 'longitude': -118.25034, 'population': 0, 'distance': 0.14}, {'id': 3855177, 'wikiDataId': 'Q65', 'type': 'CITY', 'city': 'Los Angeles', 'name': 'Los Angeles', 'country': 'United States of America', 'countryCode': 'US', 'region': 'California', 'regionCode': 'CA', 'regionWdId': 'Q99', 'latitude': 34.05223, 'longitude': -118.24368, 'population': 3898747, 'distance': 0.39}, {'id': 3447478, 'wikiDataId': 'Q4762767', 'type': 'CITY', 'city': 'Angelino Heights', 'name': 'Angelino Heights', 'country': 'United States of America', 'countryCode': 'US', 'region': 'California', 'regionCode': 'CA', 'regionWdId': 'Q99', 'latitude': 34.070277777, 'longitude': -118.254722222, 'population': 0, 'distance': 1.43}, {'id': 3824900, 'wikiDataId': 'Q122553752', 'type': 'CITY', 'city': 'Mission Junction', 'name': 'Mission Junction', 'country': 'United States of America', 'countryCode': 'US', 'region': 'California', 'regionCode': 'CA', 'regionWdId': 'Q99', 'latitude': 34.0625114, 'longitude': -118.2275733, 'population': 0, 'distance': 1.55}, {'id': 3832131, 'wikiDataId': 'Q122570043', 'type': 'CITY', 'city': 'Pico Gardens', 'name': 'Pico Gardens', 'country': 'United States of America', 'countryCode': 'US', 'region': 'California', 'regionCode': 'CA', 'regionWdId': 'Q99', 'latitude': 34.0402901, 'longitude': -118.222573, 'population': 0, 'distance': 1.71}], 'metadata': {'currentOffset': 0, 'totalCount': 775}}

# %%
# understand the structure of it by json viewer
data = response.json()['data']
data
# so details of 5 cities
# Out:
# [{'id': 3446973,
#   'wikiDataId': 'Q2928231',
#   'type': 'CITY',
#   'city': 'Bunker Hill',
#   'name': 'Bunker Hill',
#   'country': 'United States of America',
#   'countryCode': 'US',
#   'region': 'California',
#   'regionCode': 'CA',
#   'regionWdId': 'Q99',
#   'latitude': 34.05204,
#   'longitude': -118.25034,
#   'population': 0,
#   'distance': 0.14},
#  {'id': 3855177,
#   'wikiDataId': 'Q65',
#   'type': 'CITY',
#   'city': 'Los Angeles',
#   'name': 'Los Angeles',
#   'country': 'United States of America',
#   'countryCode': 'US',
#   'region': 'California',
#   'regionCode': 'CA',
#   'regionWdId': 'Q99',
#   'latitude': 34.05223,
#   'longitude': -118.24368,
#   'population': 3898747,
#   'distance': 0.39},
#  {'id': 3447478,
#   'wikiDataId': 'Q4762767',
#   'type': 'CITY',
#   'city': 'Angelino Heights',
#   'name': 'Angelino Heights',
#   'country': 'United States of America',
#   'countryCode': 'US',
#   'region': 'California',
#   'regionCode': 'CA',
#   'regionWdId': 'Q99',
#   'latitude': 34.070277777,
#   'longitude': -118.254722222,
#   'population': 0,
#   'distance': 1.43},
#  {'id': 3824900,
#   'wikiDataId': 'Q122553752',
#   'type': 'CITY',
#   'city': 'Mission Junction',
#   'name': 'Mission Junction',
#   'country': 'United States of America',
#   'countryCode': 'US',
#   'region': 'California',
#   'regionCode': 'CA',
#   'regionWdId': 'Q99',
#   'latitude': 34.0625114,
#   'longitude': -118.2275733,
#   'population': 0,
#   'distance': 1.55},
#  {'id': 3832131,
#   'wikiDataId': 'Q122570043',
#   'type': 'CITY',
#   'city': 'Pico Gardens',
#   'name': 'Pico Gardens',
#   'country': 'United States of America',
#   'countryCode': 'US',
#   'region': 'California',
#   'regionCode': 'CA',
#   'regionWdId': 'Q99',
#   'latitude': 34.0402901,
#   'longitude': -118.222573,
#   'population': 0,
#   'distance': 1.71}]

# %%
pd.DataFrame(data)
# list of dictionaray
# key of column name valuues ko unko value
# Out:
#         id  wikiDataId  type              city              name  \
# 0  3446973    Q2928231  CITY       Bunker Hill       Bunker Hill
# 1  3855177         Q65  CITY       Los Angeles       Los Angeles
# 2  3447478    Q4762767  CITY  Angelino Heights  Angelino Heights
# 3  3824900  Q122553752  CITY  Mission Junction  Mission Junction
# 4  3832131  Q122570043  CITY      Pico Gardens      Pico Gardens
#
#                     country countryCode      region regionCode regionWdId  \
# 0  United States of America          US  California         CA        Q99
# 1  United States of America          US  California         CA        Q99
# 2  United States of America          US  California         CA        Q99
# 3  United States of America          US  California         CA        Q99
# 4  United States of America          US  California         CA        Q99
#
#     latitude   longitude  population  distance
# 0  34.052040 -118.250340           0      0.14
# 1  34.052230 -118.243680     3898747      0.39
# 2  34.070278 -118.254722           0      1.43
# 3  34.062511 -118.227573           0      1.55
# 4  34.040290 -118.222573           0      1.71

# %%
print(response.json())
# Out:
# {'links': [{'rel': 'first', 'href': '/v1/geo/adminDivisions/Q104994/nearbyCities?offset=0&limit=5&radius=100'}, {'rel': 'next', 'href': '/v1/geo/adminDivisions/Q104994/nearbyCities?offset=5&limit=5&radius=100'}, {'rel': 'last', 'href': '/v1/geo/adminDivisions/Q104994/nearbyCities?offset=770&limit=5&radius=100'}], 'data': [{'id': 3446973, 'wikiDataId': 'Q2928231', 'type': 'CITY', 'city': 'Bunker Hill', 'name': 'Bunker Hill', 'country': 'United States of America', 'countryCode': 'US', 'region': 'California', 'regionCode': 'CA', 'regionWdId': 'Q99', 'latitude': 34.05204, 'longitude': -118.25034, 'population': 0, 'distance': 0.14}, {'id': 3855177, 'wikiDataId': 'Q65', 'type': 'CITY', 'city': 'Los Angeles', 'name': 'Los Angeles', 'country': 'United States of America', 'countryCode': 'US', 'region': 'California', 'regionCode': 'CA', 'regionWdId': 'Q99', 'latitude': 34.05223, 'longitude': -118.24368, 'population': 3898747, 'distance': 0.39}, {'id': 3447478, 'wikiDataId': 'Q4762767', 'type': 'CITY', 'city': 'Angelino Heights', 'name': 'Angelino Heights', 'country': 'United States of America', 'countryCode': 'US', 'region': 'California', 'regionCode': 'CA', 'regionWdId': 'Q99', 'latitude': 34.070277777, 'longitude': -118.254722222, 'population': 0, 'distance': 1.43}, {'id': 3824900, 'wikiDataId': 'Q122553752', 'type': 'CITY', 'city': 'Mission Junction', 'name': 'Mission Junction', 'country': 'United States of America', 'countryCode': 'US', 'region': 'California', 'regionCode': 'CA', 'regionWdId': 'Q99', 'latitude': 34.0625114, 'longitude': -118.2275733, 'population': 0, 'distance': 1.55}, {'id': 3832131, 'wikiDataId': 'Q122570043', 'type': 'CITY', 'city': 'Pico Gardens', 'name': 'Pico Gardens', 'country': 'United States of America', 'countryCode': 'US', 'region': 'California', 'regionCode': 'CA', 'regionWdId': 'Q99', 'latitude': 34.0402901, 'longitude': -118.222573, 'population': 0, 'distance': 1.71}], 'metadata': {'currentOffset': 0, 'totalCount': 775}}

# %%
response.json()['links']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 response.json()['links']
#
# KeyError: 'links'

# %%
response.json()['metadata']['totalCount']
# Out:
# 775

# %%
775/5 # tho huma 155 times loop chalan aha
# Out:
# 155.0

# %% [markdown]
# ### Problem 3:
#
# Go to this url: https://www.flipkart.com/search?q=smartphones. This is the url to find phones in flipkart website. You have to extract the below things:
# 1. image url of the phone
# 2. name of the image
# 3. average ratings
# 4. total ratings
# 5. total reviews
# 6. discounted price
# 7. actual price
#
# Extract all the phones which are available in this website. So you have to use the pagination concept. **Also after requesting every page through the url, please wait for a while (minimum 2-3 seconds), otherwise your IP address can be banned to access the flipkart website later.**
#
# After collecting all the data, save that in a JSON file.

# %%
# code here
