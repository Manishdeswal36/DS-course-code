# %% [markdown]
# So Data anlysis have 5 steps
# 1. Asking Question
# 2. Data Wraning
#    -  Data Gathering
#    -  Data Asseing
#    - Data cleaning

# %% [markdown]
# Then in Data Gathering
# - csv
# - api
# - Webscraping
# - database

# %%
# we learn the basic webscraping using request and beautiful soup library
# some websities are tricky 
# today we learn how to do advance web Scrapinng using Selenium 
# after that you scrap any normal or difficult website .

# %%
# some advance tools or software also that do the web scraping .
# but today we  learn programatically .

# %%
# smartprix website ma aaj webscraping karega
# aap ek project bana sakta ho like laptop price predactor 
# example 8gb game ha 512 ssd ha 
# tho is range ma aap laptop buy kar sakta ho 
# sir na bana raka ha 

# aap ek phone price predicator app bhi bana sakta ho.
# same like 8gb ram ha 64 gb rom ha camera
# apko price bata deka .

# ya machine learning predication problem ha 
# aap ek recommender sytem bhi bana sakta ho
# yadi aap is par click karo tho ek phone par 

# us sa similar phone mil jayega .  sayad apko 
# phoen bhi pasand aa sakta ha

# %%
# tho apko data ka liya webscraping karna pad sakta ha 
# lakin ya smartprix dyanmic website ha .
# apko ya ek bhari ma 20 phones dekata ha yadi apko agla phones dekna ha
# tho dubara load par click karta ho 

# deko request library ma asa koi mechansim nahi ha ki vo par click kara uska htmlf laya
# deko ya dyamic website ha tho phala first 20 phones ka html code ata 
# lakin jasa hi user load 20 par click karta ha 
# tho website server yani (database ) par request karta ha
# agla 20 phones ka data fir usko html code ata ha
# so we have to learn new tools that do the task

# %%
# twitter ,instagram ,yotube ya sari dyanmic  website 
# deko ya ajio website jo products seel karti 
# menj jact ma kuch 7000 items ha 
# lakin show vo sirf 50 ki karega 
# kyuki yadi aab sara content (data) ko website par ek dam daaloga
# tho website slow ho jayega isliya web developer na ya technique lagayi
# thirda thirda website load karta ha . 
# slowly as you swipe they load the data .

# %% [markdown]
# Selenium is a suite of tools for automating web browser .
# - It is primarily used for testing the web application
# - It is used for web scraping ,data extraction .
# - and other tasks that require interactive with web browser programmatically .

# %% [markdown]
# so in software industry. there are two person
# - software engierns who write the code.
# - QA or tester who test the code .  (ki tik kam tho kar raha hana)

# %% [markdown]
# With Selenium, you can write code in variety of programming lanuages ,including python,java ,C# aand others , to controle a web browser and interact with a web page .
# aap selenium ka use kareka User Interaction ko Simulate kar sakta ho .jasa ki button par click,filling out forms and naviagting between pages ,  aor other gernal task s.
# aor test kar sakta ho ki web application kasa behave kar rahi ha .

# %% [markdown]
# aap selenium ka use karka web scraping kar saka ho
# fir aap ek dataframe bana sakta ho
# aor us par anlaysis kar sakta ho .

# %% [markdown]
# Technology sikana ma time lagta ha . deko yadi aap acha level ka selenium sikana chata ho tho apko 10 -15 classes  leni padegai
# fir uska upar pratice karna padega .

# %% [markdown]
#  lakin huma yaha sirf data analysis ka perspective sa cheeza sika raha ha . Data Science padna ka persepctive ma jo bhi cheeza aya gi we study it

# %% [markdown]
# Steps
# - Install Selenium
# - Install chromedriver

# %%
# deko automatically mera bina open kara chrome open hoga

# %% [markdown]
# # Campus x

# %% [markdown]
# ## open chrome browser

# %% [markdown]
# ## open google

# %%
# open the google chrome
# 


from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time

# Uncomment this and set correct path for Brave if using Brave
# options = Options()
# options.binary_location = r"C:\Program Files\BraveSoftware\Brave-Browser\Application\brave.exe"

# hum seliumn ka class ka use kar raha ha aor object bana kar use kar raha ha 
s = Service(r"C:\Users\sumit\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe")
# driver = webdriver.Chrome(service=s, options=options) # For Brave
driver = webdriver.Chrome(service=s) # For Chrome

driver.get('http://google.com')
input("Press Enter to close the browser...")  # Keeps window open until you press Enter

# %% [markdown]
# ## open youtube

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time

#Uncomment this and set correct path for Brave if using Brave
#options = Options()
#options.binary_location = r"C:\Program Files\BraveSoftware\Brave-Browser\Application\brave.exe"

s = Service(r"C:\Users\sumit\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe")
# driver = webdriver.Chrome(service=s, options=options) # For Brave
driver = webdriver.Chrome(service=s) # For Chrome

driver.get('http://youtube.com')
#input("Press Enter to close the browser...")  # Keeps window open until you press Enter

# %% [markdown]
# ## open example.com

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time

#Uncomment this and set correct path for Brave if using Brave
#options = Options()
#options.binary_location = r"C:\Program Files\BraveSoftware\Brave-Browser\Application\brave.exe"

s = Service(r"C:\Users\sumit\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe")
# driver = webdriver.Chrome(service=s, options=options) # For Brave
driver = webdriver.Chrome(service=s) # For Chrome

driver.get('http://example.com')
input("Press Enter to close the browser...")  # Keeps window open until you press Enter

# %%
# open google.com
# search campusx
# learnwith.campusx.in
# dsmp course page
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

options = Options()
options.binary_location = r"C:\Program Files\BraveSoftware\Brave-Browser\Application\brave.exe"

s = Service(r"C:\Users\sumit\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe")
# driver = webdriver.Chrome(service=s, options=options) # For Brave
driver = webdriver.Chrome(service=s) # For Chrome

driver.get('http://google.com')
time.sleep(4)


# fetch the search input box using xpath

user_input = driver.find_element(
    by=By.XPATH,
    value='//*[@id="APjFqb"]'
    #value='/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input'
    )
user_input.send_keys('Campusx')
time.sleep(5)


user_input.send_keys(Keys.ENTER)
time.sleep(20)


link = driver.find_element(
    by= By.XPATH,
    #value= '//*[@id="rso"]/div[1]/div/div/div/div/div/div/div/div[1]/div/span/a'
    value='//*[@id="rso"]/div[1]/div/div/div/div/div/div/div/div[1]/div/span/a'
    #value = '/html/body/div[3]/div/div[11]/div/div[2]/div[2]/div/div/div[1]/div/div/div/div/div/div/div/div[1]/div/span/a'
)
link.click()
time.sleep(230)

#input("Press Enter to close the browser...")  # Keeps window open until you press Enter

# %%
# har kisi kar x path hota ha waha tak puchana ka

# %%
# wow ham user ka flow ko simulate kar pa raha ha ji

# %% [markdown]
# Xpath is a lanuague used to navigate XML  and HTML in order to locate elements within the document .selenium it is used to find elements on a web page such as linkds button,text boxes ,etc that with xpath expressions can be used to select elements based on their tag name ,attributes or postion within the documents

# %% [markdown]
# deko html ka andr alag alag tags ,elements hota . unko khojna ka liya hum xpath ka use karta ha . fir unka sath hum interact kar raha click kar rha ha ya

# %% [markdown]
# # Ajio

# %% [markdown]
# now we move part 2 of the class start

# %% [markdown]
# ## simple code

# %%
# plan is hum ajio website ma back pack par jayaega
# aor selenium sa infinite scroll karwaya ga . 
# yani bottom tak scroll karega . 
# fir us page ka sara html load ho jayega 
# usko extract karega.

from selenium import webdriver
from selenium.webdriver.chrome.service import Service


# initalise the chrome driver and make serive object
service_object = Service(r"C:\Users\sumit\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe")

# sent your serive object into chrome class
driver = webdriver.Chrome(service=service_object)

driver.get('https://www.ajio.com/men-backpacks/c/830201001')

# %%
# that is vary high chance that google chrome or ajio,flipkart,amozon detect me as bot
# this is a vary simple

# %% [markdown]
# ## dont detect it

# %%
# plan is hum ajio website ma back pack par jayaega
# aor selenium sa infinite scroll karwaya ga . 
# yani bottom tak scroll karega . 
# fir us page ka sara html load ho jayega 
# usko extract karega.

from selenium import webdriver
from selenium.webdriver.chrome.service import Service


# initalise the chrome driver and make serive object
service_object = Service(r"C:\Users\sumit\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe")

# sent your serive object into chrome class
driver = webdriver.Chrome(service=service_object)

driver.get('https://www.ajio.com/men-backpacks/c/830201001')

# %% [markdown]
# ## ajio scraping code

# %%
# Overview 
# We extract the data from ajio website 
# we use the senium to browse it
# we check first its webpage height
# then we run the loop 
# and when the loop complete
# extract the all html code from the ajio webpage and store them
# in a file 



from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time

# initalise the chrome driver and make serive object
service_object = Service(r"C:\Users\sumit\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe")

# sent your serive object into chrome class
driver = webdriver.Chrome(service=service_object)

driver.get('https://www.ajio.com/men-backpacks/c/830201001')

old_height = driver.execute_script('return document.body.scrollHeight')

counter = 1
while True:


    driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    time.sleep(2)

    new_height = driver.execute_script('return document.body.scrollHeight')

    print(counter)
    counter += 1
    print(old_height)
    print(new_height)

    if new_height == old_height:
        break

    old_height = new_height



html = driver.page_source

with open('ajio.html','w',encoding='utf-8') as f:
    f.write(html)
