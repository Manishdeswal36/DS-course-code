# %%
import pandas as pd
df = pd.read_csv('startup_funding.csv')
df
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      09/01/2020                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3      09/01/2020                     Mamaearth
# 3         4      02/01/2020  https://www.wealthbucket.in/
# 4         5      02/01/2020                        Fashor
# ...     ...             ...                           ...
# 3039   3040      29/01/2015                    Printvenue
# 3040   3041      29/01/2015                      Graphene
# 3041   3042      30/01/2015                Mad Street Den
# 3042   3043      30/01/2015                     Simplotel
# 3043   3044      31/01/2015              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# ...

# %% [markdown]
# ### startup names

# %%
df['Startup Name'].unique().shape
# Out:
# (2459,)

# %%
df['Startup Name'].unique().tolist()
# Out:
# ['BYJU’S',
#  'Shuttl',
#  'Mamaearth',
#  'https://www.wealthbucket.in/',
#  'Fashor',
#  'Pando',
#  'Zomato',
#  'Ecozen',
#  'CarDekho',
#  'Dhruva Space',
#  'Rivigo',
#  'Healthians',
#  'Licious',
#  'InCred',
#  'Trell',
#  'Rein Games',
#  'Lenskart.com',
#  'Freshworks',
#  'Misters',
#  'Sunstone Eduversity Pvt. Ltd',
#  'Burger Singh',
#  'Ninjacart',
#  'Aye Finance',
#  'SuperGaming',
#  'Clumio',
#  'eBikeGo',
#  'Digital Mall Asia',
#  'Medikabazaar',
#  'Vogo Automotive',
#  'Furtados School of Music',
#  'Paytm',
#  'Dunzo',
#  'Udaan',
#  'The Man Company',
#  'FPL Technologies',
#  'Cashflo',
#  'Digital F5',
#  '3rdFlix',
#  '75F',
#  'Myelin Foundry',
#  'Atomberg Technology',
#  'GOQii',
#  'Vyapar App',
#  'Progcap',
#  'MyPetrolPump',
#  'Alteria Capital',
#  'Pine Labs',
#  'Meesho',
#  'Cars24',
#  'Uniphore',
#  'Zendrive',
#  'Lo! Foods',
#  'Tala',
#  'INDwealth',
#  'HungerBox',
#  'AdmitKard',
#  'Mishry Reviews',
#  'Grofers',
#  'Rapido Bike Taxi',
# ...

# %%
sorted(df['Startup Name'].unique().tolist())
# Out:
# ['"BYJU\\\\\'S"',
#  '#Fame',
#  '121Policy',
#  '19th mile',
#  '1Crowd',
#  '1mg',
#  '1mg (Healthkartplus)',
#  '20Dresses',
#  '33Coupons',
#  '360Ride',
#  '3Dexter',
#  '3HCare',
#  '3rdFlix',
#  '48East',
#  '4tigo',
#  '5th Vital',
#  '6Degree',
#  '75F',
#  '91SpringBoard',
#  '99Games',
#  '99PerHour',
#  '9Stacks',
#  'A&R Bon Vivants',
#  'ABI Health',
#  'AEON Learning',
#  'AHA Taxis',
#  'AYE Finance',
#  'AadharAPI.com',
#  'Aadyah',
#  'Aahaa',
#  'Aahaa Stores',
#  'Aarav UAV',
#  'Aasaanjobs',
#  'Aashiyaan',
#  'Aavishkaar-Intellecap Group',
#  'AbeRuk',
#  'Abhibus',
#  'Absentia',
#  'Absentia VR',
#  'Ace Turtle',
#  'Ace2three',
#  'Acko',
#  'ActOnMagic',
#  'Actionable Analytics',
#  'Active AI',
#  'Active.ai',
#  'Actofit',
#  'Ad2pro',
#  'AdPushUp',
#  'AdStringO',
#  'AdUrCup',
#  'AdWyze',
#  'Address Health',
#  'AdmitKard',
#  'Advanced Structures India',
#  'Advantage Club',
#  'Advenio',
#  'Adytude',
#  'Aequm',
#  'AerMed',
#  'Affimity',
# ...

# %% [markdown]
# ### investor  names

# %%
df['Investors Name'].unique().tolist()
# Out:
# ['Tiger Global Management',
#  'Susquehanna Growth Equity',
#  'Sequoia Capital India',
#  'Vinod Khatumal',
#  'Sprout Venture Partners',
#  'Chiratae Ventures',
#  'Ant Financial',
#  'Sathguru Catalyzer Advisors',
#  'Ping An Global Voyager Fund',
#  'Mumbai Angels, Ravikanth Reddy',
#  'SAIF Partners, Spring Canter Investment Ltd.',
#  'Paytm, NPTK, Sabre Partners and Neoplux',
#  'Vertex Growth Fund',
#  nan,
#  'Ruizheng Investment',
#  'Manipal Education and Medical Group (MEMG)',
#  'SoftBank Vision Fund',
#  'Sequoia, CapitalG, Accel',
#  'Sauce.vc, Rainforest Ventures',
#  'Prime Venture Partners, LetsVenture, PS1 Venture and GlobalLogic co-founder Rajul Garg',
#  'RB Investments',
#  'DG Daiwa Ventures, DG Incubation',
#  'Trifecta Capital Advisors',
#  'FinTech',
#  'Dream Incubator',
#  'Altimeter Capital, Sutter Hill Ventures',
#  'Startup Buddy',
#  'Amour Infrastructure',
#  'Ackermans & van Haaren, HealthQuad, Rebright Partners, Toppan Printing',
# ...

# %%
df['Investors Name'].unique().tolist()
# Out:
# ['Tiger Global Management',
#  'Susquehanna Growth Equity',
#  'Sequoia Capital India',
#  'Vinod Khatumal',
#  'Sprout Venture Partners',
#  'Chiratae Ventures',
#  'Ant Financial',
#  'Sathguru Catalyzer Advisors',
#  'Ping An Global Voyager Fund',
#  'Mumbai Angels, Ravikanth Reddy',
#  'SAIF Partners, Spring Canter Investment Ltd.',
#  'Paytm, NPTK, Sabre Partners and Neoplux',
#  'Vertex Growth Fund',
#  nan,
#  'Ruizheng Investment',
#  'Manipal Education and Medical Group (MEMG)',
#  'SoftBank Vision Fund',
#  'Sequoia, CapitalG, Accel',
#  'Sauce.vc, Rainforest Ventures',
#  'Prime Venture Partners, LetsVenture, PS1 Venture and GlobalLogic co-founder Rajul Garg',
#  'RB Investments',
#  'DG Daiwa Ventures, DG Incubation',
#  'Trifecta Capital Advisors',
#  'FinTech',
#  'Dream Incubator',
#  'Altimeter Capital, Sutter Hill Ventures',
#  'Startup Buddy',
#  'Amour Infrastructure',
#  'Ackermans & van Haaren, HealthQuad, Rebright Partners, Toppan Printing',
# ...

# %%
sorted(df['Investors Name'].unique().tolist())
# ya isliya hua kyuki pandas na missing value ko np.nan yani float ma store kiya
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 sorted(df['Investors Name'].unique().tolist())
#       2 # ya isliya hua kyuki pandas na missing value ko np.nan yani float ma store kiya
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
# kahi baar hota hi ki start investor compnay ka name nahi bata ti 
# so we write undisclosed . 
df['Investors Name'].fillna('undisclosed',inplace=True)
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_6844\4292309786.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Investors Name'].fillna('undisclosed',inplace=True)

# %%
print(sorted(df['Investors Name'].unique().tolist()))
# Out:
# ['"Kedaraa Capital, Ontario Teachers\\\\\'"', '021 Capita, Binny Bansal', '1Crowd', '1Crowd (through crowd funding)', '1Crowd (through crowdfunding)', '1Crowd, Ankur Capital', '1Crowd, Eureka Forbes Ltd, Shapoorji Pallonji & Co. Ltd.', '3 undisclosed HNIs', '3 undisclosed investors', '3One4 Capital', '3one4 Capital, Mumbai Angels, Aarin Capital', '3one4 Capital, Tracxn Labs, Aaruha Technology Fund, Endiya Partners', '3one4 capital', '500 Startups', '500 Startups, IDG Ventures & Advantedge fund, Neeraj Arora, Leon Seynave', '500 Startups, IvyCap Ventures', '500 Startups, Littlerock, Singularity Ventures', '500 Startups, Mato Peric & Others', '500 Startups, Mato Peric, TracxnLabs', '500 Startups, Purvi Capital, Rajan Anandan, Abhishek Gupta', '500 Startups, Smile Multimedia, Kunal Bahl, Rohit Bansal, Girish Matrubootham', '500 Startups, TV Mohandas Pai, Tandem Capital, Vikram Chachra, Aloke Bajpai', '50K Ventures', '50k Ventures, Munish Jauhar, Pulkit Jain, Rohit Narang', '91maker.com'
# ...

# %% [markdown]
# so we start anlaysis by investor because we learn how to clean data and investor coloumn is very unclean data we have to clean it bhut kachara ho raka ha waha

# %% [markdown]
# so when funding is needed in startup it does not happen like a investor give all money tho ek hi company ka andr multiple investor hoga example a startup need 1crore than 40 lakh form one investor , and 40 from another and 30 from another

# %% [markdown]
# so in our dataset their have multiple entries where multiple investor name in one entry.

# %% [markdown]
# so first goal is ki ahar ek invesot ka name ko alag karna ha muja group of investor ko study nahi karna muja single investor ko study karna ha usna kaha kaha paisa lagya ha

# %% [markdown]
# ## data preprocessing
# - drop remark coloumn
# - set index number
# - renmae coloumn
# - convert amount to Cr. rupess
# - date col
# - drop na
# - investor ko alag alag karaga

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3044 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %% [markdown]
# so remarks coloumn ma 10% data bhi nahi ha usa bhi kam data ha we drop the coloumn because it not help us in analysis

# %% [markdown]
# so set index hamara vo padas generate kar raha ho or phala bhi data ha so serial number ko hum index set karaga

# %% [markdown]
# rename the coloumn example
# -  date(mm/dd/yyyy)
# - city location
# - investement and type

# %% [markdown]
# data ma jo amount ha money usd ma hum usa crrore rupess ma convert kar lega.

# %% [markdown]
# date coloumn string isko datetime data type ma convert karaga

# %% [markdown]
# data ma industry nahi tho vo usa remove kar dega lakin hum dhyan dega ki kahi jada data remove na ho jaya

# %% [markdown]
# example 3000 rows ha 300 hata diya 10% is mangemable chalaga

# %% [markdown]
# ### drop remark coloumn

# %%
df.drop(columns=['Remarks'],inplace=True)

# %% [markdown]
# ### set index

# %%
df.set_index('Sr No',inplace=True)

# %%
df.columns
# Out:
# Index(['Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical', 'SubVertical',
#        'City  Location', 'Investors Name', 'InvestmentnType', 'Amount in USD'],
#       dtype='object')

# %% [markdown]
# ### rename coloumns

# %%
df.rename(columns={
    'Date dd/mm/yyyy': 'date',
    'Startup Name': 'startup',
    'Industry Vertical': 'vertical',
    'SubVertical': 'subvertical',
    'City  Location': 'city',
    'Investors Name': 'investers',
    'InvestmentnType': 'round',
    'Amount in USD': 'amount',
},inplace=True)
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_6844\1137089548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={

# %%
df.columns
# Out:
# Index(['date', 'startup', 'vertical', 'subvertical', 'city', 'investment',
#        'round', 'amount'],
#       dtype='object')

# %%
df
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue                  NaN
# 3041   29/01/2015                      Graphene                  NaN
# 3042   30/01/2015                Mad Street Den                  NaN
# 3043   30/01/2015                     Simplotel                  NaN
# 3044   31/01/2015              couponmachine.in                  NaN
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %% [markdown]
# ### convert amount to crore

# %% [markdown]
# #### check datatype of amount
# it is string

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3044 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3044 non-null   object
#  1   startup      3044 non-null   object
#  2   vertical     2873 non-null   object
#  3   subvertical  2108 non-null   object
#  4   city         2864 non-null   object
#  5   investment   3044 non-null   object
#  6   round        3040 non-null   object
#  7   amount       2084 non-null   object
# dtypes: object(8)
# memory usage: 214.0+ KB

# %%
# and they are in string data-type format we have convert in float
# why we convert in float not in integer
# so the promblem is there are 2084 meaning approx thousands values are missing
# we replace np.nan values to 0 meaning not disclose or not known company does not tell the investor name

# %%
# 0 meaning jitna capital usna raise kiya usna media ko btaya nah

# %% [markdown]
# #### fill nan values with 0

# %%
#df['amount'] =df['amount'].fillna({'amount':'0'},inplace=True)
df['amount'] =df['amount'].fillna('0')

# %% [markdown]
# #### now check if it filled or not

# %%
df.info()
# now i don't have missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3044 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3044 non-null   object
#  1   startup      3044 non-null   object
#  2   vertical     2873 non-null   object
#  3   subvertical  2108 non-null   object
#  4   city         2864 non-null   object
#  5   investment   3044 non-null   object
#  6   round        3040 non-null   object
#  7   amount       3044 non-null   object
# dtypes: object(8)
# memory usage: 214.0+ KB

# %% [markdown]
# #### now convert into int promblem 1

# %%
df['amount'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 df['amount'].astype('int')
#
# File c:\Users\sumit\miniconda3\envs\my_env\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\sumit\miniconda3\envs\my_env\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %% [markdown]
# #### solve the comma problme in it

# %%
# aap is tara '20,00,00,000' ki cheez ko integer ma convert nahi kar sakta kyuki bitch ma comas ha 
# question is how to removes commas in it 
df['amount']= df['amount'].str.replace(',','')

# %%
df['amount']
# Out:
# Sr No
# 1       200000000
# 2         8048394
# 3        18358860
# 4         3000000
# 5         1800000
#           ...
# 3040      4500000
# 3041       825000
# 3042      1500000
# 3043            0
# 3044       140000
# Name: amount, Length: 3044, dtype: object

# %%
df['amount'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 df['amount'].astype('int')
#
# File c:\Users\sumit\miniconda3\envs\my_env\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\sumit\miniconda3\envs\my_env\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
# so kahi kahi par 'undisclosed' lika ha usko hum convert nahi kar pa raha integer ma
# jaha par bhi undisclosed ha usko hum empty space sa cover karta ha

# %% [markdown]
# #### solve the undisclosed promblem

# %%
df['amount']= df['amount'].str.replace('undisclosed','0',)

# %%
df['amount'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 df['amount'].astype('int')
#
# File c:\Users\sumit\miniconda3\envs\my_env\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\sumit\miniconda3\envs\my_env\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
# aba kahi kahi data ma unknwon string lika ha so we have to solve it 
# isko bhi replace karo

# %% [markdown]
# #### solve the unknown problem

# %%
df['amount']= df['amount'].str.replace('unknown','0',)

# %%
df['amount'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 df['amount'].astype('int')
#
# File c:\Users\sumit\miniconda3\envs\my_env\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\sumit\miniconda3\envs\my_env\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
# aab kahi par capital ma 'Undisclosed' lika ha usa solve karo

# %%
df['amount']= df['amount'].str.replace('Undisclosed','0',)

# %%
df['amount'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 df['amount'].astype('int')
#
# File c:\Users\sumit\miniconda3\envs\my_env\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\sumit\miniconda3\envs\my_env\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
# ab kahi kahi data ma float datatype tho vo integer ma nahi ho raha
# now isko convert karo float ma

# %% [markdown]
# #### solve the float promblem

# %%
df['amount'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 df['amount'].astype('float')
#
# File c:\Users\sumit\miniconda3\envs\my_env\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\sumit\miniconda3\envs\my_env\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3044 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3044 non-null   object
#  1   startup      3044 non-null   object
#  2   vertical     2873 non-null   object
#  3   subvertical  2108 non-null   object
#  4   city         2864 non-null   object
#  5   investment   3044 non-null   object
#  6   round        3040 non-null   object
#  7   amount       3044 non-null   object
# dtypes: object(8)
# memory usage: 214.0+ KB

# %%
## ab kahi kahi par integer ka sath + symbol bhi laga hua ha

# %%
df['amount'].str.isdigit().sum()
# 3044 - 3029 = 15 
# abhi bhi 15 asi values ha jo digit nahi matlab 15 different kuch ek 
# jasa error aya ga
# un coloumns ko tik karna hoga
# Out:
# np.int64(3029)

# %%
# tho digit wali rows ko nikalo un par hi kar karga
df[df['amount'].str.isdigit()] 
# assign it make permanet operation
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue                  NaN
# 3041   29/01/2015                      Graphene                  NaN
# 3042   30/01/2015                Mad Street Den                  NaN
# 3043   30/01/2015                     Simplotel                  NaN
# 3044   31/01/2015              couponmachine.in                  NaN
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
df = df[df['amount'].str.isdigit()]

# %% [markdown]
# #### we successful convert into float

# %%
df['amount'].astype('float')
# Out:
# Sr No
# 1       200000000.0
# 2         8048394.0
# 3        18358860.0
# 4         3000000.0
# 5         1800000.0
#            ...
# 3040      4500000.0
# 3041       825000.0
# 3042      1500000.0
# 3043            0.0
# 3044       140000.0
# Name: amount, Length: 3029, dtype: float64

# %%
# reassign it 
df['amount']= df['amount'].astype('float')
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_6844\615016167.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amount']= df['amount'].astype('float')

# %%
df['amount'].dtype
# done ho gaya
# Out:
# dtype('float64')

# %% [markdown]
# #### func to_inr

# %%
def to_inr(dollar):
    inr = dollar * 82.5
    return inr/10000000

# %%
df['amount'] = df['amount'].apply(to_inr)
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_6844\2898200987.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amount'] = df['amount'].apply(to_inr)

# %%
df['amount']
# Out:
# Sr No
# 1       1650.000000
# 2         66.399250
# 3        151.460595
# 4         24.750000
# 5         14.850000
#            ...
# 3040      37.125000
# 3041       6.806250
# 3042      12.375000
# 3043       0.000000
# 3044       1.155000
# Name: amount, Length: 3029, dtype: float64

# %%
df
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue                  NaN
# 3041   29/01/2015                      Graphene                  NaN
# 3042   30/01/2015                Mad Street Den                  NaN
# 3043   30/01/2015                     Simplotel                  NaN
# 3044   31/01/2015              couponmachine.in                  NaN
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %% [markdown]
# ### date coloumn
# convert into date type object

# %%
pd.to_datetime(df['date'],errors='coerce')
# Out:
# Sr No
# 1      2020-09-01
# 2             NaT
# 3      2020-09-01
# 4      2020-02-01
# 5      2020-02-01
#           ...
# 3040          NaT
# 3041          NaT
# 3042          NaT
# 3043          NaT
# 3044          NaT
# Name: date, Length: 3029, dtype: datetime64[ns]

# %%
df['date'].str.contains('05/072018')
df[df['date'].str.contains('05/072018')]
#df[df['date'].str.find('05/072018')]
# Out:
# Empty DataFrame
# Columns: [date, startup, vertical, subvertical, city, investment, round, amount]
# Index: []

# %%
df['date'] = df['date'].str.replace('05/072018','05/07/2018')
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_6844\805237904.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['date'].str.replace('05/072018','05/07/2018')

# %%
pd.to_datetime(df['date'],errors='coerce').size
# Out:
# 3029

# %%
pd.to_datetime(df['date'],errors='coerce').count()
# Out:
# np.int64(1284)

# %%
pd.to_datetime(df['date'],errors='ignore').count()
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_6844\3907141335.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   pd.to_datetime(df['date'],errors='ignore').count()
# np.int64(3029)

# %%
pd.to_datetime(df['date'],errors='ignore').size
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_6844\436564260.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   pd.to_datetime(df['date'],errors='ignore').size
# 3029

# %%
pd.to_datetime(df['date'],errors='coerce').info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 3029 entries, 1 to 3044
# Series name: date
# Non-Null Count  Dtype
# --------------  -----
# 1284 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 47.3 KB

# %%
df['date'] = pd.to_datetime(df['date'],errors='ignore')
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_6844\3238279543.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df['date'] = pd.to_datetime(df['date'],errors='ignore')
# C:\Users\sumit\AppData\Local\Temp\ipykernel_6844\3238279543.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'],errors='ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3029 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1284 non-null   datetime64[ns]
#  1   startup      3029 non-null   object
#  2   vertical     2858 non-null   object
#  3   subvertical  2104 non-null   object
#  4   city         2849 non-null   object
#  5   investment   3029 non-null   object
#  6   round        3027 non-null   object
#  7   amount       3029 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 213.0+ KB

# %%
df
# Out:
#             date                       startup             vertical  \
# Sr No
# 1     2020-09-01                        BYJU’S               E-Tech
# 2            NaT                        Shuttl       Transportation
# 3     2020-09-01                     Mamaearth           E-commerce
# 4     2020-02-01  https://www.wealthbucket.in/              FinTech
# 5     2020-02-01                        Fashor  Fashion and Apparel
# ...          ...                           ...                  ...
# 3040         NaT                    Printvenue                  NaN
# 3041         NaT                      Graphene                  NaN
# 3042         NaT                Mad Street Den                  NaN
# 3043         NaT                     Simplotel                  NaN
# 3044         NaT              couponmachine.in                  NaN
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
# benefit of datetime object is ki aap usma sa year,month,day,time ko nikal sakta ho
df['date'].dt.month
# apna har ek month nikal liya 
# agar aapsa koi month on month deals pucha
# aap asa hi year,day bhi nikal sakta ho
# Out:
# Sr No
# 1       9.0
# 2       NaN
# 3       9.0
# 4       2.0
# 5       2.0
#        ...
# 3040    NaN
# 3041    NaN
# 3042    NaN
# 3043    NaN
# 3044    NaN
# Name: date, Length: 3029, dtype: float64

# %% [markdown]
# ### dropna
# we remove the missing value in the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3029 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1283 non-null   datetime64[ns]
#  1   startup      3029 non-null   object
#  2   vertical     2858 non-null   object
#  3   subvertical  2104 non-null   object
#  4   city         2849 non-null   object
#  5   investment   3005 non-null   object
#  6   round        3027 non-null   object
#  7   amount       3029 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 213.0+ KB

# %%
# subvertical ma bhut jada value missing ha tho hum usko chod ka baki sabhi coloumn ka basics par dropna laga sakta ha

# %%
df.columns
# Out:
# Index(['date', 'startup', 'vertical', 'subvertical', 'city', 'investment',
#        'round', 'amount'],
#       dtype='object')

# %%
df = df.dropna(subset=[ 'startup', 'vertical',  'city', 'investment','round', 'amount'])

# %%
df
# Out:
#             date                       startup                    vertical  \
# Sr No
# 1     2020-09-01                        BYJU’S                      E-Tech
# 2            NaT                        Shuttl              Transportation
# 3     2020-09-01                     Mamaearth                  E-commerce
# 4     2020-02-01  https://www.wealthbucket.in/                     FinTech
# 5     2020-02-01                        Fashor         Fashion and Apparel
# ...          ...                           ...                         ...
# 2869         NaT                        Tracxn  Startup Analytics platform
# 2870         NaT                          Dazo    Mobile Food Ordering app
# 2871         NaT                      Tradelab  Financial Markets Software
# 2872         NaT                        PiQube   Hiring Analytics platform
# 2873         NaT               Travel Triangle   Online Travel Marketplace
#
#                                  subvertical       city  \
# ...

# %% [markdown]
# ## two options
# - first ki ya cleaning wala sara code app.py ma liko
# - ya fir is clean wala data ko sida export kar do

# %% [markdown]
# ya hota ha ki phala data ko pura clean kiya jata ha fir uska upar project banya jata ha .
# - hum asa isliya nahi kar paya kyuki huma nahi pata on the way data clean hum pura kar paya ha ki nahi ya fir isma aor bhi kuch parasani ha

# %% [markdown]
# # investor

# %% [markdown]
# ## import the data
# - read_csv read karta ha data ko
# - to_csv data ko load karta ha

# %%
df.rename(columns={'investment': 'investers',
},inplace=True)
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_6844\3186669681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'investment': 'investers',

# %%
df['']

# %%
df.to_csv('startup_clean.csv',index=False)

# %%
## ab huma sara investor ka name ko alag karna ha
# df['investers'].str.split(',') # split the names of investor by comma
# than apply sum on it and make a giant list 
#df['investers'].str.split(',').sum()
# lakin abb unique nikalan ka tarika hum esa set ma convert kar da tho iska unique items
# rahega 
#set(df['investers'].str.split(',').sum())
# fir dubara aap isko list ma convert kar do 
# muja sorted bhi karna ha usko

# %%
# kal yadi ek compnay ma multiple investor tho vo ek sath aa raha tha now vo akala(invidually ) aa raha ha

# %%
sorted(set(df['investers'].str.split(',').sum()))
# Out:
# ['',
#  ' & Others',
#  ' 100 Co-founders Lab and others.',
#  ' 122 West Ventures',
#  ' 1Crowd',
#  ' 3ONE4 Capital Advisors',
#  ' 3one4 Capital',
#  ' 3one4 Capital Advisors LLP',
#  ' 500 Start-Ups',
#  ' 500 Startups',
#  ' 500 Startups & Other HNIs',
#  ' 50K Ventures & others',
#  ' 91SpringBoard',
#  ' 91springboard',
#  ' ABB Technology Ventures',
#  ' ABCOM Investments',
#  ' AECAL',
#  ' AET Fund',
#  ' AL Nour International Holdings and Mark V Investments',
#  ' ASP Consulting',
#  ' AVN Business Solutions',
#  ' Aarin Capital',
#  ' Aarin Capital & Others',
#  ' Aaruha Technology Fund',
#  ' Abaran Deep',
#  ' Abhai S. Rao',
#  ' Abhay Singhal',
#  ' Abhijit Bhandari',
#  ' Abhinav Patodia',
#  ' Abhinav Sinha',
#  ' Abhishek Acharya',
#  ' Abhishek Goyal',
#  ' Abhishek Gupta',
#  ' Abhishek Jain',
#  ' Abhishekh Goyal',
#  ' Abstract Ventures',
#  ' Abu Farhan Azmi',
#  ' Accel',
#  ' Accel India',
#  ' Accel Partner',
#  ' Accel Partners',
# ...

# %%
## lakin  abhi bhi promblem 
# ola olalabs Ola company alag alag dika raha jo ki same ha sari
# softbank ka sath bhi yani ha 
# is ma kam ati ha apka Testing team
# users

# %% [markdown]
# - apka testing team software ka thorugh apko nikal kar da
# - apka users apko feedback da
# - machine learning library jo two similar text ko pachan paya

# %% [markdown]
# others technique you use
# - sara investor ka name ko small case ma la kar jayiya
# - unka bitch ka space hata dho
# - us sa apko samaj aa jaya ki ya sab nlp ka domain ki bhat kar raha
# - fuzzy logic laga sakta ha
# - their are many others technique of it

# %% [markdown]
# abhi we are begining so hum itna deep ma nahi ja sakta
# wahi ma bol raha ha ek chota sa project bhi bana na  jaho bhut choti choti cheeza aap usma improve kar sakta ho

# %% [markdown]
# ## find 5 investment

# %%
df['investers'].str.contains(' 91SpringBoard')
df[df['investers'].str.contains(' IDG Ventures')].head()[['date','startup','vertical','city','round','amount']]
# Out:
#             date            startup           vertical       city  \
# Sr No
# 102          NaT            Tripoto       Social Media  New Delhi
# 259   2018-02-05            Bizongo  Consumer Internet     Mumbai
# 310          NaT              POPxo         Technology      Delhi
# 505          NaT             Heckyl         Technology     Mumbai
# 528   2017-05-10  Little Black Book  Consumer Internet  New Delhi
#
#                 round      amount
# Sr No
# 102          Series B   29.628844
# 259    Private Equity  181.500000
# 310    Private Equity   45.375000
# 505    Private Equity   22.275000
# 528    Private Equity    8.250000

# %% [markdown]
# ## biggest investments

# %%
df[df['investers'].str.contains(' IDG Ventures')].groupby('startup')['amount'].sum().sort_values(ascending=False)
# Out:
# startup
# Lenskart                 495.000000
# CureFit                  206.250000
# Bizongo                  181.500000
# Curefit                  123.750000
# Xpressbees               103.125000
# FirstCry.com              82.500000
# POPxo                     70.950000
# \\xc2\\xa0CloudCherry     49.500000
# Sigtuple                  47.850000
# Aasaanjobs                41.250000
# RentMojo                  41.250000
# PlaySimple                33.000000
# Tripoto                   29.628844
# Active.ai                 24.750000
# Heckyl                    22.275000
# Cloudcherry Analytics      8.250000
# Little Black Book          8.250000
# Name: amount, dtype: float64

# %% [markdown]
# ## pie chart on industries

# %%
df[df['investers'].str.contains(' IDG Ventures')].groupby('vertical')['amount'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='amount'>

# %%
import matplotlib.pyplot as plt
vertical_series = df[df['investers'].str.contains(' IDG Ventures')].groupby('vertical')['amount'].sum()
ig1 ,ax1  = plt.subplots()
ax1.pie(labels=vertical_series.index,x = vertical_series.values)
plt.plot()
# Out:
# []

# %% [markdown]
# ## round

# %%
import matplotlib.pyplot as plt
round_series = df[df['investers'].str.contains(' IDG Ventures')].groupby('round')['amount'].sum()
fig2 ,ax2  = plt.subplots()
ax2.pie(labels=round_series.index,x = round_series.values)
plt.plot()
# Out:
# []

# %% [markdown]
# ## city

# %%
import matplotlib.pyplot as plt
round_series = df[df['investers'].str.contains(' IDG Ventures')].groupby('city')['amount'].sum().sort_values(ascending=False)
fig2 ,ax2  = plt.subplots()
ax2.pie(labels=round_series.index,x = round_series.values)
plt.plot()
# Out:
# []

# %% [markdown]
# ## line chart.

# %%
df['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df
# Out:
#             date                       startup                    vertical  \
# Sr No
# 1     2020-09-01                        BYJU’S                      E-Tech
# 2            NaT                        Shuttl              Transportation
# 3     2020-09-01                     Mamaearth                  E-commerce
# 4     2020-02-01  https://www.wealthbucket.in/                     FinTech
# 5     2020-02-01                        Fashor         Fashion and Apparel
# ...          ...                           ...                         ...
# 2869         NaT                        Tracxn  Startup Analytics platform
# 2870         NaT                          Dazo    Mobile Food Ordering app
# 2871         NaT                      Tradelab  Financial Markets Software
# 2872         NaT                        PiQube   Hiring Analytics platform
# 2873         NaT               Travel Triangle   Online Travel Marketplace
#
#                                  subvertical       city  \
# ...

# %%
df[df['investers'].str.contains(' IDG Ventures')].groupby('year')['amount'].sum().plot(kind='line')
# Out:
# <Axes: xlabel='year'>

# %%
year_series = df[df['investers'].str.contains(' IDG Ventures')].groupby('year')['amount'].sum()
fig2 ,ax2  = plt.subplots()
ax2.plot(year_series)
plt.plot()
# Out:
# []

# %% [markdown]
# ## find similar investor
# - you can use ki jin investor ka sector same ha unko ek jaga rak do
# - ya fir aap clustring bhi kar sakta ho use of machine learning
# - their are various ways to solve the promblem

# %% [markdown]
# # General analysis

# %% [markdown]
# ## Cards

# %%
import pandas as pd 
# import the clean dataset
df = pd.read_csv('startup_clean.csv')
df
# Out:
#             date                       startup                    vertical  \
# 0     2020-09-01                        BYJU’S                      E-Tech
# 1            NaN                        Shuttl              Transportation
# 2     2020-09-01                     Mamaearth                  E-commerce
# 3     2020-02-01  https://www.wealthbucket.in/                     FinTech
# 4     2020-02-01                        Fashor         Fashion and Apparel
# ...          ...                           ...                         ...
# 2842         NaN                        Tracxn  Startup Analytics platform
# 2843         NaN                          Dazo    Mobile Food Ordering app
# 2844         NaN                      Tradelab  Financial Markets Software
# 2845         NaN                        PiQube   Hiring Analytics platform
# 2846         NaN               Travel Triangle   Online Travel Marketplace
#
#                                 subvertical       city  \
# ...

# %% [markdown]
# ### total money spent in indian startup ecosystem

# %%
round(df['amount'].sum())
# 3 lakh crore rupess
# Out:
# 301646

# %% [markdown]
# ### sabsa jada paisa kis company ma laga

# %%
df['amount'].max()
# Out:
# np.float64(32175.0)

# %%
df[df['amount'] == 32175]
# Out:
#    date           startup        vertical subvertical       city  \
# 59  NaN  Rapido Bike Taxi  Transportation   Bike Taxi  Bengaluru
#
#              investers     round   amount
# 59  Westbridge Capital  Series B  32175.0

# %%
df.groupby('startup')['amount'].max().sort_values(ascending=False)
# Out:
# startup
# Rapido Bike Taxi    32175.0
# Flipkart            20625.0
# Paytm               11550.0
# Flipkart.com         5775.0
# True North           4950.0
#                      ...
# CarveNiche              0.0
# Printland               0.0
# Plick                   0.0
# ePathsala               0.0
# ZenRadius               0.0
# Name: amount, Length: 2319, dtype: float64

# %%
df.groupby('startup')['amount'].max().sort_values(ascending=False).values[0]
# Out:
# np.float64(32175.0)

# %% [markdown]
# ### avg funding

# %%
round(df.groupby('startup')['amount'].sum().mean())
# Out:
# 130

# %% [markdown]
# ### total funded startup
# lakin humara names jo ha vo repeat ho raha ha tho ya sahi information nahi ha

# %%
df['startup'].nunique()
# Out:
# 2319

# %% [markdown]
# ## moneth on month analysis
# har month ma kitna starup ma funding gay

# %%
df['date'] = pd.to_datetime(df['date'],errors='coerce')

# %%
df['date'].dt.month
# Out:
# 0       9.0
# 1       NaN
# 2       9.0
# 3       2.0
# 4       2.0
#        ...
# 2842    NaN
# 2843    NaN
# 2844    NaN
# 2845    NaN
# 2846    NaN
# Name: date, Length: 2847, dtype: float64

# %%
# make a new month coloumn and yer coloum
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2847 entries, 0 to 2846
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1216 non-null   datetime64[ns]
#  1   startup      2847 non-null   object
#  2   vertical     2847 non-null   object
#  3   subvertical  2096 non-null   object
#  4   city         2847 non-null   object
#  5   investers    2847 non-null   object
#  6   round        2847 non-null   object
#  7   amount       2847 non-null   float64
#  8   month        1216 non-null   float64
#  9   year         1216 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(6)
# memory usage: 222.6+ KB

# %%
df.groupby(by=['year','month'],as_index=False)['startup'].count()
# Out:
#       year  month  startup
# 0   2015.0    1.0       36
# 1   2015.0    2.0       14
# 2   2015.0    3.0       37
# 3   2015.0    4.0       22
# 4   2015.0    5.0       23
# ..     ...    ...      ...
# 57  2019.0   11.0        5
# 58  2019.0   12.0        5
# 59  2020.0    2.0        2
# 60  2020.0    9.0        2
# 61  2020.0   10.0        1
#
# [62 rows x 3 columns]

# %% [markdown]
# ### total number of funding in each month and year

# %%
df.groupby(by=['year','month'],as_index=False)['amount'].sum()
# Out:
#       year  month       amount
# 0   2015.0    1.0  5274.637500
# 1   2015.0    2.0  1567.178250
# 2   2015.0    3.0  1913.298750
# 3   2015.0    4.0  1944.896250
# 4   2015.0    5.0   821.988750
# ..     ...    ...          ...
# 57  2019.0   11.0  1153.350000
# 58  2019.0   12.0  1233.375000
# 59  2020.0    2.0    39.600000
# 60  2020.0    9.0  1801.460595
# 61  2020.0   10.0  1237.500000
#
# [62 rows x 3 columns]
