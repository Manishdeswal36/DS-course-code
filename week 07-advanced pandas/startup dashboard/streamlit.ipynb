# %% [markdown]
# our mission is to make a mini project in streamlit  . where we use some data anlaysis ,pandas ,streamlit

# %% [markdown]
# hum ek dashborad banya ga jisma user click karaga and information ko dek sakta ha company ,investor name  and so on ...

# %% [markdown]
# # What is streamlit
# streamlit is a library jo aap python ma use kar sakta ho .
# `a faster way to built and share data apps`  <br>
# Turn your data scripts into shareable web apps in minutes.
# All in pure Python. No front‑end experience required.

# %% [markdown]
#  hota kiya ha aap as a machine learning enginer or data scientist data ka upar model banan ya koi analysis karna karn hota ha  <br>
#
#
# vo analysis kam ki nahi ha jab tak vo dursa logo ka samna nahi ati .dursa logo sa matlab<br>
#
# apka model koi website ya app ma run karna chaya <br>
# end to end project bana ka matlab ha ki ek taraf aap apna model ya dashborad banta ha fir deploy karta ha website ma uska liya apko frontend ana chaya <br>
# streamlit bitch ma aa kar bolta ha kyu na hum es process ko simply kar deta ha <br>
# aap website bana sakta bina advance frontend knowledge tab bhi chalega apko baas python ma kuch function ko call karna hoga vo apka kam kar dega

# %% [markdown]
# ## Main benefits of streamlit
# hama sirf data analysis and model bana par dhyan dena ha frontend(html,css,javascript) coding sikana ka jararut nahi ha vo aap streamlit sa kar sakta ho  a good looking and working website
# aap apna data analysis,data vis,model ko turant website ma convert kar sakta ha

# %% [markdown]
# ## techanically How streamlit work
# so behind the scenes streamlit frontend ma react use karta ha and backend ma python ko use karta ha
# - apko python ka function ko call karna ha streamlit ma .
# -  streamlit react ko call karaga
# - react html,css,javascript ko website ma display kar dega

# %% [markdown]
# ## flask vs streamlit
# apko flask ma thoda jada mehnat karan padta to make web apps .streamlit usko elimnate kar raha ha tho streamlit is better lakin streamlit ma ek disadvantage apka paas bhut jada option ha frontend ka lakin usko customise karna ka jada tarika nahi ha apko streamlit ka rasta chalna hoga yadi apko khud ka customise web app banan ha tho apko flask ka rasta lena hoga. usko liya thoda web dev and front end sikana hoga

# %% [markdown]
# - aap individual ho tho than suitable ha  streamlit
# - agar aap company ho than flask,djano is suitable

# %% [markdown]
# # streamlit features
# streamlit ma har ek design element ko widget bolta ha

# %% [markdown]
# ## Text utilitiy

# %% [markdown]
# ### make the title

# %%
import streamlit as st

st.title('Startup Dashbaord')

# %% [markdown]
# page ka top par jo hota ha usa title bolta ha
# and us page ka andr cheeza ko section bolta ha
# section ma
# - heading
# - subheading hoti ha

# %% [markdown]
# ### header and subheader

# %%
import streamlit as st

st.title('Startup Dashbaord')
st.header('I am learning streamlit ')
st.subheader('I am very happy and love it ')

# %% [markdown]
# good part about streamlit it's built on react so it auto update or live preview of your code

# %% [markdown]
# ### write
# a very important func apko screen par kuch bhi print karna ha you use write

# %%
import streamlit as st

st.title('Startup Dashbaord')
st.header('I am learning streamlit ')
st.subheader('I am very happy and love it ')
st.write('This is normal text')

# %% [markdown]
# ### markdown
# markdown is similar to html .but easire than html . markdown ki waja sa hum text,link,images add kar pata ha jupyter notebook ma

# %%
import streamlit as st

st.title('Startup Dashbaord')
st.header('I am learning streamlit ')
st.subheader('I am very happy and love it ')

st.write('This is normal text')

st.markdown(''' 
### morning affirmation
1. focus and flow
2. happy and exicted 
3. love the process
            ''')

# %% [markdown]
# ### code
# aap koi blog likh rha aor apko code samjana ha aap koi bhi lanuage ko code lik sakta ho

# %%
import streamlit as st

st.title('Startup Dashbaord')
st.header('I am learning streamlit ')
st.subheader('I am very happy and love it ')

st.write('This is normal text')

st.markdown(''' 
### morning affirmation
1. focus and flow
2. happy and exicted 
3. love the process
            ''')

st.code('''
def some_func(input)
    return input**2
''')

# %% [markdown]
# ### latex
# used by researcher when they publish so they write in latex for writing mathemtaical symbols, formulas,equations

# %%
import streamlit as st

st.title('Startup Dashbaord')
st.header('I am learning streamlit ')
st.subheader('I am very happy and love it ')

st.write('This is normal text')

st.markdown(''' 
### morning affirmation
1. focus and flow
2. happy and exicted 
3. love the process
            ''')

st.code('''
def some_func(input)
    return input**2
''')

st.latex('x^2 +y^2 + 2 = 0')

# %% [markdown]
# ## Display elements

# %% [markdown]
# ### Dataframes
# read and display datafrmae

# %%
import streamlit as st
import pandas as pd 

st.title('Startup Dashbaord')
st.header('I am learning streamlit ')
st.subheader('I am very happy and love it ')

st.write('This is normal text')

st.markdown(''' 
### morning affirmation
1. focus and flow
2. happy and exicted 
3. love the process
            ''')

st.code('''
def some_func(input)
    return input**2
''')

st.latex('x^2 +y^2 + 2 = 0')

df = pd.DataFrame({
    'Name': ['manish','anand','ayush','piyush','aryaveer'],
    'marks': [80,90,85,80,89],
    'package': [10,20,30,40,50]
    
})
st.dataframe(df)

# %% [markdown]
# ### Metrics
# aap chota chota cards bana sakta ha jisma aap cards ko dika sakta ho
# example
# - aaj kitna registration hua
# - kitni sales hui
# - kitna peoples na click kiya

# %%
import streamlit as st
import pandas as pd 

st.title('Startup Dashbaord')
st.header('I am learning streamlit ')
st.subheader('I am very happy and love it ')

st.write('This is normal text')

st.markdown(''' 
### morning affirmation
1. focus and flow
2. happy and exicted 
3. love the process
            ''')

st.code('''
def some_func(input)
    return input**2
''')

st.latex('x^2 +y^2 + 2 = 0')

df = pd.DataFrame({
    'Name': ['manish','anand','ayush','piyush','aryaveer'],
    'marks': [80,90,85,80,89],
    'package': [10,20,30,40,50]
    
})
st.dataframe(df)

st.metric('Reveneue','Rs3lakh','-5%')
st.metric('Reveneue','Rs3lakh','2%')

# %% [markdown]
# ### json

# %%
import streamlit as st
import pandas as pd 

st.title('Startup Dashbaord')
st.header('I am learning streamlit ')
st.subheader('I am very happy and love it ')

st.write('This is normal text')

st.markdown(''' 
### morning affirmation
1. focus and flow
2. happy and exicted 
3. love the process
            ''')

st.code('''
def some_func(input)
    return input**2
''')

st.latex('x^2 +y^2 + 2 = 0')

df = pd.DataFrame({
    'Name': ['manish','anand','ayush','piyush','aryaveer'],
    'marks': [80,90,85,80,89],
    'package': [10,20,30,40,50]
    
})
st.dataframe(df)

st.metric('Reveneue','Rs3lakh','10%')

st.json({
    'Name': ['manish','anand','ayush','piyush','aryaveer'],
    'marks': [80,90,85,80,89],
    'package': [10,20,30,40,50]
    
})

# %% [markdown]
# ## Display media

# %% [markdown]
# ### Images
# you can display the images

# %%
st.image(r"C:\Users\sumit\my_download photos\bhakt parad\bhagawad_geeta_cover.jpeg")

# %% [markdown]
# ### videos

# %%
st.video(r"C:\Users\sumit\My_code_files\manim_code_files\Manim Crash Course\media\videos\first_animation\1080p60\simple_animation.mp4")

# %% [markdown]
# ### audio

# %%
#st.audio()

# %% [markdown]
# ## creating layouts

# %% [markdown]
# ### sidebar
# side menu jissa user navigate karaga webiste ma

# %%
st.sidebar.title('sidebar ka title')

# %% [markdown]
# ### coloumns
# ho kiya rha hum sari cheeza ek ka nicha ek hum chaya tho  2 objects ko side by side bhi dika sakta ha

# %%
col1,col2 = st.columns(2)
with col1:
    st.image(r"C:\Users\sumit\my_download photos\bhakt parad\bhagawad_geeta_cover.jpeg")

with col2:
    st.image(r"C:\Users\sumit\my_download photos\bhakt parad\bhagawad_geeta_cover.jpeg")

# %% [markdown]
# ## Showing status

# %% [markdown]
# ### progress bar
# man lo model training ma time laga raha ha tho hum user ko time dika sakta ha kitna laga ga
# - file upload ma time lagta ha tho aap user ko ya dika sakta ho

# %%
import time
bar = st.progress(0)

for i in range(0,101):
    time.sleep(0.1)
    bar.progress(i)

# %% [markdown]
# ###  error message ,success

# %%
st.error('login failed')

st.success('login success')

# %% [markdown]
# ###  warning info

# %%
st.warning('login chal raha ha')
st.info('login ho gaya')

# %% [markdown]
# ## taking input from user

# %%
email = st.text_input('enter email')
number = st.number_input('enter age')
date = st.date_input('enter registration date')

# %% [markdown]
# ### taking input number

# %% [markdown]
# ### taking input date

# %% [markdown]
# ### buttons -> balons
# clickable buttion
# we make a smalll login in streamlit

# %%
import streamlit as st

email = st.text_input('enter email')
password = st.text_input('enter password')
# usecase of button if clicked do some task 
our_button = st.button('login karo')
# our case buttion check the email and password 
if our_button: # meaning # if buttion is clicked
    if email =='manishdeswal@gmail.com' and password == '1234':
        st.success('login sucesss')
    else:
        st.error('login failured')

# %%
# show celebration ballons 
import streamlit as st

email = st.text_input('enter email')
password = st.text_input('enter password')
gender = st.selectbox('select gender',['male','female','others'])

our_button = st.button('login karo')

# if buttion is clicked
if our_button:
    if email =='manishdeswal@gmail.com' and password == '1234':
        st.success('login sucesss')
        st.balloons()
    else:
        st.error('login failured')

# %% [markdown]
# ### dropdown
# user apna gender select kara ga and we display it

# %%
import streamlit as st

email = st.text_input('enter email')
password = st.text_input('enter password')
gender = st.selectbox('select gender',['male','female','others'])

our_button = st.button('login karo')

# if buttion is clicked
if our_button:
    if email =='manishdeswal@gmail.com' and password == '1234':
        st.success('login sucesss')
        st.balloons()
        st.write(gender)
    else:
        st.error('login failured')

# %% [markdown]
# ### file upload

# %%
import streamlit as st
import pandas as pd
# user upload the csv file and
# apko uska upar kuch analysis karna ha  
# we do pandas describe func on it and display it 
file = st.file_uploader('upload the csv file')
if file is not None:
    df = pd.read_csv(file)
    st.dataframe( df.describe() )

# %% [markdown]
# # Design startup app

# %% [markdown]
# ### load the data

# %%
import pandas as pd
st.sidebar.title('Startup Funding Analysis')

df = pd.read_csv('startup_funding.csv')
st.dataframe(df)

# %% [markdown]
# ### button structure

# %%
import streamlit as st
import pandas as pd

df = pd.read_csv('startup_funding.csv')
st.dataframe(df)

st.sidebar.title('Startup Funding Analysis')

option = st.sidebar.selectbox('Select One',['Overall Analysis','StartUp','Investor'])

if option =='Overall Analysis':
    pass
elif option == 'StartUp':
    pass
elif option == 'Investor':
    pass
else:
    pass

# %% [markdown]
# ### sidebar

# %%
import streamlit as st
import pandas as pd

df = pd.read_csv('startup_funding.csv')
st.dataframe(df)

st.sidebar.title('Startup Funding Analysis')

option = st.sidebar.selectbox('Select One',['Overall Analysis','StartUp','Investor'])

if option =='Overall Analysis':
    st.title('Overall Analysis')
elif option == 'StartUp':
    st.sidebar.selectbox('Select Startup' ,["Byju's",'Ola','flipkart'])
    st.title('StartUp')
#elif option == 'Investor':
else:
    st.sidebar.selectbox('Select Investor' ,['amir adami 1','amir adami 2'])
    st.title('Investor')

# %% [markdown]
# ### add sorted started and investor name

# %%
import streamlit as st
import pandas as pd

df = pd.read_csv('startup_funding.csv')
# cleaning data 
df['Investors Name'].fillna('undisclosed',inplace=True)
st.dataframe(df)

st.sidebar.title('Startup Funding Analysis')

option = st.sidebar.selectbox('Select One',['Overall Analysis','StartUp','Investor'])

if option =='Overall Analysis':
    st.title('Overall Analysis')
elif option == 'StartUp':
    st.sidebar.selectbox('Select Startup' ,sorted(df['Startup Name'].unique().tolist()))
    st.title('StartUp')
#elif option == 'Investor':
else:
    st.sidebar.selectbox('Select Investor' ,sorted(df['Investors Name'].unique().tolist()))
    st.title('Investor')

# %% [markdown]
# ### add buttons
# - find startup details
# - find investor details

# %%
import streamlit as st
import pandas as pd

df = pd.read_csv('startup_funding.csv')
# cleaning data
df['Investors Name'].fillna('undisclosed',inplace=True)

st.dataframe(df)

st.sidebar.title('Startup Funding Analysis')

option = st.sidebar.selectbox('Select One',['Overall Analysis','StartUp','Investor'])

if option =='Overall Analysis':
    st.title('Overall Analysis')
elif option == 'StartUp':
    st.sidebar.selectbox('Select Startup' ,sorted(df['Startup Name'].unique().tolist()))
    st.title('StartUp')
    button_1 = st.sidebar.button('Find Startup details')
elif option == 'Investor':
    st.sidebar.selectbox('Select Investor' ,sorted(df['Investors Name'].unique().tolist()))
    st.title('Investor')
    button_2 = st.sidebar.button('Find Investor details')
else:
    pass

# %%
import streamlit as st
import pandas as pd

st.sidebar.title('Startup Funding Analysis')
df = pd.read_csv('startup_funding.csv')
# cleaning data
df['Investors Name'].fillna('undisclosed',inplace=True)
*

option = st.sidebar.selectbox('Select One',['Overall Analysis','StartUp','Investor'])

if option =='Overall Analysis':
    st.title('Overall Analysis')
elif option == 'StartUp':
    st.sidebar.selectbox('Select Startup' ,sorted(df['Startup Name'].unique().tolist()))
    st.title('StartUp')
    button_1 = st.sidebar.button('Find Startup details')
elif option == 'Investor':
    st.sidebar.selectbox('Select Investor' ,sorted(df['Investors Name'].unique().tolist()))
    st.title('Investor')
    button_2 = st.sidebar.button('Find Investor details')
else:
    pass

# %% [markdown]
# ## clean the data
# use this is now

# %%
mport streamlit as st
import pandas as pd

st.sidebar.title('Startup Funding Analysis')
df = pd.read_csv('startup_clen.csv')

# %% [markdown]
# ## change the coloumn name and sort it

# %%
import streamlit as st
import pandas as pd

st.sidebar.title('Startup Funding Analysis')
df = pd.read_csv('startup_clean.csv')


option = st.sidebar.selectbox('Select One',['Overall Analysis','StartUp','Investor'])

if option =='Overall Analysis':
    st.title('Overall Analysis')
elif option == 'StartUp':
    st.sidebar.selectbox('Select Startup' ,sorted(df['startup'].unique().tolist()))
    st.title('StartUp')
    button_1 = st.sidebar.button('Find Startup details')
elif option == 'Investor':
    st.sidebar.selectbox('Select Investor' ,sorted(set(df['investers'].str.split(',').sum())))
    st.title('Investor')
    button_2 = st.sidebar.button('Find Investor details')
else:
    pass

# %% [markdown]
# # investor section

# %% [markdown]
# ## name of the investor

# %%
import streamlit as st
import pandas as pd

st.sidebar.title('Startup Funding Analysis')
df = pd.read_csv('startup_clean.csv')

def load_investor_details(investor):
    st.title(investor)
    # load the recent 5 investments of the investors
    last5_df = df[df['investers'].str.contains(investor)].head()[['date','startup','vertical','city','round','amount']]
    st.subheader('Most Recent Investments')
    st.dataframe(last5_df)
option = st.sidebar.selectbox('Select One',['Overall Analysis','StartUp','Investor'])

if option =='Overall Analysis':
    st.title('Overall Analysis')
elif option == 'StartUp':
    st.sidebar.selectbox('Select Startup' ,sorted(df['startup'].unique().tolist()))
    st.title('StartUp')
    button_1 = st.sidebar.button('Find Startup details')
elif option == 'Investor':
    selected_invesor = st.sidebar.selectbox('Select Investor' ,sorted(set(df['investers'].str.split(',').sum())))
    st.title('Investor')
    button_2 = st.sidebar.button('Find Investor details')
    if button_2:
        load_investor_details(selected_invesor)

# %% [markdown]
# ## biggest investment

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt 


st.sidebar.title('Startup Funding Analysis')
df = pd.read_csv('startup_clean.csv')

def load_investor_details(investor):
    st.title(investor)
    # load the recent 5 investments of the investors
    last5_df = df[df['investers'].str.contains(investor)].head()[['date','startup','vertical','city','round','amount']]
    st.subheader('Most Recent Investments')
    st.dataframe(last5_df)
    
    
    # biggest inventest 
    big_series = df[df['investers'].str.contains(investor)].groupby('startup')['amount'].sum().sort_values(ascending=False).head()
    st.subheader('Biggest  Investments ')
    #st.dataframe(big_series)
    fig ,ax  = plt.subplots()
    ax.bar(big_series.index,big_series.values)
    
    st.pyplot(fig)
    
option = st.sidebar.selectbox('Select One',['Overall Analysis','StartUp','Investor'])

if option =='Overall Analysis':
    st.title('Overall Analysis')
elif option == 'StartUp':
    st.sidebar.selectbox('Select Startup' ,sorted(df['startup'].unique().tolist()))
    st.title('StartUp')
    button_1 = st.sidebar.button('Find Startup details')
elif option == 'Investor':
    selected_invesor = st.sidebar.selectbox('Select Investor' ,sorted(set(df['investers'].str.split(',').sum())))
    st.title('Investor')
    button_2 = st.sidebar.button('Find Investor details')
    if button_2:
        load_investor_details(selected_invesor)

# %% [markdown]
# ## set page config and page title

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt 


st.sidebar.title('Startup Funding Analysis')
df = pd.read_csv('startup_clean.csv')

def load_investor_details(investor):
    st.title(investor)
    # load the recent 5 investments of the investors
    last5_df = df[df['investers'].str.contains(investor)].head()[['date','startup','vertical','city','round','amount']]
    st.subheader('Most Recent Investments')
    st.dataframe(last5_df)
    
    
    # biggest inventest 
    big_series = df[df['investers'].str.contains(investor)].groupby('startup')['amount'].sum().sort_values(ascending=False).head()
    st.subheader('Biggest  Investments ')
    #st.dataframe(big_series)
    fig ,ax  = plt.subplots()
    ax.bar(big_series.index,big_series.values)
    
    st.pyplot(fig)
    
option = st.sidebar.selectbox('Select One',['Overall Analysis','StartUp','Investor'])

if option =='Overall Analysis':
    st.title('Overall Analysis')
elif option == 'StartUp':
    st.sidebar.selectbox('Select Startup' ,sorted(df['startup'].unique().tolist()))
    st.title('StartUp')
    button_1 = st.sidebar.button('Find Startup details')
elif option == 'Investor':
    selected_invesor = st.sidebar.selectbox('Select Investor' ,sorted(set(df['investers'].str.split(',').sum())))
    st.title('Investor')
    button_2 = st.sidebar.button('Find Investor details')
    if button_2:
        load_investor_details(selected_invesor)

# %% [markdown]
# ## year wise investment

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt 

st.set_page_config(layout = 'wide',page_title='StartUp Analysis')

st.sidebar.title('Startup Funding Analysis')
df = pd.read_csv('startup_clean.csv')
df['date'] = pd.to_datetime(df['date'],errors='coerce')

def load_investor_details(investor):
    st.title(investor)
    # load the recent 5 investments of the investors
    last5_df = df[df['investers'].str.contains(investor)].head()[['date','startup','vertical','city','round','amount']]
    st.subheader('Most Recent Investments')
    st.dataframe(last5_df)
    
    col1,col2 = st.columns(2)
    with col1:
        # biggest inventest 
        big_series = df[df['investers'].str.contains(investor)].groupby('startup')['amount'].sum().sort_values(ascending=False).head()
        st.subheader('Biggest  Investments ')
        #st.dataframe(big_series)
        fig ,ax  = plt.subplots()
        ax.bar(big_series.index,big_series.values)
        
        st.pyplot(fig)
        
    with col2:
        # investvemtns in each sector 
        vertical_series = df[df['investers'].str.contains(investor)].groupby('vertical')['amount'].sum().sort_values(ascending=False)
        st.subheader('Sector Investment')
        # polt the pie chart
        fig1 ,ax1  = plt.subplots()
        ax1.pie(x=vertical_series.values,labels=vertical_series.index,autopct='%0.01f%%')
        
        st.pyplot(fig1)
    
    # year wise investemnt line chart
    df['year'] = df['date'].dt.year
    st.subheader('Year wise Investment')
    # plot the line chart
    
    year_series = df[df['investers'].str.contains(investor)].groupby('year')['amount'].sum()
    fig2 ,ax2  = plt.subplots()
    ax2.plot(year_series.index ,year_series.values)
    st.pyplot(fig2)

option = st.sidebar.selectbox('Select One',['Overall Analysis','StartUp','Investor'])

if option =='Overall Analysis':
    st.title('Overall Analysis')
elif option == 'StartUp':
    st.sidebar.selectbox('Select Startup' ,sorted(df['startup'].unique().tolist()))
    st.title('StartUp')
    button_1 = st.sidebar.button('Find Startup details')
elif option == 'Investor':
    selected_invesor = st.sidebar.selectbox('Select Investor' ,sorted(set(df['investers'].str.split(',').sum())))
    st.title('Investor')
    button_2 = st.sidebar.button('Find Investor details')
    if button_2:
        load_investor_details(selected_invesor)

# %% [markdown]
# ## overalll analysis

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt 

st.set_page_config(layout = 'wide',page_title='StartUp Analysis')

st.sidebar.title('Startup Funding Analysis')
df = pd.read_csv('startup_clean.csv')
df['date'] = pd.to_datetime(df['date'],errors='coerce')

def load_overall_details():
    # total investment money
    total = round(df['amount'].sum())
    # max amount invested in a startup
    max_funding = df.groupby('startup')['amount'].max().sort_values(ascending=False).values[0]
    # avg fundging  invested in a startup
    avg_funding = round(df.groupby('startup')['amount'].sum().mean())
    # total  number of funded startup
    total_startup = df['startup'].nunique()
    
    col1,col2,col3,col4 = st.columns(4)
    col1.metric(label='Total',value=f'{total} Cr.',)
    col2.metric(label='Maximum funding',value=f'{max_funding} Cr.' )
    col3.metric(label='Avg funding',value=f'{avg_funding} Cr.' )
    col4.metric(label='funded startups',value=f'{total_startup} ' )
    


def load_investor_details(investor):
    st.title(investor)
    # load the recent 5 investments of the investors
    last5_df = df[df['investers'].str.contains(investor)].head()[['date','startup','vertical','city','round','amount']]
    st.subheader('Most Recent Investments')
    st.dataframe(last5_df)
    
    col1,col2 = st.columns(2)
    with col1:
        # biggest inventest 
        big_series = df[df['investers'].str.contains(investor)].groupby('startup')['amount'].sum().sort_values(ascending=False).head()
        st.subheader('Biggest  Investments ')
        #st.dataframe(big_series)
        fig ,ax  = plt.subplots()
        ax.bar(big_series.index,big_series.values)
        
        st.pyplot(fig)
        
    with col2:
        # investvemtns in each sector 
        vertical_series = df[df['investers'].str.contains(investor)].groupby('vertical')['amount'].sum().sort_values(ascending=False)
        st.subheader('Sector Investment')
        # polt the pie chart
        fig1 ,ax1  = plt.subplots()
        ax1.pie(x=vertical_series.values,labels=vertical_series.index,autopct='%0.01f%%')
        
        st.pyplot(fig1)
    
    # year wise investemnt line chart
    df['year'] = df['date'].dt.year
    st.subheader('Year wise Investment')
    # plot the line chart
    
    year_series = df[df['investers'].str.contains(investor)].groupby('year')['amount'].sum()
    fig2 ,ax2  = plt.subplots()
    ax2.plot(year_series.index ,year_series.values)
    st.pyplot(fig2)

option = st.sidebar.selectbox('Select One',['Overall Analysis','StartUp','Investor'])

if option =='Overall Analysis':
    st.title('Overall Analysis')
    button_0 = st.sidebar.button('Show overall analysis')
    if button_0:
        load_overall_details()
elif option == 'StartUp':
    st.sidebar.selectbox('Select Startup' ,sorted(df['startup'].unique().tolist()))
    st.title('StartUp')
    button_1 = st.sidebar.button('Find Startup details')
elif option == 'Investor':
    selected_invesor = st.sidebar.selectbox('Select Investor' ,sorted(set(df['investers'].str.split(',').sum())))
    st.title('Investor')
    button_2 = st.sidebar.button('Find Investor details')
    if button_2:
        load_investor_details(selected_invesor)
