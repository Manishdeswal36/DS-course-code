# %%
# So we learn 5 steps in data anlaysis 
# 1. Ask Question 
# 2. Data Wraning  threee stpes
# - Data gathering ,Data assesing ,Data cleaning 
# today we do learn two steps 
# eda and drawing concluions
# Data Presenation (ya koi nahi sika sakta)
# khud apko sikana padeaga

# %%
# today we work on titanic dataset beginners ka liya acha mana jata ha 
# bhut easy bhi nahi bhut difficult bhi nahi ha 
# apko kuch na kuch naya sikana ko jarrur milaga
# bhut hidden chezza ha uska andr

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# tho 891 passengers travel in titanic ship 
# jab jounrey ho raha tha vo dump gaya 
# aor 12 variable ma unki ninofrmation ha
# passenger_id uski 
# surived  = died or not died(survived)
# Pclass hama bata raha ha ki vo konsi class ma travel kar raha tha 1,2,3
# their are 3 classes
# name = name of the person
# sex = gender bata raha ha male or female
# age of the passenger
# Sibsp = siblings = passengers ka sath uska kinta bhai bhen ,pati ya patni travel kar raha tha
# Parch = parent child huma bata raha ha ki current passenger ka sath kitna 
# parents and children travel kar raha tha .
# ticket = like id of the person
# fare = apna kitna money diya ticket kardina ka liya
# Cabin = jasa train ma cabin hota ha vasa hi
# apka passenger kon sa cabhin ma travel kar raha tha
# embarked = aap konsa station sa titianic par chada ho
# their are 3 stations 3 names of cities 
# S =Southampton, England: This was the primary departure point for the Titanic's maiden voyage. 
# C = Cherbourg, France: The ship made a stop here to pick up additional passengers, primarily from France and other parts of Europe. 
# Q = Queenstown (now Cobh), Ireland: The final stop before crossing the Atlantic, where some passengers boarded and mail was collected

# %%
# eda full form exploratory data analysis
# jo apka pass dat ha usko anlysie karna hota ha .
# aor apko gain insight karna hota ha

# %%
# tho 2 ghanta ma eda nahi ho sakta ek dataset par 
# ek dataset ma bhut kuch chuapa hua ha .
# aaj hum apko sochna ka tarika sikaya jayega eda par
# koi bhi data mila uska upar eda kasa kara

# %% [markdown]
# # Why do EDA
#
# - Model building
# - Analysis and reporting
# - Validate assumptions
# - Handling missing values
# - feature engineering
# - detecting outliers

# %% [markdown]
# mera paas ek dataset ha ma us par eda kyu karu
# what is benefit of eda .
# deko data science machine learning ma hota kiya apko ek data par model predication karna hota ha
# deko apka titanic ma ek model banaya
# by providing some input apko batana ha ki passenger mar jaya ga ya bach jaya ga .

# %% [markdown]
# deko jab tak apko ya nahi pata hoga apka data ma kon sa columns ha aor vo kiya kar raha ha  tab tak aap ek acha model nahi bana sakta
# deko jab bhi aap predication (machine learning ) kar raha ho
# us sa phala apko apna data ki understanding honi chaya
# aor vo understanding kaha sa aya ga
# vo aya ga jab aaap apna data ko par anlysis karo ga explore karo ga
# isliya exploratary data analysis
# - you go explore ( expand  gain new information)
# - data (knowldge you gain)
# - analysis . connection of facts you find the similarity and difference you understand how things works

# %% [markdown]
# main reason for doing eda
# aap apna data ka understanding lena chata ho
# so aap better predictive model bana paho

# %%
# jarui nahi apko predication model hi bana ha 
# khai bar esa hi oo sakta ki apko data diya jaya
# iska andr sa information extract kareka do 
# knowldegable points extract karka deko.
# apko ek company ka sales ka data da diya gaya
# apko figure out karna ha humna es saal loss kyu kiya
# aap pura data analysis karo ga aor find karo ga 
# this are the points jisa waja sa aap loss ma gaya
# aap ya koi predicative model nahi bana raha 
# aap analyise kar raha ho to get the insight

# %%
# validate assumption
# our assumption female are more safe Compare to male.
# ya par infertnial statistics hypothesis testing

# %%
# handling missing data
# two solution : remove it or fill it 
# swal ha aap uska andr kiya value ko fill karo ga and kyu?
# deko apka paas students ka data ha kuch students ka marks missing ha
# asa tho nahi aap 0 fill kar do dega 
# issa tho bacha fail ho jayega
# aap mean sa replace kar do 
# lakin kiya ho yadi data ma outliers ho
# you have to think agar value fill karni ha tho shai value konsi hogi
# vo samaj kaha sa ayega jab aap data anlysis karoga

# %%
# machine learning is all about feature enfinering 
# feature yani column yani variable ko study anlyise karna
# kons esa column(variable) ha jo predication ma help karega
# kahi baar hota ha ki
# naya columns create karna padta ha
# existing column ma change karna padta ha
# ya kab karna chya ,kitna karna chaya ,
# kis par karna chaya
# iska understanding bhi tabhi milti ha jab aap eda karta ho

# %%
# deteching outliers
# sharma ji ka beta
# vo bandha jo bakiyo sa sab sa alag ha
# esa data predicative model ka liya bada dangerious hota ha
# statistical test ka liya dangerous hota ha
# isliya aap usa ata dena 
# apko  pata kasa chalega
# aap ke data ma outlier ha 
# simple ha aap ko eda karno hoga

# %%
# ma apko 5 aor reasons da sakta hu
# itna important hota ha eda
# aap data analystics ya data science ki domain ma project ka raha ho
# eda is must.
# ya aap life baar karoga

# %%
# deko very important
# eda is an iteractive process

# %%
# esa nahi hoga 2 ghanta dimag lagya eda  perform kiya 
# kam ho gaya 
# hamesha kiya hota ha aap eda perform karta ho .
# us sa aap kuch results nikal kar lata ho
# un results ka through kuch changes ata ha 
# un changes ki vaja sa aap data ma dubara changes karta ho
# aor data ma change hua tho fir aap eda perform karta ho
# basically it is a circle aap baar baar eda perform karta ho
# eventually you reach a stage  you make conclusion 
# hum 2 baar pura data ma gumega

# %% [markdown]
# # Column Types
#
# - **Numerical** - Age,Fare,PassengerId
# - **Categorical** - Survived, Pclass, Sex, SibSp, Parch,Embarked
# - **Mixed** - Name, Ticket, Cabin

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# step 1 aap apna data ko classify and sttucture karo
# variables numerical ha ki cateogrical,mixed ha 
# labeling your data

# %%
# logic 
# passenger id = nermical kisi kam ki nahi
# sruvived = catergoeical two values 0 and 1 
# pclass = categorical 3 values 1,2,3
# name = ab name numerical tho nahi ha 
# na hi categrical ha kyuki bhut sara names ha category kasa bana gi
# Sex = gender male or female categrical
# Age is number = 0 sa 100 tho numerical
# sibsp, parch = categrical ,
# Ticket = mixed
# cabin = mixed
# Embarked = cateogrical

# %% [markdown]
# # EDA Steps
# 1. classify columns
# 2. univariate
# 3. bivarite
# 4. Multivariate
# 5. feature engerning -> outlier -> missing values

# %%
# clasiffy your variable (columsns)
# fir aap karto ho
# univarite,bivarite,multivarite anlysis
# aap apko apna dataset ma bhara ma bhut achi jankari (understanding ho gai)
# ab karta ho feature engerning -> outlier -> missing values
# ab missing values fill karna ka baad aap dubara apna dataset ma eda karta ho

# %% [markdown]
# Univarite =
# - uni =  one
# - variate = variable

# %% [markdown]
# Univariate

# %% [markdown]
# one variable anlaysis single columns analysis
# Indepedent variable analysis

# %% [markdown]
# # Univariate Analysis
# What you do (focus) on Univarite Anlysis ?
# Univariate analysis focuses on analyzing each variable in the dataset independently.
#
# - **Distribution analysis**: The distribution of each variable is examined to identify its shape, central tendency, and dispersion.
#
# - **Identifying potential issues**: Univariate analysis helps in identifying potential problems with the data such as outliers, skewness, and missing values

# %% [markdown]
# ## Numerical

# %% [markdown]
# #### The shape of a data distribution refers to its overall pattern or form as it is represented on a graph. Some common shapes of data distributions include:
#
# - **Normal Distribution**: A symmetrical and bell-shaped distribution where the mean, median, and mode are equal and the majority of the data falls in the middle of the distribution with gradually decreasing frequencies towards the tails.
#
# - **Skewed Distribution**: A distribution that is not symmetrical, with one tail being longer than the other. It can be either positively skewed (right-skewed) or negatively skewed (left-skewed).
#
# - **Bimodal Distribution**: A distribution with two peaks or modes.
#
# - **Uniform Distribution**: A distribution where all values have an equal chance of occurring.
#
# The shape of the data distribution is important in identifying the presence of outliers, skewness, and the type of statistical tests and models that can be used for further analysis.

# %% [markdown]
# #### **Dispersion** is a statistical term used to describe the spread or variability of a set of data. It measures how far the values in a data set are spread out from the central tendency (mean, median, or mode) of the data.
#
# There are several measures of dispersion, including:
#
# - **Range**: The difference between the largest and smallest values in a data set.
#
# - **Variance**: The average of the squared deviations of each value from the mean of the data set.
#
# - **Standard Deviation**: The square root of the variance. It provides a measure of the spread of the data that is in the same units as the original data.
#
# - **Interquartile range (IQR)**: The range between the first quartile (25th percentile) and the third quartile (75th percentile) of the data.
#
# Dispersion helps to describe the spread of the data, which can help to identify the presence of outliers and skewness in the data.

# %% [markdown]
# ### Steps of doing Univariate Analysis on Numerical columns
#
# - **Descriptive Statistics**: Compute basic summary statistics for the column, such as mean, median, mode, standard deviation, range, and quartiles. These statistics give a general understanding of the distribution of the data and can help identify skewness or outliers.
#
# - **Visualizations**: Create visualizations to explore the distribution of the data. Some common visualizations for numerical data include histograms, box plots, and density plots. These visualizations provide a visual representation of the distribution of the data and can help identify skewness an outliers.
#
# - **Identifying Outliers**: Identify and examine any outliers in the data. Outliers can be identified using visualizations. It is important to determine whether the outliers are due to measurement errors, data entry errors, or legitimate differences in the data, and to decide whether to include or exclude them from the analysis.
#
# - **Skewness**: Check for skewness in the data and consider transforming the data or using robust statistical methods that are less sensitive to skewness, if necessary.
#
# - **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# ### Age
#
# **conclusions**
#
# - Age is normally(almost) distributed
# - 20% of the values are missing
# - There are some outliers

# %%
# outlier detect karna ka bhutch technique ha 
# very important agar outlier ha tho vo kyu ha measurement error,
# data entry , or something else and decide whether of include or exuclde the outliers

# skewness sa data normal nahi rehata aor apka stastical test kharab ho sakta ha .
# thier are various types of transformations in it.

# jab bhi apko kisi variable ka bara ma samaj ata ha you note down it and 
# taki future ma refrence mil jaya
# hum eda isliya kar raha ha taki hum ek acha predication model bana saka 
# ab passenger id is not important numerical column
#  because yadi colleage ma bhukam (earth quake aya ga)
# tho aap roll no wise nahi maroga. iska koi relation nahi ha kuch khas

# %%
# check describe stattics of age column
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# count 714 passengers ka ha
# mean 29 and std 14
# minumium = 0.42 yani bacha sa lakar maximum = 80 (old ages) person bhi ha 
# 25 percent people ka age 20 sa kam ha
# 50 percent people ka age 28 sa kam ha isa median bhi bolta ha
# 75 percent people ka age 30 sa kam ha

# %%
df['Age'].shape
# Out:
# (891,)

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
# tho 177 missing vvalues ha age ma

# %%
sns.histplot(data = df,x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
# deko 0-5 years ka bach bhi trvel kar raha ha
# matlab bhut chota bacha jada travle kar raha ha 
# aor sabsa jada young people travel kar raha ha
# old people ki count kam yani kam travel kar raha ha

# %%
sns.kdeplot(data=df,x='Age',fill=True)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# tho perflectly normally distibution nahi 
# but you approximate it to normal

# %%
# check the skenwness of it
df['Age'].skew()
# tho
# Out:
# 0.38910778230082704

# %%
# -1 = negative = left skew = tail is longer on left mean < median
# 0  = normal disticution = symmetric  = mean = medina 
# 1 = postive = right skew  - tail is longer on right mean > median

# %%
# lets see the dispersion
sns.boxplot(data=df,x='Age')
# Out:
# <Axes: xlabel='Age'>

# %%
# tho 65 ka upar outlier btaya ja raha 
# now lets see write code to anlayise the outlier
# filter out data by condition boolean indexing 
df[df['Age'] > 65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
# kitni maissing values ha
df['Age'].isnull().sum()/len(df['Age'])
# Out:
# 0.19865319865319866

# %%
(df['Age'].isnull().sum()/len(df['Age'])) * 100
# Out:
# 19.865319865319865

# %%
# so 19.8 percent missing values ha
# approx 20 percent missing values ha out of 100
# matlab 5 passenger ha unam sa har 4 ka age pata ha ha 1 ka pata nahi ha
# out of every 5 passenger age value is unknown.

# %% [markdown]
# ### fare

# %%
# now lets do for fare it is 
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
# wow fair ka sara data ha 
# min is 0 and max is 512 people na bhut jada or kam values par ticket liya ha
# mean is 32
# 25 percent people ka fair 7.9 lagabag 8 sa kam ha
# 50 percent people ka fair 14 sa kam ha isa median bhi bolta ha
# 75 percent people ka fair 32 sa kam ha

# %%
# hisotgram dekta ha
sns.histplot(data=df,x='Fare')
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
# ya right skew ha tail is on the right side 
# meaning
# kam paisa dekar jada log travel kar raha ha
# aor bhut kam asa log ha jo jada paisa da kar travel kar raha ha

# %%
sns.kdeplot(data=df,x='Fare',fill=True)
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
# lets check skewness
# direction of outleir 
df['Fare'].skew()
# Out:
# 4.787316519674893

# %%
# it is highly skewed
# matlab aap in par statistical test nahi kar sakta ab .

# %%
# how many outleirs 
df['Fare'].kurtosis()
# Out:
# 33.39814088089868

# %%
# lets check the outliers
sns.boxplot(data=df,x='Fare')
# Out:
# <Axes: xlabel='Fare'>

# %%
# bhut sara outliers ha

# %%
# just to see 200 ka upar kitna outliers ha
df[df['Fare'] > 250]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %%
# deko 311 and 742 fare exactly same ha
# is sa samaj aya fare ma individual values nahi ha 
# example ek family ha 4 member ha tho 20 dollar each 
# lakin total hua 80 dollar tho har kisi kar 80 dollar lika ha 
# fair ma this is the problem . 
# hamra assumption passenger na kitna pay kiya 
#  lakin data dekar huma samaj aa raha ha family na kitna diya 
# total ticket ka liya 
# this is the failure of our assumption
# may be future ma huma feature engerning karna pad sakta ha
# ya grouped fair ha hum individual fair nikalaga

# %%
# check for null values
df['Fare'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Fair conclusions
# - The data is highely righlty skewed
# - failr col actually contains the group fair not the indivual fare (this might be and issuse)
# - We need to create a now column called indivdual fare
# - their is no misssing values

# %% [markdown]
# ## Categorical

# %% [markdown]
# ### Steps of doing Univariate Analysis on Categorical columns
#
# **Descriptive Statistics**: Compute the frequency distribution of the categories in the column. This will give a general understanding of the distribution of the categories and their relative frequencies.
#
# **Visualizations**: Create visualizations to explore the distribution of the categories. Some common visualizations for categorical data include
# count plot and pie chart . bar chart ,pie chart ,ecdf chart
# These visualizations provide a visual representation of the distribution of the categories and can help identify any patterns or anomalies in the data.
#
#
# **Missing Values**: Check for missing values in the data and decide how to handle them. Missing values can be imputed or excluded from the analysis, depending on the research question and the data set.
#
# **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# ### Survived
#
# **conclusions**
#
# - Parch and SibSp cols can be merged to form  a new col call family_size
# - Create a new col called is_alone

# %%
# we ask question is passenger survived
# 1 yes survived not dead
# 0 no  not survived dead

# %%
df['Survived'].value_counts()
# 0 means died
# 1 means survived
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# draw a count plot 
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
# survived columns
sns.countplot(data=df,x='Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# agar apko percenetage dekna ha tho
df['Survived'].value_counts().plot(kind='pie',autopct= '%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# so titanic accident is deadly 
# lagbag 60 percent people died 
# 6 out of 10 every 6 people died .

# %%
# check for missing values
df['Survived'].isnull().sum()
# Out:
# 0

# %% [markdown]
# suvived conculsions
# - 549 people dead 342 survived
# - 60 percent died 40 percent survived
# - no missing values

# %% [markdown]
# ### Pclass

# %%
# pclass ka dekta ha
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
# jasa indian railway ma hota
# general slipper,3ac, 2ac,1ac
# isi their 
# 1st ma bdya 2nd medium 3rd ussa kam

# %%
# sabsa jada people 3 class ma = 491
# genral pattern sabsa cheap ma jada peopl
# fir jada expense ma kam people
# sabsa jada expense ma bhut kam people 
# suprise pattern
# sabsa kam people 2 class ma = 216
# medium  people 1 class ma = 184 
# asa kyu hua jana ka liya ? 2 ma kam 1 ma jada
# har class ka fair compare kara

# %%
# count plot
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
# huma percentage dekan ha har pclass ma  
df['Pclass'].value_counts().plot(kind='pie',autopct= '%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# pclass conculsion
# - most people travel  in pclass 1
# - but surplirsely less people travel in pclasss two and more people travel in  pclass one

# %%
# now curiosity question why people travel more in 1 and less in 2

# %% [markdown]
# ### sex

# %%
# chalo aap gender ko dekta ha 
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# frequency graph ka chart
# mo

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
# percentage ma bhi dekta ha
df['Sex'].value_counts().plot(kind='pie',autopct= '%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# sex conclusion
# - 65 % males and 35 % males population

# %%
# so more males are travel compare to females

# %% [markdown]
# ### sibling

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
# single travel more in number 608
# 1 brother sister ya husband wife wala  209
# 2,3,4,5,8 family ha

# %%
# tho iska frequency plot hoga
df['SibSp'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SibSp'>

# %%
df['SibSp'].value_counts().plot(kind='pie',autopct= '%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### parent child

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
# single people jada 
# 1 bacha 118 2 bacha 80 and so on

# %%
df['Parch'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Parch'>

# %% [markdown]
# Conclusion
# - parent child (parch) and Sibling (SibSp) column can be mergred to form a new column and call it family size
# - create a new col called is_alone

# %% [markdown]
# ### embarked

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct= '%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
## need to do fixture engierning at mixed columns

# %% [markdown]
# # Bivariate

# %% [markdown]
# ### Steps of doing Bivariate Analysis
#
# - Select 2 cols
# - Understand type of relationship
#     1. **Numerical - Numerical**<br>
#         a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots<br>
#         b. Check correlation coefficent to check linear relationship
#     2. **Numerical - Categorical** - create visualizations that compare the distribution of the numerical data across different categories of the categorical data.<br>
#         a. You can plot graphs like barplot, boxplot, kdeplot violinplot even scatterplots<br>
#     3. **Categorical - Categorical**<br>
#         a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.<br>
#         b. You can plots like heatmap, stacked barplots, treemaps
#
# - Write your conclusions

# %% [markdown]
# ## categorical-categorical

# %%
# generally apka paas 11 columns ha 
# unma sa har 2 ka apko bivariate anlysis karna chaya 
# lakin vo karna thoda jada time lega 
# ideally aap apna sabsa ek ya muliple important columsn ko pakda ho
#  uska baki sabhi columns ka sath bivarite anlysis karta ho
# example humar goal ha surival predication model bana 
# two important columns surived and age
# tho aap survived ko har ek column(variable) ka sath bivarite anlysis karog
# age column ma missing values ha tho aap age ko dursa sabhi column ka 
# sath distibution deko ga 
# and fir age ki missing values ko fill karega

# %%
# deko ya tho iterative and mix up approach hota ha
# tho data cleaning kiya fir eda kiya
# eda karna par pata chala data ka kiya kharabi ha fir clean
# the fir sa anlysis kiya

# %% [markdown]
# ### surivied-pclass

# %%
# Question har pclass ma kitna log mar gaya kitn log bach gaya
pd.crosstab(df['Survived'],df['Pclass'])
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
# today learned a new function croostab jo contigency table banta ha
# provide the two columns you want 
# what is row (index) and what ic column  
# shortcut for doing pivot

# %%
df.pivot_table(
    index = 'Survived',
    columns='Pclass',
    values='PassengerId',
    aggfunc='count'
)
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
# how to read it
# pclas 1 ma 80 mar gaya
#           136 bacha gaya
# pclas 2 ma 97 mar gaya
#            87 bacha gaya
# pclas 3 ma 372 mar gaya
#            119  bacha gaya

# %%
# tho pclass 3 ma sabsa jada people mar gaya
# kyuki va log bhi jada tha isliya number jada aa raha
# huma proprtion dekna chaya
# har ek p_class ma kitna percent log mara ha bacha ha

# %%
# tho hum percentage ki baat kara kyuki vo sabko same scale par la gaya
# normalise kar da  
# we use the parameter normalise  aor normlaise karga on the basis of survived jo ki index ha
pd.crosstab(df['Survived'],df['Pclass'],normalize='columns')
# Out:
# Pclass          1         2         3
# Survived
# 0         0.37037  0.527174  0.757637
# 1         0.62963  0.472826  0.242363

# %%
# tho ya 0 sa 1 ka bitch ma ha
pd.crosstab(df['Survived'],df['Pclass'],normalize='columns') * 100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
# now it is a better reprsenation
# pclass 1 ma 37 % mar gaya
# pclass 1 ma 63 % bach gaya

# pclass 2 ma 52 % bach gaya
# pclass 2 ma 47 % bach gaya

# pclass 3 ma 75% bach gaya
# pclass 2 ma 25 % bach gaya

# %%
# ab aya maja anlaysis karka
# now we find insights .

# %%
# you can also plot heatmatp

# %%
sns.heatmap((pd.crosstab(df['Survived'],df['Pclass'],normalize='columns') * 100) )
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
# light shade big percentage darker shade lesss percentage
#  dark matlab pclass 1 ma hight number and pclass 3 ma less number

# %% [markdown]
# Conclusion
# - pclass 3 is the more dangerous class 75 % passenger died
# - pclass 1 is the safest class . 62% passenger survived

# %%
# tho amir pasa wala aadami bach gaya and gareeb class ma mar gaya 
# vo bacha ka process kasa hua

# %% [markdown]
# ### survived and gender

# %%
pd.crosstab(
    index=df['Survived'],
    columns=df['Sex']
)
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
# tho lag raha ha females kam mari ma males jada mara
# lakin kitna
# so percentage nikalta ha same scale par normalise it

# %%
pd.crosstab(
    index=df['Survived'],
    columns=df['Sex'],
    normalize='columns'
) * 100
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
# insterseting pattern
# females 25% mar gayi
# females 75%  bach gayi

# males 81%  mar gayi
# males 19%  bach gayi

# %%
(pd.crosstab(
    index=df['Survived'],
    columns=df['Sex'],
    normalize='columns'
) * 100).plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %% [markdown]
# ### Survival embarked

# %%
# deko ek train ka accident hua 
# ya depend thodi karega ki vo delhi sa chada ya haryana sa

# %%
# deko generally marna ko koi connection nahi hona chaya tha
# vo kaha sa chada ha ship par
# lakin connection ha

# %%
# S =Southampton, England: This was the primary departure point for the Titanic's maiden voyage. 
# C = Cherbourg, France: The ship made a stop here to pick up additional passengers, primarily from France and other parts of Europe. 
# Q = Queenstown (now Cobh), Ireland: The final stop before crossing the Atlantic, where some passengers boarded and mail was collected

# %%
pd.crosstab(df['Survived'],df['Embarked'],normalize='columns') * 100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
# Question C : Cherbourg wala people jada surive kara  Q:Queetons or S : Southhampton ka 
# comparions ma asa kyua hua ?
# assumption answer may be Embakred C ma
# pclasss 1 ka jada travel kar raha ha 
# ya fir usma females jada ha

# %%
# lets check our assumption 
#  gneder(sex) vs Embarked 
pd.crosstab(df['Sex'],df['Embarked'],normalize='columns') * 100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %%
# C : cherobug  ma 43 % female and 56 % male ha 
# tho gender ka tho lagbag same hi ha

# %%
pd.crosstab(df['Pclass'],df['Embarked'],normalize='columns') * 100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %%
# deko ab aya pattern insight 
# 50 percent Pclass 1 passengers   cherobug :england  sa chada ha 
# tho ya aap derivative conclusion nikal sakta ho .

# %% [markdown]
# Conclusion
# - pclass 1 people are more safe (they survived)
# - but p_class1 people are cherobhug
# - so cherobug people are more sage (survived )

# %%
# wow hamana ek story ko connect kiya ha .

# %% [markdown]
# ## categorical - numerical

# %% [markdown]
# ### age -survived

# %%
# tho hum kde plot banya ga  survived and age
# hum dekna chata ha age ka hisab sa survival ka chance kasa baad raha ya gat raha ha

# %%
# filter out data fetch age column than kde

# jo bach gaya 
df[df['Survived'] == 1]['Age'].plot(kind='kde',label = 'Survived')
df[df['Survived'] == 0]['Age'].plot(kind='kde',label = 'Not survived')

plt.legend()
plt.show()

# %%
# this is very good graph and give you insight
# agar aap specific ages pakado
# agar age 0 sa 5 ha tho  Bacho ma  (child ho )
# blue curve is more compare to orange curve 
# survival ka chance jada ha comparion ko marna ka chance sa 
# survive ko probability jada ha comparison to dead ka probability sa

# apko bachaya ja raha ha

# agar aap 10 sa 40 ka bitch ma range ha tho
# marna ka chance ki more compare ko survial ka .
# so not surival ki probability jada ha compare to survive ka 

# 40 sa 60 tak fir apka 
# survial ki probabality jada as compare to not survial 

# fir 60 to 80
# old ages ma apka orange curve agian dominanted 
# tho marna ka probability jada ha comparison to bachna ka .

# %%
# matlab survival predicat karna ka liya age bhut important columns ha .

# %%
# now aap age ko lakar baki columns ka sath comparion kar sakta ho
# aor uski missing values ko fill kar sakta ho.
# konsa columns par age depend kar raha ha.

# %% [markdown]
# ## feature engierning

# %% [markdown]
# ### fair
#
# - Problems: ya groups ka fair bata raha ha
# - solution : ideally ya par individual fair hona chaya

# %%
# yadi family ma 4 person ha per person ha 20 dollar total 80 dollar 
# lakin huma grouped fair 80 dolar dika raha ha

# %%
# Question : how can we create a new column jisma individual fair ho

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
# family 8 loga sath wali deko

df[df['SibSp']== 8]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
# inka name bhi same or ticket number hi same ha or
# fair bhi same

# %%
# 8 sibling ha
# 2 parent child ha 
# or 1 vo self ha 
# total 11 person ho gaya

# %%
# solution fair is divided by sibling and parent child .
65.55/11
# Out:
# 5.959090909090909

# %%
# tho person person fair is 5.95 dollars

# %%
df['Ticket'].nunique()
# Out:
# 681

# %%
df[df['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
# ohh tho 7 person hi ha ticket ma 
# may bhi baki 4 ka paas dursi ticket ha
# so lets check sage family ma kitna member tha

# %%
df[df['Name'].str.contains('Sage')]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 641          642         1       1               Sagesser, Mlle. Emma  female
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#       Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159   NaN      8      2  CA. 2343  69.55   NaN        S
# 180   NaN      8      2  CA. 2343  69.55   NaN        S
# 201   NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
# ya sagessar tho dursa world ha 
# matlab seven people hi ha family ma
# matlab data nahi ha 
# maybe rest of family member in test dataset

# %%
# so lets check in test.csv ma
test_df = pd.read_csv('test.csv')
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
titanic_df = pd.concat((df,test_df))
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df[titanic_df['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160       0.0       3         Sage, Master. Thomas Henry    male
# 180          181       0.0       3       Sage, Miss. Constance Gladys  female
# 201          202       0.0       3                Sage, Mr. Frederick    male
# 324          325       0.0       3           Sage, Mr. George John Jr    male
# 792          793       0.0       3            Sage, Miss. Stella Anna  female
# 846          847       0.0       3           Sage, Mr. Douglas Bullen    male
# 863          864       0.0       3  Sage, Miss. Dorothy Edith "Dolly"  female
# 188         1080       NaN       3                    Sage, Miss. Ada  female
# 342         1234       NaN       3              Sage, Mr. John George    male
# 360         1252       NaN       3        Sage, Master. William Henry    male
# 365         1257       NaN       3     Sage, Mrs. John (Annie Bullen)  female
#
# ...

# %%
# wow ab ya exact 11 people ha 
# sabsa name ma sage 
# sabka ticket name bhi same ha

# %%
titanic_df['Ticket'].value_counts()
# Out:
# Ticket
# CA. 2343        11
# CA 2144          8
# 1601             8
# PC 17608         7
# S.O.C. 14879     7
#                 ..
# 113792           1
# 36209            1
# 323592           1
# 315089           1
# 359309           1
# Name: count, Length: 929, dtype: int64

# %%
titanic_df[titanic_df['Ticket'] == 'CA 2144']
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 59            60       0.0       3       Goodwin, Master. William Frederick
# 71            72       0.0       3               Goodwin, Miss. Lillian Amy
# 386          387       0.0       3          Goodwin, Master. Sidney Leonard
# 480          481       0.0       3           Goodwin, Master. Harold Victor
# 678          679       0.0       3  Goodwin, Mrs. Frederick (Augusta Tyler)
# 683          684       0.0       3              Goodwin, Mr. Charles Edward
# 139         1031       NaN       3           Goodwin, Mr. Charles Frederick
# 140         1032       NaN       3              Goodwin, Miss. Jessie Allis
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 59     male  11.0      5      2  CA 2144  46.9   NaN        S
# 71   female  16.0      5      2  CA 2144  46.9   NaN        S
# 386    male   1.0      5      2  CA 2144  46.9   NaN        S
# ...

# %%
# deko inka bhi fare same ha siblings bhi or name bhi

# %%
# fair ko divide karo karo by sibling and parentchild

# %%
df['Fare']/(df['SibSp'] + df['Parch'] + 1)
# Out:
# 0       3.62500
# 1      35.64165
# 2       7.92500
# 3      26.55000
# 4       8.05000
#          ...
# 886    13.00000
# 887    30.00000
# 888     5.86250
# 889    30.00000
# 890     7.75000
# Length: 891, dtype: float64

# %%
df['individual_fare'] = df['Fare']/(df['SibSp'] + df['Parch'] + 1)

# %%
df['individual_fare'].describe()
# Out:
# count    891.000000
# mean      19.916375
# std       35.841257
# min        0.000000
# 25%        7.250000
# 50%        8.300000
# 75%       23.666667
# max      512.329200
# Name: individual_fare, dtype: float64

# %%
sns.histplot(data=df,x=df['individual_fare'])
# Out:
# <Axes: xlabel='individual_fare', ylabel='Count'>

# %%
# now lets compare befor and after both
df[[ 'individual_fare','Fare']].describe()
# Out:
#        individual_fare        Fare
# count       891.000000  891.000000
# mean         19.916375   32.204208
# std          35.841257   49.693429
# min           0.000000    0.000000
# 25%           7.250000    7.910400
# 50%           8.300000   14.454200
# 75%          23.666667   31.000000
# max         512.329200  512.329200

# %%
# mean kafi nicha aa gaya 32 sa 19 ho gaya
# std bhi 49 sa 35 
# 25 percentile lagbag braber
# aor median bhi nicha aa gaya kam ho gya 7.9 to 7.25
# 75 thoda kam hua
# sach ek person ha jinsa 512 dollars diya ha

# %%
df[[ 'individual_fare','Fare']].plot(kind = 'box')
# Out:
# <Axes: >

# %%
# thoda difference aya ha baas

# %% [markdown]
# ### family size
# it is combintaion of sibling parent and self

# %%
df['family_size'] = df['SibSp'] + df['Parch'] + 1

# %%
df['family_size']
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 886    1
# 887    1
# 888    4
# 889    1
# 890    1
# Name: family_size, Length: 891, dtype: int64

# %% [markdown]
# ### family type
# so we know family size usko upar ham family ka classification type banya ga  alone,small or large family
# - family size = 1  alone
# - family size = 2 sa 4 small family
# - family size = 5+ large family

# %%
def transform_family_size(number):
    if number == 1:
        return 'alone'
    elif number > 1 and number < 5: # greator than 2 or equal to 2 less than 5 
        return 'small_family'
    else:
        return 'large_family'

# %%
df['family_type'] = df['family_size'].apply(transform_family_size)

# %%
df['family_type']
# Out:
# 0      small_family
# 1      small_family
# 2             alone
# 3      small_family
# 4             alone
#            ...
# 886           alone
# 887           alone
# 888    small_family
# 889           alone
# 890           alone
# Name: family_type, Length: 891, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# now aap en naya columns par eda kar sakta hoa
# univariate bhi bivarite bhi 
# chalo hum bivarite karta ha

# %%
pd.crosstab(df['Survived'],df['family_type'],normalize='columns') * 100
# Out:
# family_type      alone  large_family  small_family
# Survived
# 0            69.646182     83.870968     42.123288
# 1            30.353818     16.129032     57.876712

# %%
# agar aap titanic ma alone ho
# marna ka chance 70 % and 30 % survival
# agar apki large ha tho tab aor  jada khartnak
# mara ka chance 83 % and survival ka 16 %
# but intersting pattern 
# small_family 2 sa 4 ha tho
# survival chance is 57% and 42% chance marna ka
# very good insights and conclusion

# %% [markdown]
# ### surname

# %%
# surname of name columns

# %%
df['surname'] = df['Name'].str.split(',').str.get(0)

# %%
# ham surname ka use kar sakta ha family ko analyise karna ka liya

# %%
df['surname'].value_counts()
# Out:
# surname
# Andersson    9
# Sage         7
# Panula       6
# Skoog        6
# Carter       6
#             ..
# Hanna        1
# Lewy         1
# Mineff       1
# Haas         1
# Dooley       1
# Name: count, Length: 667, dtype: int64

# %% [markdown]
# ### title

# %%
# mr and ms nikalta ha

# %%
df['title'] = df['Name'].str.split(',').str.get(1).str.strip().str.split(' ').str.get(0)

# %%
df['title']
# Out:
# 0        Mr.
# 1       Mrs.
# 2      Miss.
# 3       Mrs.
# 4        Mr.
#        ...
# 886     Rev.
# 887    Miss.
# 888    Miss.
# 889      Mr.
# 890      Mr.
# Name: title, Length: 891, dtype: object

# %%
df['title'].value_counts()
# Out:
# title
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Mlle.          2
# Major.         2
# Col.           2
# the            1
# Capt.          1
# Ms.            1
# Sir.           1
# Lady.          1
# Mme.           1
# Don.           1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
df['title'].value_counts().index
# Out:
# Index(['Mr.', 'Miss.', 'Mrs.', 'Master.', 'Dr.', 'Rev.', 'Mlle.', 'Major.',
#        'Col.', 'the', 'Capt.', 'Ms.', 'Sir.', 'Lady.', 'Mme.', 'Don.',
#        'Jonkheer.'],
#       dtype='object', name='title')

# %%
import pandas as pd
import re

# Define the function to extract and classify titles
def extract_and_replace_title(name):
    # Extract the title using regex
    title_search = re.search(r'\b(\w+\.)', name)
    if title_search:
        title = title_search.group(1)
    else:
        title = ''
    
    # Map titles to main classification words
    title_map = {
        'Mr.': 'Mr',
        'Miss.': 'Miss',
        'Mrs.': 'Mrs',
        'Master.': 'Master',
        'Dr.': 'Dr',
        'Rev.': 'Rev',
        'Mlle.': 'Miss',
        'Major.': 'Officer',
        'Col.': 'Officer',
        'the': 'Royalty',
        'Capt.': 'Officer',
        'Ms.': 'Miss',
        'Sir.': 'Royalty',
        'Lady.': 'Royalty',
        'Mme.': 'Mrs',
        'Don.': 'Royalty',
        'Jonkheer.': 'Royalty'
    }
    
    return title_map.get(title, 'Other')

# Example usage with your Titanic dataframe
# df = pd.read_csv('titanic.csv')  # Uncomment and use your actual data
df['Title'] = df['Name'].apply(extract_and_replace_title)

# %%
df['title'] = df['title'].str.replace('Dr.','others')
df['title'] = df['title'].str.replace('Rev.','others')
df['title'] = df['title'].str.replace('Major.','others')
df['title'] = df['title'].str.replace('Col.','others')
df['title'] = df['title'].str.replace('Capt.','others')
df['title'] = df['title'].str.replace('the','others')
df['title'] = df['title'].str.replace('Jonkheer.','others')

# %%
df['title'].value_counts()
# Out:
# title
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# oothersrs     18
# Mlle.          2
# others         2
# Don.           1
# Mme.           1
# Ms.            1
# Lady.          1
# Sir.           1
# Name: count, dtype: int64

# %%
# ya sab karna ka hamara par 5 cateogry . ho jaya gayi .

# %%
df['Title'].value_counts()
# Out:
# Title
# Mr         517
# Miss       185
# Mrs        126
# Master      40
# Dr           7
# Rev          6
# Officer      5
# Royalty      4
# Other        1
# Name: count, dtype: int64

# %%
pd.crosstab(df['Survived'],df['Title'],normalize='columns') * 100
# Out:
# Title            Dr  Master      Miss         Mr        Mrs  Officer  Other  \
# Survived
# 0         57.142857    42.5  29.72973  84.332689  20.634921     60.0    0.0
# 1         42.857143    57.5  70.27027  15.667311  79.365079     40.0  100.0
#
# Title       Rev  Royalty
# Survived
# 0         100.0     50.0
# 1           0.0     50.0

# %%
# wow title sa ham survival ka predication help kar sakta ha

# %% [markdown]
# ### cabin

# %%
df['Cabin'].isnull().sum()
# Out:
# 687

# %%
df['Cabin'].isnull().sum()/len(df['Cabin'])
# Out:
# 0.7710437710437711

# %%
# deko isma 77 percent missing values tho log is column ko drop kar deta 
# lakin isma ek hidden information ha

# %%
# deko aap titanic ka wikipedia par jaho
# aap dimesnsion and layout par 
# alag alag deck ka information ha .

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
# ya deck ka information ha 
# deck sa apki location kiya ha ship 
# accident hua aor apki location sa survival 
# bhut bada conection ha .

# %%
df['Cabin'].fillna('M')
# Out:
# 0         M
# 1       C85
# 2         M
# 3      C123
# 4         M
#        ...
# 886       M
# 887     B42
# 888       M
# 889    C148
# 890       M
# Name: Cabin, Length: 891, dtype: object

# %%
# create a new column deck
df['deck'] = df['Cabin'].str[0]

# %%
# without missing values

# %%
df['deck'].value_counts()
# Out:
# deck
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# T     1
# Name: count, dtype: int64

# %%
df['deck'].fillna('M',inplace = True)
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_11436\2162439334.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['deck'].fillna('M',inplace = True)

# %%
df['deck'].value_counts()
# Out:
# deck
# M    687
# C     59
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# T      1
# Name: count, dtype: int64

# %%
pd.crosstab(df['deck'],df['Pclass'])
# Out:
# Pclass   1    2    3
# deck
# A       15    0    0
# B       47    0    0
# C       59    0    0
# D       29    4    0
# E       25    4    3
# F        0    8    5
# G        0    0    4
# M       40  168  479
# T        1    0    0

# %%
# A deck ma 15 pclass 1 ka ha

# %%
# do very instersting and important thing
# location and survival graph
pd.crosstab(df['Survived'],df['deck'],normalize='columns') * 100
# Out:
# deck              A          B          C          D     E          F     G  \
# Survived
# 0         53.333333  25.531915  40.677966  24.242424  25.0  38.461538  50.0
# 1         46.666667  74.468085  59.322034  75.757576  75.0  61.538462  50.0
#
# deck              M      T
# Survived
# 0         70.014556  100.0
# 1         29.985444    0.0

# %%
round(pd.crosstab(df['deck'],df['Survived'],normalize='index') * 100)
# Out:
# Survived      0     1
# deck
# A          53.0  47.0
# B          26.0  74.0
# C          41.0  59.0
# D          24.0  76.0
# E          25.0  75.0
# F          38.0  62.0
# G          50.0  50.0
# M          70.0  30.0
# T         100.0   0.0

# %%
pd.crosstab(df['deck'],df['Survived'],normalize='index').plot(kind='bar',stacked = True)
# Out:
# <Axes: xlabel='deck'>

# %%
# deko alag alg decks ki waja sa survival ka probability change ho raha ha
# alag alag distibution ha har deck ma

# %%
# A,B,C ko mila kar ek category 
# D ,E ko mila  mila kar ek cateogry
# aor deck ka information aap apna model ko da sakta ho .

# %%
# deko aap eyes close karka 19 centuary ma ja chuka ho 
# aor titanic ka evenet dek raha ho 
# breiallnt idea . 
# data is story telling . 
# aap data ka through vislualisze kar sakta ho 
# every row ,column tells you a event story .

# %% [markdown]
# # multivativarite anlysis

# %%
# agar ek coloumn ka sath dursa ka sath correlation 
# ya ha corrrelation cofficient dekna chata

# %%
df.corr(numeric_only=True)
# Out:
#                  PassengerId  Survived    Pclass       Age     SibSp  \
# PassengerId         1.000000 -0.005007 -0.035144  0.036847 -0.057527
# Survived           -0.005007  1.000000 -0.338481 -0.077221 -0.035322
# Pclass             -0.035144 -0.338481  1.000000 -0.369226  0.083081
# Age                 0.036847 -0.077221 -0.369226  1.000000 -0.308247
# SibSp              -0.057527 -0.035322  0.083081 -0.308247  1.000000
# Parch              -0.001652  0.081629  0.018443 -0.189119  0.414838
# Fare                0.012658  0.257307 -0.549500  0.096067  0.159651
# individual_fare     0.026303  0.221600 -0.485079  0.150763 -0.094682
# family_size        -0.040143  0.016639  0.065997 -0.301914  0.890712
#
#                     Parch      Fare  individual_fare  family_size
# PassengerId     -0.001652  0.012658         0.026303    -0.040143
# Survived         0.081629  0.257307         0.221600     0.016639
# Pclass           0.018443 -0.549500        -0.485079     0.065997
# ...

# %%
# konsa variable (columns) ma kasa correlation 
# postive ,negative 
# agar two variable jada correlated ha tho
# aap ek variable ko ek ma raka ho

# %%
# lakin hamra main prediation column ha surivied
df.corr(numeric_only=True)['Survived']
# Out:
# PassengerId       -0.005007
# Survived           1.000000
# Pclass            -0.338481
# Age               -0.077221
# SibSp             -0.035322
# Parch              0.081629
# Fare               0.257307
# individual_fare    0.221600
# family_size        0.016639
# Name: Survived, dtype: float64

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
# seaborn pariplot ,jointplot ,bubbleplot ,hue ,size lagan ya multivarible anlysis hota ha

# %%
# eda is a pratical thing . not much theory things
# you learn by example ,application ,usecase of it 
# not learn by reading theory ,definitions,
