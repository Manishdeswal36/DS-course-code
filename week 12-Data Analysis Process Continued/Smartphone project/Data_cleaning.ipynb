# %% [markdown]
# Question : How To gain Domain knowlege <br>
# Answer : Spent time in the domain ,read and study about particular domain . The more project you make in a domain better you understand the domain .

# %% [markdown]
#  That why when people switch job they prefer in same domain . Example : A person working in swiggy (foodtech) he gets two offers of job from zomato or amazon . he prefer zomatao . he work in same domain . so industry ma uska demand ha

# %% [markdown]
# deko ai tools are coming . lakin domain knowldage person shield bana kar raka ha , kyuki ai tool ko uska domain level ka inution ya experience nahi hoga.

# %% [markdown]
# actionable advice : koi ek cheez pakad kar uska upar kam karo you gain domain knowldge .

# %% [markdown]
# ma apna deka thu muja ek sa jada domain knowldge ma interset ha .
# ya it is possible that you have knowldge of two or many domain combination ho.

# %% [markdown]
# # Project Roadmmap
# 1. we scrape a website about smartphone data
# 2. We clean the data
# 3. We do analysises on it.
# 4. we make a dashboard in streamlit

# %% [markdown]
# you also extend the idea make smartphone price predicator app

# %% [markdown]
# We use the same smartphone data which we scrape using the selnium last class

# %% [markdown]
# ## Today Task
# Our today task is that we clean the data we scrape from the samrtprix website .

# %%
import numpy as np
import pandas as pd

# %%
smartphone = pd.read_csv('smartphones.csv')
smartphone
# Out:
#                                 model    price  rating  \
# 0                       OnePlus 11 5G  ₹54,999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2               Samsung Galaxy A14 5G  ₹16,499    75.0
# 3                Motorola Moto G62 5G  ₹14,999    81.0
# 4                  Realme 10 Pro Plus  ₹24,999    82.0
# ...                               ...      ...     ...
# 1015       Motorola Moto Edge S30 Pro  ₹34,990    83.0
# 1016                      Honor X8 5G  ₹14,990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  ₹28,990    85.0
# 1018             Motorola Moto G91 5G  ₹19,990    80.0
# 1019           Samsung Galaxy M52s 5G  ₹24,990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %% [markdown]
# so sir na phala hi manual assesment kar diya ha .
# hum usko dekan ha

# %% [markdown]
# ## Data Assessing
#
# ### Quality Issues
#
# 1. **model** - some brands are written diiferently like OPPO in model column `consistency`
# 2. **price** - has unneccesary '₹' `validity`
# 3. **price** - has ',' between numbers `validity`
# 4. **price** - phone Namotel has a price of 99 `accuracy`
# 5. **ratings** - missing values `completeness`
# 6. **processor** - has some incorrect values for some samsung phones(row # -642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002) `validity`
# 7. There is ipod on row 756 `validity`
# 8. **memory** - incorrect values in rows (441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002) `validity`
# 9. **battery** - incorrect values in rows(113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002) `validity`
# 10. **display** - sometimes frequency is not available `completeness`
# 11. **display** - incorrect values in rows(378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002) `validity`
# 12. certain phones are foldable and the info is scattered `validity`
# 13. **camera** - words like Dual, Triple and Quad are used to represent number of cameras and front and rear cameras are separated by '&'
# 14. **camera** - problem with rows (100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016
# ) `validity`
# 15. **card** - sometimes contains info about os and camera `validity`
# 16. **os** - sometimes contains info about bluetooth and fm radio `validity`
# 17. **os** - issue with rows (324,378) `validity`
# 18. **os** - sometimes contains os version name like lollipop `consistency`
# 19. missing values in camera, card and os `completeness`
# 20. datatype  of price and rating is incorrect `validity`
#
#
#
# ### Tidiness Issues
#
# 1. **sim** - can be split into 3 cols has_5g, has_NFC, has_IR_Blaster
# 2. **ram** - can be split into 2 cols RAM and ROM
# 3. **processor** - can be split into processor name, cores and cpu speed.
# 4. **battery** - can be split into battery capacity, fast_charging_available
# 5. **display** - can be split into size, resolution_width, resolution_height and frequency
# 6. **camera** - can be split into front and rear camera
# 7. **card** - can be split into supported, extended_upto

# %% [markdown]
# sir na 2 hour tak manual assement ki fir uska baad points lika . example vo

# %% [markdown]
# Explanation about it quality issue in our dataset.
# - deko kahi par Oppo lika ha aor kahi par OPPO lika ha ya ha data ma consistency issue kahi par capital letter ma ha kahi par small letters ma lika ha tho
# - ruppes coloumn ma price ka symbol ha jo uncessary ha and bitch ma vo comma sa separated bhi ha.
# - namophone 99 rupeees ka ya anomoly ha kyuki phones 99 rupess ma nahi ata . (may be scam)
# - some values are missing in rating columns
# - some rows numbers have quality issue in processor
# - hamra paas ek ipod ha usko hum remove karega.
# - deko hamena webscraping kiya tho thoda shifting ho gaya ha usa bhi thik karna ha. (shifting ki waja sa thoda hamara unclean data ha)
# - operting system ma fm radio or bluetooth ha
# - operaing system ma kahi jaga android version ka name ha tho kahi jaga uska os ka name ha .

# %% [markdown]
# structure issue in our dataset
# - sim vard coloum ko 3 alag column ma split karo dual sim , har ek phone ki lagbam dual sim kuch 10 phone hoga baas single sim wala 3G sabhi phones ma 4G bhi phones ma ha 5G har phone ma nahi ha tho ya differenting factor ha. NFC Thoda premeir phones ma hota ha.  aor IR blaster china ka phones ma hota ha
# - processor sa bhi 3 information
#     - name of the processor
#     - kitna core ka process ha dual,hecta
#     - frequency ya speed kitna ha processor ka
# - ram ka hum coloumns ram and rom
# - batter sa bhi 2 columns banta sakta
# - displays sa bhi screen and refresh rate
# - camera ha front and back
# - card kuch khas nahi baas memory card ha ki nahi ha tho kitna gb ka ha.
# - operating system konsa ha and konsa version ha
# - scren divide ko kareka pixes sa pixel by inch vo bhi bhut acha feature ho sakta ha .
# - agar aap chaho tho aap koi aor acha columns (variable bhi bana sakta ho.)

# %% [markdown]
# NFC = Near field communication (jo thoda premium phones ma hota ha . )
# ya wirelss type of communication jo thoda premium phones ma hota ha.
# By just Tab . you do payements.

# %% [markdown]
# feature engering  meaning you do analysis you think you make more columns out of it.
# - feature means columns (variable)
# - engineering means creating new columns

# %% [markdown]
# In today you do iterative process
# thoda assesment fir thoda cleaning , fir assesment fir cleaning .

# %% [markdown]
# ## programmetic cleaning

# %%
# deko head tail karna ki jarraut nahi haman data dek liya
# sample  bhi humana data dek liya.

# %%
smartphone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
# rating ma missing values hamana already bo lik diya ha . 
smartphone.isnull().sum()
# Out:
# model          0
# price          0
# rating       141
# sim            0
# processor      0
# ram            0
# battery        0
# display        0
# camera         1
# card           7
# os            17
# dtype: int64

# %%
smartphone.describe()
# apko kuch khas ya par nahi milega .
# Out:
#            rating
# count  879.000000
# mean    78.258248
# std      7.402854
# min     60.000000
# 25%     74.000000
# 50%     80.000000
# 75%     84.000000
# max     89.000000

# %%
smartphone.duplicated().sum()
# Out:
# 0

# %%
# deko phala aap basic level cleaning karo and fir aap
# uska upar programmetic assessment karo
# deko yadi chota data ha tho tho aap manual assesment karo
# you feel more powerful with it. 
# lakin yadi big data ha tho do programmetic assessment .

# %% [markdown]
# # Do cleaning

# %%
# know ths solution stucture 
# lakin tho aaj hu completness nahi validiy issue sa saruhat karega . 
# kyuki jada values nahi ha hamara paas

# %% [markdown]
# ## make copy

# %%
df = smartphone.copy()
df
# Out:
#                                 model    price  rating  \
# 0                       OnePlus 11 5G  ₹54,999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2               Samsung Galaxy A14 5G  ₹16,499    75.0
# 3                Motorola Moto G62 5G  ₹14,999    81.0
# 4                  Realme 10 Pro Plus  ₹24,999    82.0
# ...                               ...      ...     ...
# 1015       Motorola Moto Edge S30 Pro  ₹34,990    83.0
# 1016                      Honor X8 5G  ₹14,990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  ₹28,990    85.0
# 1018             Motorola Moto G91 5G  ₹19,990    80.0
# 1019           Samsung Galaxy M52s 5G  ₹24,990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %% [markdown]
# ## price
# lets start with price coloumn  it have 3 columns
# - rupees symbol
# - comma in between
# - datatype string ha usko integer karo

# %%
# ja bhi ruppes symbol deka usko replace karo empty space sa

# %%
df['price'].str.replace('₹','')
# Out:
# 0       54,999
# 1       19,989
# 2       16,499
# 3       14,999
# 4       24,999
#          ...
# 1015    34,990
# 1016    14,990
# 1017    28,990
# 1018    19,990
# 1019    24,990
# Name: price, Length: 1020, dtype: object

# %%
# fir aap all the commas ko empty space yani nothingless sa replace karo
df['price'].str.replace('₹','').str.replace(',','')
# Out:
# 0       54999
# 1       19989
# 2       16499
# 3       14999
# 4       24999
#         ...
# 1015    34990
# 1016    14990
# 1017    28990
# 1018    19990
# 1019    24990
# Name: price, Length: 1020, dtype: object

# %%
# ab iska dattype ko integer karna hoga
df['price'].str.replace('₹','').str.replace(',','').astype(np.int64)
# Out:
# 0       54999
# 1       19989
# 2       16499
# 3       14999
# 4       24999
#         ...
# 1015    34990
# 1016    14990
# 1017    28990
# 1018    19990
# 1019    24990
# Name: price, Length: 1020, dtype: int64

# %%
# make permanet change in the coloumns 
df['price'] = df['price'].str.replace('₹','').str.replace(',','').astype(np.int64)

# %%
df['price']
# Out:
# 0       54999
# 1       19989
# 2       16499
# 3       14999
# 4       24999
#         ...
# 1015    34990
# 1016    14990
# 1017    28990
# 1018    19990
# 1019    24990
# Name: price, Length: 1020, dtype: int64

# %%
# wow we solve all the problems in it.

# %%
# deko rating ma missing values ha hum usko knn immunator valyes sa fill
# kar sakta ha . 
# we do in later

# %% [markdown]
# ## sim

# %%
df['sim']
# Out:
# 0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#                               ...
# 1015                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# Name: sim, Length: 1020, dtype: object

# %%
# hamena mehnat karka rows khoja jinma 
# hum us row ko variable ma dal raha ha 
# like processor 
# hamana google sheet ma jo deko vo 2 index tha
# aor pandas ma 2 index hum picha tha isliya unko same kiya

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index                            model  price  rating  \
# 0         0                    OnePlus 11 5G  54999    89.0
# 1         1        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         2            Samsung Galaxy A14 5G  16499    75.0
# 3         3             Motorola Moto G62 5G  14999    81.0
# 4         4               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1015       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1016                      Honor X8 5G  14990    75.0
# 1017   1017  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1018             Motorola Moto G91 5G  19990    80.0
# 1019   1019           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
df['index'] = df['index'] + 2

# %%
df
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
# jin coloumns ma problem hui unka ek alag dataframe ma daleta ha

# %%
processor_rows = set((642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002))
ram_rows = set((441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002))
battery_rows = set((113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002))
display_rows = set((378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002))
camera_rows = set((100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016 ))

# %%
# take union of all 
union_all = processor_rows | ram_rows | battery_rows | display_rows | camera_rows
print(union_all)
# Out:
# {273, 534, 792, 553, 819, 308, 309, 571, 572, 575, 323, 324, 584, 846, 854, 855, 858, 859, 610, 100, 613, 615, 365, 367, 113, 883, 884, 630, 378, 896, 642, 647, 649, 394, 659, 915, 916, 919, 151, 667, 157, 927, 929, 161, 932, 684, 687, 945, 441, 956, 701, 705, 450, 711, 723, 728, 990, 995, 484, 485, 1002, 750, 238, 756, 759, 1016, 506, 764}

# %%
# why we take set . because set data stucture 
# is collection of all unique elments

# %%
# this is all problematic rows

# %%
df[df['index'].isin(union_all)]
# Out:
#       index                              model   price  rating  \
# 98      100                     Vivo X Fold 5G  106990     NaN
# 111     113                    Apple iPhone 12   51999    74.0
# 149     151               Apple iPhone 12 Mini   40999    74.0
# 155     157                    Nokia 2780 Flip    4990     NaN
# 159     161                    Oppo Find N2 5G   94990     NaN
# ...     ...                                ...     ...     ...
# 954     956  Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 988     990                Nokia 5310 Dual Sim    3399     NaN
# 993     995                      Huawei Mate X  169000     NaN
# 1000   1002                    XTouch F40 Flip    1999     NaN
# 1014   1016                      Vivo X Fold 2  119990     NaN
#
#                                                     sim  \
# 98              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 111             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
# so out of 1020 rows we have 68 probabalic rows 
# jisma kisi ek atleast row ma problem ha.

# %%
# take union of all 
intersection_all = processor_rows & ram_rows & battery_rows & display_rows & camera_rows
print(intersection_all)
# Out:
# {929, 642, 932, 647, 649, 1002, 750, 659, 819, 884, 759, 667, 927}

# %%
df[df['index'].isin(intersection_all)]
# Out:
#       index                   model  price  rating  \
# 640     642          Nokia 105 Plus   1299     NaN
# 645     647         Nokia 2760 Flip   5490     NaN
# 647     649       Motorola Moto A10   1339     NaN
# 657     659           Zanco Tiny T1   2799     NaN
# 665     667            itel it2163S    958     NaN
# 748     750            Nokia 400 4G   3290     NaN
# 757     759            Karbonn KU3i    995     NaN
# 817     819            itel Magic X   2239     NaN
# 882     884  Nokia 5710 XpressAudio   4799     NaN
# 925     927           Nokia 3310 4G   3999     NaN
# 927     929      Samsung Guru E1200   1685     NaN
# 930     932        iKall K88 Pro 4G   2099     NaN
# 1000   1002         XTouch F40 Flip   1999     NaN
#
#                                  sim                   processor  \
# 640                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 645          Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# ...

# %%
# deko ya 13 rows almost every 4 coloumns have some problem 
# yahi vo columns ha jisma shifting hui ha .

# %%
# inka mean price nikala 
df[df['index'].isin(intersection_all)]['price'].mean()
# Out:
# 2537.6923076923076

# %%
# we notice ya problems un phones ma ha jinka price point bhut kam ha .

# %%
# tho average price inka ha 2500 ruppess
# 2500 ka phone milta ha market ma 
# ya sara keyboard phone ha

# %%
# lakin hum analysis kar raha ha smartphone data par tho 
# ham en keyboard  phones ko drop kar dega .

# %%
# so 3400 thousand ka nicha smartphone nahi ha .

# %%
df = df[df['price'] > 3400]

# %%
df
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
# deko en 991 phones  keybaord phones ho sakta ha
# lakin smarphone ka sara phone 3400 ka upar hi ata ha

# %%
df[df['index'].isin(intersection_all)]
# Out:
#      index                   model  price  rating  \
# 645    647         Nokia 2760 Flip   5490     NaN
# 882    884  Nokia 5710 XpressAudio   4799     NaN
# 925    927           Nokia 3310 4G   3999     NaN
#
#                                 sim                   processor  \
# 645         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 882                Dual Sim, 3G, 4G                     No Wifi
# 925  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery  \
# 645  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 882                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 925                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
#                                display                             camera  \
# 645  Memory Card Supported, upto 32 GB                         Kaios v3.0
# ...

# %%
# ab apka ya 3 phones bacha ha

# %% [markdown]
# ## processor

# %% [markdown]
# now hum ek ek coloumns ko clena karta ha usko dekta ha .

# %%
df[df['index'].isin(processor_rows)]
# Out:
#      index                   model  price  rating  \
# 645    647         Nokia 2760 Flip   5490     NaN
# 857    859             LG Folder 2  11999     NaN
# 882    884  Nokia 5710 XpressAudio   4799     NaN
# 925    927           Nokia 3310 4G   3999     NaN
#
#                                 sim                   processor  \
# 645         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 857       Single Sim, 3G, 4G, Wi-Fi      1 GB RAM, 8 GB inbuilt
# 882                Dual Sim, 3G, 4G                     No Wifi
# 925  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery  \
# 645  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 857                  1470 mAh Battery  2.8 inches, 240 x 320 px Display
# 882                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 925                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
# ...

# %%
# ya sara keyboard phones ha so we drop it 
# isko index pakodo aor drop kar do 
df[df['index'].isin(processor_rows)].index.to_list()
# Out:
# [645, 857, 882, 925]

# %%
df.drop([645, 857, 882, 925],inplace=True)
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_14972\486334192.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop([645, 857, 882, 925],inplace=True)

# %%
df
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %% [markdown]
# ## ram rows

# %%
df[df['index'].isin(ram_rows)]
# Out:
#      index                             model   price  rating  \
# 439    441            Apple iPhone SE 3 2022   43900     NaN
# 483    485  Huawei Mate 50 RS Porsche Design  239999    81.0
# 582    584                     Nokia 8210 4G    3749     NaN
#
#                                                  sim  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 582                                 Dual Sim, 3G, 4G
#
#                                             processor             ram  \
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 483  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
# 582                                           No Wifi     Unisoc T107
#
#                                      battery  \
# 439        4.7 inches, 750 x 1334 px Display
# 483  4700 mAh Battery with 66W Fast Charging
# 582                48 MB RAM, 128 MB inbuilt
#
# ...

# %%
# tho phal is keyboard (feauture phone) ko drop karta ha 
df.drop(582,inplace=True)
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_14972\22856165.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(582,inplace=True)

# %%
df[df['index'].isin(ram_rows)]
# Out:
#      index                             model   price  rating  \
# 439    441            Apple iPhone SE 3 2022   43900     NaN
# 483    485  Huawei Mate 50 RS Porsche Design  239999    81.0
#
#                                                  sim  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
#
#                                             processor             ram  \
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 483  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
#
#                                      battery  \
# 439        4.7 inches, 750 x 1334 px Display
# 483  4700 mAh Battery with 66W Fast Charging
#
#                                          display  \
# 439               12 MP Rear & 7 MP Front Camera
# 483  6.74 inches, 1212 x 2616 px, 120 Hz Display
#
#                                                 camera  \
# ...

# %%
# tho in 2 phones ma problem ha ki inska ram diya gaya ha rom nahi diya gaya ha

# %% [markdown]
# ## battery

# %%
df[df['index'].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 376    378               Nokia 2660 Flip    4649     NaN
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 754    756    Apple iPod Touch (7th Gen)   18900     NaN
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
# so sara sa iphone ma battery ki jaga display information aa gaya
# aor sara left shift ho gaya ha . 

# first ya nokia ka keyboard aor ipod ko remove karo 
df.drop([376,754],inplace=True)
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_14972\3030001642.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop([376,754],inplace=True)

# %%
# hamra paas bacha sara iphone

# %%
df[df['index'].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
# we are using the shiting function

# %%
temp_df = df[df['index'].isin(battery_rows)]
temp_df
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %% [markdown]
# ## shfting code

# %%
#    rows sliching ,columns sliching
# meaning all rows but start coloumns after 7 
temp_df.iloc[:,7:]
# Out:
#                                                battery  \
# 111  6.1 inches, 1170 x 2532 px Display with Large ...
# 149                 5.4 inches, 1080 x 2340 px Display
# 307  6.1 inches, 1170 x 2532 px Display with Large ...
# 363                 5.4 inches, 1080 x 2340 px Display
# 439                  4.7 inches, 750 x 1334 px Display
# 448  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 628  6.1 inches, 1170 x 2532 px Display with Large ...
# 762                  6.1 inches, 750 x 1580 px Display
# 853  6.1 inches, 1170 x 2532 px Display with Large ...
# 913                 5.4 inches, 1080 x 2340 px Display
# 914  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                                display  \
# 111       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 307       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 363       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# ...

# %%
temp_df.iloc[:,7:].shift(1,axis=1) # axis =1 for columns
# Out:
#     battery                                            display  \
# 111    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 149    None                 5.4 inches, 1080 x 2340 px Display
# 307    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 363    None                 5.4 inches, 1080 x 2340 px Display
# 439    None                  4.7 inches, 750 x 1334 px Display
# 448    None  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 628    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 762    None                  6.1 inches, 750 x 1580 px Display
# 853    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 913    None                 5.4 inches, 1080 x 2340 px Display
# 914    None  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                                 camera  \
# 111       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# ...

# %%
our_array = temp_df.iloc[:,7:].shift(1,axis=1).values
our_array
# Out:
# array([[None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '5.4 inches, 1080\u2009x\u20092340\u2009px Display',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '5.4 inches, 1080\u2009x\u20092340\u2009px Display',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '4.7 inches, 750\u2009x\u20091334\u2009px Display',
#         '12\u2009MP Rear & 7\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v15'],
# ...

# %%
x_index = temp_df.index
x_index
# Out:
# Index([111, 149, 307, 363, 439, 448, 628, 762, 853, 913, 914], dtype='int64')

# %%
df.loc[temp_df.index,temp_df.columns]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
# en index and coloumns ma hamrai temp df ki values ko set karo 
df.loc[temp_df.index,temp_df.columns[7:]] = our_array

# %%
# chalo dekta ha editing hua ha k nahi
df[df['index'].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
# har waha editing ho gaya ha hamara ji

# %% [markdown]
# ## display rows

# %%
df[df['index'].isin(display_rows)]
# Out:
#      index                         model   price  rating  \
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 628  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 913  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                       ram  \
# 439  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 448                                 Bionic  A16  8 GB RAM, 128 GB inbuilt
# ...

# %%
# hara ya wahi wala iphone tha tho pichala wala solve kiya tha isliya ya bhi tik ho gaya

# %% [markdown]
# ## camera rows

# %%
df[df['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 155     157                           Nokia 2780 Flip    4990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 271     273                         Nokia 2720 V Flip    6199     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# ...

# %%
#  this are  feature phone 
# 155,275
df.drop([155,275],inplace=True)
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_14972\1588539464.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop([155,275],inplace=True)

# %%
df[df['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 271     273                         Nokia 2720 V Flip    6199     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 365     367                          OPPO Find N Flip   89990    88.0
# ...

# %%
# deko ja par bhi foldable display lika ha wha par wo right shift ho gaya ha data 
# jaha normal camera ha wha tik ha 
temp_df = df[df['index'].isin(camera_rows)]
temp_df
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 271     273                         Nokia 2720 V Flip    6199     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 365     367                          OPPO Find N Flip   89990    88.0
# ...

# %%
temp_df[temp_df['camera'].str.contains('MP')]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 856    858       Samsung Galaxy A01 Core    4999     NaN
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
# do negation of it . now we find the all mistakes phone 
camera_df = temp_df[~temp_df['camera'].str.contains('MP')]
camera_df
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 271     273                         Nokia 2720 V Flip    6199     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# 482     484                          Vivo X Fold Plus  113990     NaN
# 504     506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# 569     571                   Samsung Galaxy Z Fold 3  110999    89.0
# ...

# %%
# just swap the coloumns values  of camera and card 

df.loc[camera_df.index,'camera']
# Out:
# 98                    Foldable Display
# 159     Foldable Display, Dual Display
# 236     Foldable Display, Dual Display
# 271                       Dual Display
# 306     Foldable Display, Dual Display
# 321     Foldable Display, Dual Display
# 322     Foldable Display, Dual Display
# 365     Foldable Display, Dual Display
# 392     Foldable Display, Dual Display
# 482     Foldable Display, Dual Display
# 504     Foldable Display, Dual Display
# 569     Foldable Display, Dual Display
# 570                       Dual Display
# 613                       Dual Display
# 682                       Dual Display
# 703     Foldable Display, Dual Display
# 709                       Dual Display
# 721                       Dual Display
# 726                   Foldable Display
# 790     Foldable Display, Dual Display
# 844                       Dual Display
# 894     Foldable Display, Dual Display
# 943     Foldable Display, Dual Display
# 954                   Foldable Display
# ...

# %%
camera_df['card']
# Out:
# 98                   50 MP Quad Rear & 16 MP Front Camera
# 159     50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 236     50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front...
# 271                                      2 MP Rear Camera
# 306          12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 321     50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 322     64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 365           50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 392           50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 482     50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera
# 504          12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 569     12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 570     64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 613     64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 682     64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 703     50 MP + 16 MP + 13 MP Triple Rear & 32 MP Fron...
# ...

# %%
camera_df['card'].values
# Out:
# array(['50\u2009MP Quad Rear & 16\u2009MP Front Camera',
#        '50\u2009MP + 48\u2009MP + 32\u2009MP Triple Rear & 32\u2009MP + 32\u2009MP Dual Front Camera',
#        '50\u2009MP + 13\u2009MP + 8\u2009MP Triple Rear & 20\u2009MP Front Camera',
#        '2\u2009MP Rear Camera',
#        '12\u2009MP + 12\u2009MP Dual Rear & 10\u2009MP Front Camera',
#        '50\u2009MP + 12\u2009MP + 10\u2009MP Triple Rear & 10\u2009MP + 4\u2009MP Dual Front Camera',
#        '64\u2009MP + 16\u2009MP + 8\u2009MP Triple Rear & 32\u2009MP Front Camera',
#        '50\u2009MP + 8\u2009MP Dual Rear & 32\u2009MP Front Camera',
#        '50\u2009MP + 8\u2009MP Dual Rear & 32\u2009MP Front Camera',
#        '50\u2009MP Quad Rear & 16\u2009MP + 16\u2009MP Dual Front Camera',
#        '12\u2009MP + 12\u2009MP Dual Rear & 10\u2009MP Front Camera',
#        '12\u2009MP + 12\u2009MP + 12\u2009MP Triple Rear & 10\u2009MP + 4\u2009MP Dual Front Camera',
# ...

# %%
# asssign the card information in dataframe

# %%
df.loc[camera_df.index,'camera'] = camera_df['card'].values

# %%
# now everything data is clean 
df[df['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 271     273                         Nokia 2720 V Flip    6199     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 365     367                          OPPO Find N Flip   89990    88.0
# ...

# %% [markdown]
# ## card

# %%
df['card'].value_counts()
# Out:
# card
# Memory Card Supported, upto 1 TB                                       171
# Memory Card Not Supported                                              123
# Android v12                                                            107
# Memory Card Supported, upto 512 GB                                     105
# Memory Card (Hybrid), upto 1 TB                                         90
# Memory Card Supported                                                   89
# Memory Card Supported, upto 256 GB                                      87
# Android v13                                                             46
# Android v11                                                             41
# Memory Card (Hybrid)                                                    30
# Memory Card (Hybrid), upto 256 GB                                       13
# Memory Card (Hybrid), upto 512 GB                                       11
# ...

# %%
# ja par ma MP usko replace kar do not supported sa
df[df['card'].str.contains('MP')]
# all the cards which have information
# Out:
#       index                                     model   price  rating  \
# 69       71                          Oppo Find N Fold   99990     NaN
# 98      100                            Vivo X Fold 5G  106990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 271     273                         Nokia 2720 V Flip    6199     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# 482     484                          Vivo X Fold Plus  113990     NaN
# 504     506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# ...

# %%
# replace it
card_df = df[df['card'].str.contains('MP')]
card_df
# Out:
#       index                                     model   price  rating  \
# 69       71                          Oppo Find N Fold   99990     NaN
# 98      100                            Vivo X Fold 5G  106990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 271     273                         Nokia 2720 V Flip    6199     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# 482     484                          Vivo X Fold Plus  113990     NaN
# 504     506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# ...

# %%
df.loc[camera_df.index,'card'] = 'Memory Card Not Supported'

# %%
df[df['card'].str.contains('MP')]['card']
# Out:
# 69    64 MP + 10 MP + 8 MP Triple Rear & 32 MP Front...
# Name: card, dtype: object

# %%
# replace this mp

# %%
df['card'] = df['card'].str.replace(
    pat='64 MP + 10 MP + 8 MP Triple Rear & 32 MP Front Camera',
    repl='Memory Card Not Supported'
)
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_14972\456004459.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['card'] = df['card'].str.replace(

# %%
df['card'].value_counts()
# Out:
# card
# Memory Card Supported, upto 1 TB       171
# Memory Card Not Supported              150
# Android v12                            107
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         90
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Android v13                             46
# Android v11                             41
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Android v10                             11
# Memory Card Supported, upto 128 GB       6
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card (Hybrid), upto 128 GB        3
# Android v9.0 (Pie)                       2
# Android v12.1                            1
# Memory Card Supported, upto 1000 GB      1
# iOS v10                                  1
# ...

# %%
df[df['card'].str.contains('Android')]
# Out:
#       index                        model  price  rating  \
# 8        10              Nothing Phone 1  26749    85.0
# 9        11           OnePlus Nord 2T 5G  28999    84.0
# 12       14  Xiaomi Redmi Note 12 Pro 5G  24762    79.0
# 17       19         OPPO Reno 9 Pro Plus  45999    86.0
# 18       20               OnePlus 10R 5G  32999    86.0
# ...     ...                          ...    ...     ...
# 1009   1011                Xiaomi Civi 3  32990    86.0
# 1011   1013                 Oppo Find X6  69990    89.0
# 1012   1014                    itel A23s   4787     NaN
# 1013   1015           Google Pixel 8 Pro  70990    80.0
# 1015   1017   Motorola Moto Edge S30 Pro  34990    83.0
#
#                                                     sim  \
# 8               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 9               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 12       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 17              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df[df['card'].str.contains('Memory Card')]
# Out:
#       index                            model   price  rating  \
# 0         2                    OnePlus 11 5G   54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G   19989    81.0
# 2         4            Samsung Galaxy A14 5G   16499    75.0
# 3         5             Motorola Moto G62 5G   14999    81.0
# 4         6               Realme 10 Pro Plus   24999    82.0
# ...     ...                              ...     ...     ...
# 1014   1016                    Vivo X Fold 2  119990     NaN
# 1016   1018                      Honor X8 5G   14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)   28990    85.0
# 1018   1020             Motorola Moto G91 5G   19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G   24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
# all those rows jaha operating system ha 
# negation of it
temp_df = df[~df['card'].str.contains('Memory Card')]
temp_df
# Out:
#       index                        model  price  rating  \
# 8        10              Nothing Phone 1  26749    85.0
# 9        11           OnePlus Nord 2T 5G  28999    84.0
# 12       14  Xiaomi Redmi Note 12 Pro 5G  24762    79.0
# 17       19         OPPO Reno 9 Pro Plus  45999    86.0
# 18       20               OnePlus 10R 5G  32999    86.0
# ...     ...                          ...    ...     ...
# 1009   1011                Xiaomi Civi 3  32990    86.0
# 1011   1013                 Oppo Find X6  69990    89.0
# 1012   1014                    itel A23s   4787     NaN
# 1013   1015           Google Pixel 8 Pro  70990    80.0
# 1015   1017   Motorola Moto Edge S30 Pro  34990    83.0
#
#                                                     sim  \
# 8               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 9               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 12       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 17              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df.loc[temp_df.index , 'card']
# Out:
# 8       Android v12
# 9       Android v12
# 12      Android v12
# 17      Android v13
# 18      Android v12
#            ...
# 1009    Android v13
# 1011    Android v12
# 1012    Android v11
# 1013    Android v13
# 1015    Android v12
# Name: card, Length: 213, dtype: object

# %%
# so we have to shift the card information to os 
# nan values ko fir replace karo memory card not supported sa 
temp_df
# Out:
#       index                        model  price  rating  \
# 8        10              Nothing Phone 1  26749    85.0
# 9        11           OnePlus Nord 2T 5G  28999    84.0
# 12       14  Xiaomi Redmi Note 12 Pro 5G  24762    79.0
# 17       19         OPPO Reno 9 Pro Plus  45999    86.0
# 18       20               OnePlus 10R 5G  32999    86.0
# ...     ...                          ...    ...     ...
# 1009   1011                Xiaomi Civi 3  32990    86.0
# 1011   1013                 Oppo Find X6  69990    89.0
# 1012   1014                    itel A23s   4787     NaN
# 1013   1015           Google Pixel 8 Pro  70990    80.0
# 1015   1017   Motorola Moto Edge S30 Pro  34990    83.0
#
#                                                     sim  \
# 8               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 9               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 12       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 17              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
temp_df['card']
# Out:
# 8       Android v12
# 9       Android v12
# 12      Android v12
# 17      Android v13
# 18      Android v12
#            ...
# 1009    Android v13
# 1011    Android v12
# 1012    Android v11
# 1013    Android v13
# 1015    Android v12
# Name: card, Length: 213, dtype: object

# %%
temp_df.index
# Out:
# Index([   8,    9,   12,   17,   18,   20,   21,   24,   29,   37,
#        ...
#         971,  974,  975, 1007, 1008, 1009, 1011, 1012, 1013, 1015],
#       dtype='int64', length=213)

# %%
temp_df.iloc[:,10:].shift(1,axis=1)
# Out:
#       card           os
# 8     None  Android v12
# 9     None  Android v12
# 12    None  Android v12
# 17    None  Android v13
# 18    None  Android v12
# ...    ...          ...
# 1009  None  Android v13
# 1011  None  Android v12
# 1012  None  Android v11
# 1013  None  Android v13
# 1015  None  Android v12
#
# [213 rows x 2 columns]

# %%
#our operating system array 
os_array = temp_df.iloc[:,10:].shift(1,axis=1).values
os_array
# Out:
# array([[None, 'Android v12'],
#        [None, 'Android v12'],
#        [None, 'Android v12'],
#        [None, 'Android v13'],
#        [None, 'Android v12'],
#        [None, 'Android v13'],
#        [None, 'Android v12'],
#        [None, 'Android v13'],
#        [None, 'Android v13'],
#        [None, 'Android v12'],
#        [None, 'Android v13'],
#        [None, 'Android v13'],
#        [None, 'Android v13'],
#        [None, 'Android v12'],
#        [None, 'Android v13'],
#        [None, 'Android v13'],
#        [None, 'Android v12'],
#        [None, 'Android v12'],
#        [None, 'Android v12'],
#        [None, 'Android v12'],
#        [None, 'Android v13'],
#        [None, 'Android v13'],
#        [None, 'Android v12'],
#        [None, 'Android v13'],
#        [None, 'Android v12'],
#        [None, 'Android v12'],
#        [None, 'Android v12'],
#        [None, 'Android v12'],
#        [None, 'Android v12'],
#        [None, 'Android v13'],
#        [None, 'Android v12'],
# ...

# %%
# before 
df.loc[temp_df.index,temp_df.columns[10:]]
# Out:
#              card           os
# 8     Android v12  No FM Radio
# 9     Android v12  No FM Radio
# 12    Android v12  No FM Radio
# 17    Android v13  No FM Radio
# 18    Android v12    Bluetooth
# ...           ...          ...
# 1009  Android v13  No FM Radio
# 1011  Android v12  No FM Radio
# 1012  Android v11  No FM Radio
# 1013  Android v13  No FM Radio
# 1015  Android v12  No FM Radio
#
# [213 rows x 2 columns]

# %%
# apply operating assiging them 
df.loc[temp_df.index,temp_df.columns[10:]] = os_array

# %%
# after checking it
df.loc[temp_df.index,temp_df.columns[10:]]
# Out:
#       card           os
# 8     None  Android v12
# 9     None  Android v12
# 12    None  Android v12
# 17    None  Android v13
# 18    None  Android v12
# ...    ...          ...
# 1009  None  Android v13
# 1011  None  Android v12
# 1012  None  Android v11
# 1013  None  Android v13
# 1015  None  Android v12
#
# [213 rows x 2 columns]

# %%
# aap check karo 
df['card'].value_counts()
# Out:
# card
# Memory Card Supported, upto 1 TB       171
# Memory Card Not Supported              150
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         90
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Memory Card Supported, upto 128 GB       6
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card Supported, upto 1000 GB      1
# Memory Card (Hybrid), upto 2 TB          1
# Name: count, dtype: int64

# %%
df['card'].isnull().sum()
# 213 values ma operating system tha
# Out:
# 213

# %%
df['card'].isnull().sum()
# Out:
# 213

# %%
df.loc[temp_df.index,'card']
# Out:
# 8       None
# 9       None
# 12      None
# 17      None
# 18      None
#         ...
# 1009    None
# 1011    None
# 1012    None
# 1013    None
# 1015    None
# Name: card, Length: 213, dtype: object

# %%
df.loc[temp_df.index,'card']  = 'Memory Card Not Supported'

# %%
df.loc[temp_df.index,'card']
# Out:
# 8       Memory Card Not Supported
# 9       Memory Card Not Supported
# 12      Memory Card Not Supported
# 17      Memory Card Not Supported
# 18      Memory Card Not Supported
#                   ...
# 1009    Memory Card Not Supported
# 1011    Memory Card Not Supported
# 1012    Memory Card Not Supported
# 1013    Memory Card Not Supported
# 1015    Memory Card Not Supported
# Name: card, Length: 213, dtype: object

# %%
df['card'].isnull().sum()
# Out:
# 0

# %%
# yes you do it.

# %%
df['card'].value_counts()
# Out:
# card
# Memory Card Not Supported              363
# Memory Card Supported, upto 1 TB       171
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         90
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Memory Card Supported, upto 128 GB       6
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card Supported, upto 1000 GB      1
# Memory Card (Hybrid), upto 2 TB          1
# Name: count, dtype: int64

# %%
# wow tho hamena aab card problem ho bhi solve kar diya ha . 
# sabhi ma memory card information ha

# %% [markdown]
# ## operating system

# %%
df['os'].value_counts()
# Out:
# os
# Android v12                           394
# Android v11                           273
# Android v13                            91
# Android v10                            69
# Android v9.0 (Pie)                     29
# Android v10.0                          23
# iOS v16                                15
# iOS v15                                12
# Android v8.1 (Oreo)                    10
# iOS v14                                 6
# Memory Card Not Supported               6
# Android v11.0                           4
# Android v8.0 (Oreo)                     4
# iOS v13                                 4
# iOS v15.0                               3
# Harmony v2.0                            2
# Memory Card (Hybrid), upto 2 TB         2
# Memory Card (Hybrid), upto 256 GB       2
# HarmonyOS v2.0                          2
# Android v5.1.1 (Lollipop)               2
# EMUI v12                                2
# Android v6.0 (Marshmallow)              2
# ...

# %%
# isma abhi bhi kuch jagea memory card ha 
# matlab waha par hamra paas operating system ka information ha hi nahi

# %%
# memory card ko dekta ha waha kiya scene chal raha ha

# %%
os_temp_df = df[df['os'].str.contains('Memory Card')]
os_temp_df
# Out:
#      index                       model   price  rating  \
# 159    161             Oppo Find N2 5G   94990     NaN
# 271    273           Nokia 2720 V Flip    6199     NaN
# 306    308     Samsung Galaxy Z Flip 3   69999    84.0
# 322    324            Royole FlexPai 2  109999    87.0
# 365    367            OPPO Find N Flip   89990    88.0
# 392    394           OPPO Find N2 Flip   70990    88.0
# 504    506  Samsung Galaxy Z Flip 4 5G   89999    88.0
# 570    572                  LG Wing 5G   54999    89.0
# 613    615                Oukitel WP21   22990    82.0
# 682    684                LG V60 ThinQ   79990     NaN
# 721    723  Asus ROG Phone 6D Ultimate  107990     NaN
# 726    728            Huawei Mate Xs 2  162990    89.0
# 844    846                CAT S22 Flip   14999     NaN
# 894    896         Royole FlexPai 3 5G  149999    87.0
# 993    995               Huawei Mate X  169000     NaN
#
#                                                    sim  \
# ...

# %%
df[df['os'].str.contains('Memory Card')]['os'].value_counts()
# Out:
# os
# Memory Card Not Supported             6
# Memory Card Supported, upto 256 GB    2
# Memory Card (Hybrid), upto 2 TB       2
# Memory Card (Hybrid), upto 256 GB     2
# Memory Card Supported                 1
# Memory Card (Hybrid)                  1
# Memory Card Supported, upto 128 GB    1
# Name: count, dtype: int64

# %%
# hamena jo memory card  not supported
# lakin vo insformation side wala coloumns ma tha .

# %%
# just swap the values and assign them 
os_temp_df['os']
# Out:
# 159             Memory Card Not Supported
# 271                 Memory Card Supported
# 306             Memory Card Not Supported
# 322    Memory Card Supported, upto 256 GB
# 365             Memory Card Not Supported
# 392             Memory Card Not Supported
# 504             Memory Card Not Supported
# 570       Memory Card (Hybrid), upto 2 TB
# 613                  Memory Card (Hybrid)
# 682       Memory Card (Hybrid), upto 2 TB
# 721             Memory Card Not Supported
# 726     Memory Card (Hybrid), upto 256 GB
# 844    Memory Card Supported, upto 128 GB
# 894    Memory Card Supported, upto 256 GB
# 993     Memory Card (Hybrid), upto 256 GB
# Name: os, dtype: object

# %%
# ya os ka value apki orignial df ma hona chaya tha

# %%
# before 
df.loc[os_temp_df.index,'card']
# Out:
# 159    Memory Card Not Supported
# 271    Memory Card Not Supported
# 306    Memory Card Not Supported
# 322    Memory Card Not Supported
# 365    Memory Card Not Supported
# 392    Memory Card Not Supported
# 504    Memory Card Not Supported
# 570    Memory Card Not Supported
# 613    Memory Card Not Supported
# 682    Memory Card Not Supported
# 721    Memory Card Not Supported
# 726    Memory Card Not Supported
# 844    Memory Card Not Supported
# 894    Memory Card Not Supported
# 993    Memory Card Not Supported
# Name: card, dtype: object

# %%
# assign them apply the operating 
df.loc[os_temp_df.index,'card'] = os_temp_df['os']

# %%
# after 
df.loc[os_temp_df.index,'card']
# Out:
# 159             Memory Card Not Supported
# 271                 Memory Card Supported
# 306             Memory Card Not Supported
# 322    Memory Card Supported, upto 256 GB
# 365             Memory Card Not Supported
# 392             Memory Card Not Supported
# 504             Memory Card Not Supported
# 570       Memory Card (Hybrid), upto 2 TB
# 613                  Memory Card (Hybrid)
# 682       Memory Card (Hybrid), upto 2 TB
# 721             Memory Card Not Supported
# 726     Memory Card (Hybrid), upto 256 GB
# 844    Memory Card Supported, upto 128 GB
# 894    Memory Card Supported, upto 256 GB
# 993     Memory Card (Hybrid), upto 256 GB
# Name: card, dtype: object

# %%
df.loc[os_temp_df.index,'card'].value_counts()
# Out:
# card
# Memory Card Not Supported             6
# Memory Card Supported, upto 256 GB    2
# Memory Card (Hybrid), upto 2 TB       2
# Memory Card (Hybrid), upto 256 GB     2
# Memory Card Supported                 1
# Memory Card (Hybrid)                  1
# Memory Card Supported, upto 128 GB    1
# Name: count, dtype: int64

# %%
# now everything is fine

# %%
# chalo now back  to our operating system ma ata ha 
df['os'].value_counts()
# Out:
# os
# Android v12                           394
# Android v11                           273
# Android v13                            91
# Android v10                            69
# Android v9.0 (Pie)                     29
# Android v10.0                          23
# iOS v16                                15
# iOS v15                                12
# Android v8.1 (Oreo)                    10
# iOS v14                                 6
# Memory Card Not Supported               6
# Android v11.0                           4
# Android v8.0 (Oreo)                     4
# iOS v13                                 4
# iOS v15.0                               3
# Harmony v2.0                            2
# Memory Card (Hybrid), upto 2 TB         2
# Memory Card (Hybrid), upto 256 GB       2
# HarmonyOS v2.0                          2
# Android v5.1.1 (Lollipop)               2
# EMUI v12                                2
# Android v6.0 (Marshmallow)              2
# ...

# %%
df[df['os'] == 'Bluetooth']
# Out:
#      index          model  price  rating                      sim  \
# 486    488  Nokia 8000 4G   6899     NaN  Dual Sim, 3G, 4G, Wi-Fi
#
#                                          processor                       ram  \
# 486  Snapdragon  210, Quad Core, 1.1 GHz Processor  512 MB RAM, 4 GB inbuilt
#
#               battery                           display            camera  \
# 486  1500 mAh Battery  2.8 inches, 240 x 320 px Display  2 MP Rear Camera
#
#                       card         os
# 486  Memory Card Supported  Bluetooth

# %%
# replace the bluetooth with np.nan
df[df['os'] == 'Bluetooth']['os']
# Out:
# 486    Bluetooth
# Name: os, dtype: object

# %%
bluetooth_df = df[df['os'] == 'Bluetooth']
bluetooth_df
# Out:
#      index          model  price  rating                      sim  \
# 486    488  Nokia 8000 4G   6899     NaN  Dual Sim, 3G, 4G, Wi-Fi
#
#                                          processor                       ram  \
# 486  Snapdragon  210, Quad Core, 1.1 GHz Processor  512 MB RAM, 4 GB inbuilt
#
#               battery                           display            camera  \
# 486  1500 mAh Battery  2.8 inches, 240 x 320 px Display  2 MP Rear Camera
#
#                       card         os
# 486  Memory Card Supported  Bluetooth

# %%
# before 
df.loc[bluetooth_df.index,'os']
# Out:
# 486    Bluetooth
# Name: os, dtype: object

# %%
# replace it with nan
df.loc[bluetooth_df.index,'os'] = np.nan

# %%
# after yes we change it
df.loc[bluetooth_df.index,'os']
# Out:
# 486    NaN
# Name: os, dtype: object

# %%
# jaha par bhi apka memory card mila waha nana

# %%
temp_df = df[df['os'].str.contains('Memory Card')]
temp_df
# Out:
#      index                       model   price  rating  \
# 159    161             Oppo Find N2 5G   94990     NaN
# 271    273           Nokia 2720 V Flip    6199     NaN
# 306    308     Samsung Galaxy Z Flip 3   69999    84.0
# 322    324            Royole FlexPai 2  109999    87.0
# 365    367            OPPO Find N Flip   89990    88.0
# 392    394           OPPO Find N2 Flip   70990    88.0
# 504    506  Samsung Galaxy Z Flip 4 5G   89999    88.0
# 570    572                  LG Wing 5G   54999    89.0
# 613    615                Oukitel WP21   22990    82.0
# 682    684                LG V60 ThinQ   79990     NaN
# 721    723  Asus ROG Phone 6D Ultimate  107990     NaN
# 726    728            Huawei Mate Xs 2  162990    89.0
# 844    846                CAT S22 Flip   14999     NaN
# 894    896         Royole FlexPai 3 5G  149999    87.0
# 993    995               Huawei Mate X  169000     NaN
#
#                                                    sim  \
# ...

# %%
# before
df.loc[temp_df.index,'os']
# Out:
# 159             Memory Card Not Supported
# 271                 Memory Card Supported
# 306             Memory Card Not Supported
# 322    Memory Card Supported, upto 256 GB
# 365             Memory Card Not Supported
# 392             Memory Card Not Supported
# 504             Memory Card Not Supported
# 570       Memory Card (Hybrid), upto 2 TB
# 613                  Memory Card (Hybrid)
# 682       Memory Card (Hybrid), upto 2 TB
# 721             Memory Card Not Supported
# 726     Memory Card (Hybrid), upto 256 GB
# 844    Memory Card Supported, upto 128 GB
# 894    Memory Card Supported, upto 256 GB
# 993     Memory Card (Hybrid), upto 256 GB
# Name: os, dtype: object

# %%
# replace with np.nan apply operation
df.loc[temp_df.index,'os'] = np.nan

# %%
# after (operation successful)
df.loc[temp_df.index,'os']
# Out:
# 159    NaN
# 271    NaN
# 306    NaN
# 322    NaN
# 365    NaN
# 392    NaN
# 504    NaN
# 570    NaN
# 613    NaN
# 682    NaN
# 721    NaN
# 726    NaN
# 844    NaN
# 894    NaN
# 993    NaN
# Name: os, dtype: object

# %%
df['os'].value_counts()
# Out:
# os
# Android v12                        394
# Android v11                        273
# Android v13                         91
# Android v10                         69
# Android v9.0 (Pie)                  29
# Android v10.0                       23
# iOS v16                             15
# iOS v15                             12
# Android v8.1 (Oreo)                 10
# iOS v14                              6
# Android v11.0                        4
# iOS v13                              4
# Android v8.0 (Oreo)                  4
# iOS v15.0                            3
# HarmonyOS v2.0                       2
# Android v5.1.1 (Lollipop)            2
# Android v6.0 (Marshmallow)           2
# Harmony v2.0                         2
# EMUI v12                             2
# Android v12.1                        2
# iOS v14.0                            2
# HarmonyOS                            1
# Android                              1
# Hongmeng OS v4.0                     1
# ...

# %% [markdown]
# ## check all coloumns

# %%
# ab aap har ek columns ma jaho aor deko kahi koi alag values tho nahi ha 
# value count karo har kisi par

# %%
df.columns
# Out:
# Index(['index', 'model', 'price', 'rating', 'sim', 'processor', 'ram',
#        'battery', 'display', 'camera', 'card', 'os'],
#       dtype='object')

# %%
df['model'].value_counts()
# Out:
# model
# OnePlus 11 5G                              1
# Vivo V25e                                  1
# Realme Narzo 50 5G (4GB RAM + 64GB)        1
# itel Vision 3                              1
# OPPO A96 4G                                1
#                                           ..
# Samsung Galaxy A73 5G (8GB RAM + 256GB)    1
# Realme 9 5G SE (8GB RAM + 128GB)           1
# Poco F4 5G                                 1
# Infinix Note 12                            1
# Samsung Galaxy M52s 5G                     1
# Name: count, Length: 982, dtype: int64

# %%
df['sim'].value_counts()
# Out:
# sim
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi                               318
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                      268
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi                           155
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster                53
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster           52
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                           46
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster                    46
# Dual Sim, 3G, 4G, Wi-Fi                                        7
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC                  7
# Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                      7
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster                5
# Single Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                          4
# Single Sim, 3G, 4G, VoLTE, Wi-Fi                               3
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi                       3
# ...

# %%
df['processor'].value_counts()
# Out:
# processor
# Dimensity 700 5G, Octa Core, 2.2 GHz Processor      29
# Helio P35, Octa Core, 2.3 GHz Processor             27
# Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor    26
# Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor     23
# Snapdragon 695, Octa Core, 2.2 GHz Processor        23
#                                                     ..
# Tiger T310, Quad Core, 2 GHz Processor               1
# Snapdragon 835, Octa Core, 2.35 GHz Processor        1
# Sanpdragon 680, Octa Core, 2.4 GHz Processor         1
# Snapdragon  210, Quad Core, 1.1 GHz Processor        1
# Google  Tensor 3, Octa Core Processor                1
# Name: count, Length: 276, dtype: int64

# %%
df['ram'].value_counts()
# Out:
# ram
# 8 GB RAM, 128 GB inbuilt     266
# 6 GB RAM, 128 GB inbuilt     190
# 4 GB RAM, 64 GB inbuilt      143
# 12 GB RAM, 256 GB inbuilt     70
# 8 GB RAM, 256 GB inbuilt      70
# 4 GB RAM, 128 GB inbuilt      62
# 3 GB RAM, 32 GB inbuilt       37
# 6 GB RAM, 64 GB inbuilt       29
# 2 GB RAM, 32 GB inbuilt       24
# 3 GB RAM, 64 GB inbuilt       15
# 12 GB RAM, 512 GB inbuilt     10
# 6 GB RAM, 256 GB inbuilt       7
# 16 GB RAM, 256 GB inbuilt      6
# 4 GB RAM, 32 GB inbuilt        6
# 1 GB RAM, 16 GB inbuilt        6
# 2 GB RAM, 16 GB inbuilt        4
# 6 GB RAM, 1 TB inbuilt         4
# 6 GB RAM, 512 GB inbuilt       4
# 12 GB RAM, 128 GB inbuilt      4
# 2 GB RAM, 64 GB inbuilt        4
# 4 GB RAM, 256 GB inbuilt       3
# 16 GB RAM, 512 GB inbuilt      3
# 3 GB RAM, 16 GB inbuilt        2
# 8 GB RAM, 512 GB inbuilt       2
# 512 MB RAM, 4 GB inbuilt       2
# 64 GB inbuilt                  2
# 512 GB inbuilt                 1
# 64 MB RAM, 128 MB inbuilt      1
# ...

# %%
df['battery'].value_counts()
# Out:
# battery
# 5000 mAh Battery with 33W Fast Charging      103
# 5000 mAh Battery with 18W Fast Charging       89
# 5000 mAh Battery                              74
# 5000 mAh Battery with 67W Fast Charging       29
# 5000 mAh Battery with 10W Fast Charging       28
#                                             ...
# 6000 mAh Battery with 120W Fast Charging       1
# 4700 mAh Battery with Fast Charging            1
# 21000 mAh Battery with 33W Fast Charging       1
# 4200 mAh Battery with 66W Fast Charging        1
# 5000 mAh Battery with 68.2W Fast Charging      1
# Name: count, Length: 230, dtype: int64

# %%
df['display'].value_counts()
# Out:
# display
# 6.67 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole    53
# 6.5 inches, 720 x 1600 px Display with Water Drop Notch        36
# 6.7 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole     25
# 6.52 inches, 720 x 1600 px Display with Water Drop Notch       23
# 6.5 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole      22
#                                                                ..
# 6 inches, 1080 x 2340 px, 90 Hz Display with Punch Hole         1
# 6.73 inches, 1440 x 3412 px, 144 Hz Display with Punch Hole     1
# 6.58 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole      1
# 6.56 inches, 720 x 1612 px, 90 Hz Display with Punch Hole       1
# 6.8 inches, 1080 x 2400 px Display with Punch Hole              1
# Name: count, Length: 347, dtype: int64

# %%
df['camera'].value_counts()
# Out:
# camera
# 50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera           40
# 64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera           38
# 50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera           34
# 13 MP + 2 MP Dual Rear & 5 MP Front Camera                     23
# 13 MP Rear & 5 MP Front Camera                                 20
#                                                                ..
# 20 MP + 16 MP Dual Rear & 16 MP Front Camera                    1
# 108 MP + 50 MP + 48 MP Triple Rear & 32 MP Front Camera         1
# 64 MP + 64 MP + 64 MP Triple Rear & 16 MP Front Camera          1
# 64 MP + 13 MP Dual Rear & 16 MP Front Camera                    1
# 48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP Front Camera     1
# Name: count, Length: 285, dtype: int64

# %%
df['card'].value_counts()
# Out:
# card
# Memory Card Not Supported              354
# Memory Card Supported, upto 1 TB       171
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         90
# Memory Card Supported                   90
# Memory Card Supported, upto 256 GB      89
# Memory Card (Hybrid)                    31
# Memory Card (Hybrid), upto 256 GB       15
# Memory Card (Hybrid), upto 512 GB       11
# Memory Card Supported, upto 128 GB       7
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card (Hybrid), upto 2 TB          3
# Memory Card Supported, upto 1000 GB      1
# Name: count, dtype: int64

# %%
df['os'].value_counts()
# Out:
# os
# Android v12                        394
# Android v11                        273
# Android v13                         91
# Android v10                         69
# Android v9.0 (Pie)                  29
# Android v10.0                       23
# iOS v16                             15
# iOS v15                             12
# Android v8.1 (Oreo)                 10
# iOS v14                              6
# Android v11.0                        4
# iOS v13                              4
# Android v8.0 (Oreo)                  4
# iOS v15.0                            3
# HarmonyOS v2.0                       2
# Android v5.1.1 (Lollipop)            2
# Android v6.0 (Marshmallow)           2
# Harmony v2.0                         2
# EMUI v12                             2
# Android v12.1                        2
# iOS v14.0                            2
# HarmonyOS                            1
# Android                              1
# Hongmeng OS v4.0                     1
# ...

# %%
# now har ek column ma uska data ki hi value ha . 
# validity issue completed

# %% [markdown]
# # part 2

# %%
# now we start data cleaning part 2 on smartphone dataset
# now we solve the tideness issue (structure)

# %%
df
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %% [markdown]
# # model col
# we create a new coloumn brand name

# %%
df['model'].str.split(' ')
# Out:
# 0                              [OnePlus, 11, 5G]
# 1               [OnePlus, Nord, CE, 2, Lite, 5G]
# 2                     [Samsung, Galaxy, A14, 5G]
# 3                      [Motorola, Moto, G62, 5G]
# 4                        [Realme, 10, Pro, Plus]
#                           ...
# 1015            [Motorola, Moto, Edge, S30, Pro]
# 1016                             [Honor, X8, 5G]
# 1017    [POCO, X4, GT, 5G, (8GB, RAM, +, 256GB)]
# 1018                   [Motorola, Moto, G91, 5G]
# 1019                 [Samsung, Galaxy, M52s, 5G]
# Name: model, Length: 982, dtype: object

# %%
df['model'].str.split(' ').str.get(0)
# Out:
# 0        OnePlus
# 1        OnePlus
# 2        Samsung
# 3       Motorola
# 4         Realme
#           ...
# 1015    Motorola
# 1016       Honor
# 1017        POCO
# 1018    Motorola
# 1019     Samsung
# Name: model, Length: 982, dtype: object

# %%
# this is our brand coloumn series
brand_names = df['model'].str.split(' ').str.get(0)
brand_names
# Out:
# 0        OnePlus
# 1        OnePlus
# 2        Samsung
# 3       Motorola
# 4         Realme
#           ...
# 1015    Motorola
# 1016       Honor
# 1017        POCO
# 1018    Motorola
# 1019     Samsung
# Name: model, Length: 982, dtype: object

# %%
# you can insert column at specific postion 
# waran hum add karta tho ya last postion par jayega
df.insert(
    loc=1,  # postion of column you add
    column= 'brand_names', # name of the oclumn
    value= brand_names
)

# %%
df
# Out:
#       index brand_names                            model  price  rating  \
# 0         2     OnePlus                    OnePlus 11 5G  54999    89.0
# 1         3     OnePlus        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4     Samsung            Samsung Galaxy A14 5G  16499    75.0
# 3         5    Motorola             Motorola Moto G62 5G  14999    81.0
# 4         6      Realme               Realme 10 Pro Plus  24999    82.0
# ...     ...         ...                              ...    ...     ...
# 1015   1017    Motorola       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018       Honor                      Honor X8 5G  14990    75.0
# 1017   1019        POCO  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020    Motorola             Motorola Moto G91 5G  19990    80.0
# 1019   1021     Samsung           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# ...

# %%
# kahi par capital case hoga kahi par small case
# tho different categories bana gi 
# now lets make them in lowecase good stragtey
df['brand_names'].str.lower()
# Out:
# 0        oneplus
# 1        oneplus
# 2        samsung
# 3       motorola
# 4         realme
#           ...
# 1015    motorola
# 1016       honor
# 1017        poco
# 1018    motorola
# 1019     samsung
# Name: brand_names, Length: 982, dtype: object

# %%
df['brand_names'] = df['brand_names'].str.lower()
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_14972\63663228.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['brand_names'] = df['brand_names'].str.lower()

# %% [markdown]
# ## price
# price hamana phala hi tick kar diya tha

# %% [markdown]
# ## sim
# - deko sara hi phone lag bad dual sim ha
# - 3G,4G bhi sara hi phone ha
# - 4G ,5G sa difference aa raha ha (this is good differenaley factor)
# - Nfc (it is very expensive phone)
# - blaster ( which you control the frige ,ac extra)

# %% [markdown]
# So We create the 3 columns from the sim
# 1. 5G phone it is or 4G
# 2. has_ nfc phone yes or no
# 3. has_irc_baster yes or no

# %%
has_5g = df['sim'].str.contains('5G')
has_5g
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1015    True
# 1016    True
# 1017    True
# 1018    True
# 1019    True
# Name: sim, Length: 982, dtype: bool

# %%
df['sim'].value_counts()
# Out:
# sim
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi                               318
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                      268
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi                           155
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster                53
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster           52
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                           46
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster                    46
# Dual Sim, 3G, 4G, Wi-Fi                                        7
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC                  7
# Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                      7
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster                5
# Single Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                          4
# Single Sim, 3G, 4G, VoLTE, Wi-Fi                               3
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi                       3
# ...

# %%
has_nfc = df['sim'].str.contains('NFC')
has_nfc
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1015    False
# 1016    False
# 1017     True
# 1018     True
# 1019    False
# Name: sim, Length: 982, dtype: bool

# %%
has_irbaster = df['sim'].str.contains('IR Blaster')
has_irbaster.value_counts()
# Out:
# sim
# False    824
# True     158
# Name: count, dtype: int64

# %%
# now insert the coloumns
df.insert(6,'has_5g',has_5g)
df.insert(7,'has_nfc',has_nfc)
df.insert(8,'has_ir_blaster',has_irbaster)

# %%
df
# Out:
#       index brand_names                            model  price  rating  \
# 0         2     oneplus                    OnePlus 11 5G  54999    89.0
# 1         3     oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4     samsung            Samsung Galaxy A14 5G  16499    75.0
# 3         5    motorola             Motorola Moto G62 5G  14999    81.0
# 4         6      realme               Realme 10 Pro Plus  24999    82.0
# ...     ...         ...                              ...    ...     ...
# 1015   1017    motorola       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018       honor                      Honor X8 5G  14990    75.0
# 1017   1019        poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020    motorola             Motorola Moto G91 5G  19990    80.0
# 1019   1021     samsung           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  has_5g  has_nfc  \
# ...

# %% [markdown]
# ## processor
# it have 3 pieces of information
# - processor name
# - processor kitna core ka ha dual,quartar,hex,octo
# - processor speed

# %% [markdown]
# We create the 4 columns
# - processor name
# - processor brand
# - number of core in processor
# - speed of the processsor

# %%
df['processor'].str.split(',')
# Out:
# 0       [Snapdragon 8 Gen2,  Octa Core,  3.2 GHz Proce...
# 1        [Snapdragon 695,  Octa Core,  2.2 GHz Processor]
# 2           [Exynos 1330,  Octa Core,  2.4 GHz Processor]
# 3       [Snapdragon  695,  Octa Core,  2.2 GHz Processor]
# 4        [Dimensity 1080,  Octa Core,  2.6 GHz Processor]
#                               ...
# 1015    [Snapdragon 8 Gen1,  Octa Core,  3 GHz Processor]
# 1016    [Snapdragon  480+,  Octa Core,  2.2 GHz Proces...
# 1017    [Dimensity 8100,  Octa Core,  2.85 GHz Processor]
# 1018     [Snapdragon 695,  Octa Core,  2.2 GHz Processor]
# 1019                                [Octa Core Processor]
# Name: processor, Length: 982, dtype: object

# %%
processor_name = df['processor'].str.split(',').str.get(0)
processor_name
# Out:
# 0         Snapdragon 8 Gen2
# 1            Snapdragon 695
# 2               Exynos 1330
# 3           Snapdragon  695
# 4            Dimensity 1080
#                ...
# 1015      Snapdragon 8 Gen1
# 1016       Snapdragon  480+
# 1017         Dimensity 8100
# 1018         Snapdragon 695
# 1019    Octa Core Processor
# Name: processor, Length: 982, dtype: object

# %%
num_cores = df['processor'].str.split(',').str.get(1)
num_cores
# Out:
# 0        Octa Core
# 1        Octa Core
# 2        Octa Core
# 3        Octa Core
# 4        Octa Core
#            ...
# 1015     Octa Core
# 1016     Octa Core
# 1017     Octa Core
# 1018     Octa Core
# 1019           NaN
# Name: processor, Length: 982, dtype: object

# %%
processor_speed = df['processor'].str.split(',').str.get(2)
processor_speed
# Out:
# 0         3.2 GHz Processor
# 1         2.2 GHz Processor
# 2         2.4 GHz Processor
# 3         2.2 GHz Processor
# 4         2.6 GHz Processor
#                ...
# 1015        3 GHz Processor
# 1016      2.2 GHz Processor
# 1017     2.85 GHz Processor
# 1018      2.2 GHz Processor
# 1019                    NaN
# Name: processor, Length: 982, dtype: object

# %%
# now insert this columns
df.insert(10,'processor_name',processor_name)
df.insert(11,'num_cores',num_cores)
df.insert(12,'processor_speed',processor_speed)

# %%
df.head()
# Out:
#    index brand_names                      model  price  rating  \
# 0      2     oneplus              OnePlus 11 5G  54999    89.0
# 1      3     oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4     samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5    motorola       Motorola Moto G62 5G  14999    81.0
# 4      6      realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# ...

# %%
df['processor_name'].value_counts()
# Out:
# processor_name
# Dimensity 700 5G        29
# Helio P35               28
# Snapdragon 8+ Gen1      26
# Snapdragon 8 Gen2       23
# Snapdragon 695          23
#                         ..
# Google  Tensor G2        1
# Snapdragon  8+ Gen1      1
# Snapdragon  720G         1
# Snapdragon 888+          1
# Google  Tensor 3         1
# Name: count, Length: 247, dtype: int64

# %%
# we do first strip operation
df['processor_name'] = df['processor_name'].str.strip()
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_14972\1321582111.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['processor_name'] = df['processor_name'].str.strip()

# %%
df[df['processor_name'].str.contains('Core')]
# Out:
#       index brand_names                                 model  price  rating  \
# 118     120       tesla                        Tesla Pi Phone  69999    83.0
# 143     145         jio                           Jio Phone 3   4499     NaN
# 188     190       ikall                         iKall Z19 Pro   8099    60.0
# 201     203     samsung                    Samsung Galaxy A13  14450    75.0
# 309     311     samsung  Samsung Galaxy A13 (4GB RAM + 128GB)  14999    75.0
# 315     317        itel                          itel S16 Pro   6990     NaN
# 496     498     samsung                    Samsung Galaxy A15  15990    63.0
# 529     531     samsung                    Samsung Galaxy F14  14990    67.0
# 587     589     samsung  Samsung Galaxy A13 (6GB RAM + 128GB)  16499    78.0
# 758     760       ikall                             iKall Z19   7999    61.0
# 778     780       tecno                   Tecno Spark Go 2022   6249    61.0
# ...

# %%
# we have have to do shifting

# %%
df[df['processor_name'].str.contains('Core')][[ 'processor_name', 'num_cores','processor_speed']]
# Out:
#            processor_name           num_cores processor_speed
# 118   Octa Core Processor                 NaN             NaN
# 143             Quad Core   1.4 GHz Processor             NaN
# 188             Quad Core   1.6 GHz Processor             NaN
# 201             Octa Core     2 GHz Processor             NaN
# 309             Octa Core     2 GHz Processor             NaN
# 315             Quad Core   1.3 GHz Processor             NaN
# 496   Octa Core Processor                 NaN             NaN
# 529   Octa Core Processor                 NaN             NaN
# 587             Octa Core     2 GHz Processor             NaN
# 758             Quad Core   1.6 GHz Processor             NaN
# 778             Octa Core   2.2 GHz Processor             NaN
# 794             Quad Core   1.3 GHz Processor             NaN
# 825   Octa Core Processor                 NaN             NaN
# 826   Octa Core Processor                 NaN             NaN
# ...

# %%
# lets do shifting 
temp_df = df[df['processor_name'].str.contains('Core')][[ 'processor_name', 'num_cores','processor_speed']].shift(1,axis=1)
temp_df
# Out:
#      processor_name            num_cores     processor_speed
# 118            None  Octa Core Processor                 NaN
# 143            None            Quad Core   1.4 GHz Processor
# 188            None            Quad Core   1.6 GHz Processor
# 201            None            Octa Core     2 GHz Processor
# 309            None            Octa Core     2 GHz Processor
# 315            None            Quad Core   1.3 GHz Processor
# 496            None  Octa Core Processor                 NaN
# 529            None  Octa Core Processor                 NaN
# 587            None            Octa Core     2 GHz Processor
# 758            None            Quad Core   1.6 GHz Processor
# 778            None            Octa Core   2.2 GHz Processor
# 794            None            Quad Core   1.3 GHz Processor
# 825            None  Octa Core Processor                 NaN
# 826            None  Octa Core Processor                 NaN
# ...

# %%
temp_df.values
# Out:
# array([[None, 'Octa Core Processor', nan],
#        [None, 'Quad Core', ' 1.4\u2009GHz Processor'],
#        [None, 'Quad Core', ' 1.6\u2009GHz Processor'],
#        [None, 'Octa Core', ' 2\u2009GHz Processor'],
#        [None, 'Octa Core', ' 2\u2009GHz Processor'],
#        [None, 'Quad Core', ' 1.3\u2009GHz Processor'],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core', ' 2\u2009GHz Processor'],
#        [None, 'Quad Core', ' 1.6\u2009GHz Processor'],
#        [None, 'Octa Core', ' 2.2\u2009GHz Processor'],
#        [None, 'Quad Core', ' 1.3\u2009GHz Processor'],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core Processor', nan],
#        [None, 'Octa Core', ' 1.8\u2009GHz Processor'],
#        [None, 'Quad Core', ' 1.3\u2009GHz Processor'],
# ...

# %%
# before 
df.loc[temp_df.index,['processor_name', 'num_cores','processor_speed']]
# Out:
#            processor_name           num_cores processor_speed
# 118   Octa Core Processor                 NaN             NaN
# 143             Quad Core   1.4 GHz Processor             NaN
# 188             Quad Core   1.6 GHz Processor             NaN
# 201             Octa Core     2 GHz Processor             NaN
# 309             Octa Core     2 GHz Processor             NaN
# 315             Quad Core   1.3 GHz Processor             NaN
# 496   Octa Core Processor                 NaN             NaN
# 529   Octa Core Processor                 NaN             NaN
# 587             Octa Core     2 GHz Processor             NaN
# 758             Quad Core   1.6 GHz Processor             NaN
# 778             Octa Core   2.2 GHz Processor             NaN
# 794             Quad Core   1.3 GHz Processor             NaN
# 825   Octa Core Processor                 NaN             NaN
# 826   Octa Core Processor                 NaN             NaN
# ...

# %%
# apply the operation of assign it 
df.loc[temp_df.index,['processor_name', 'num_cores','processor_speed']] = temp_df.values

# %%
# after check your opertion 
df.loc[temp_df.index,['processor_name', 'num_cores','processor_speed']]
# Out:
#      processor_name            num_cores     processor_speed
# 118            None  Octa Core Processor                 NaN
# 143            None            Quad Core   1.4 GHz Processor
# 188            None            Quad Core   1.6 GHz Processor
# 201            None            Octa Core     2 GHz Processor
# 309            None            Octa Core     2 GHz Processor
# 315            None            Quad Core   1.3 GHz Processor
# 496            None  Octa Core Processor                 NaN
# 529            None  Octa Core Processor                 NaN
# 587            None            Octa Core     2 GHz Processor
# 758            None            Quad Core   1.6 GHz Processor
# 778            None            Octa Core   2.2 GHz Processor
# 794            None            Quad Core   1.3 GHz Processor
# 825            None  Octa Core Processor                 NaN
# 826            None  Octa Core Processor                 NaN
# ...

# %%
# now check all processor 
df[df['processor_name'] == '(28 nm)']
# Out:
#      index brand_names                    model  price  rating  \
# 856    858     samsung  Samsung Galaxy A01 Core   4999     NaN
#
#                                 sim  has_5g  has_nfc  has_ir_blaster  \
# 856  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
#
#                                  processor processor_name   num_cores  \
# 856  (28 nm), Quad Core, 1.5 GHz Processor        (28 nm)   Quad Core
#
#         processor_speed                      ram           battery  \
# 856   1.5 GHz Processor  1 GB RAM, 16 GB inbuilt  3000 mAh Battery
#
#                                display                         camera  \
# 856  5.3 inches, 720 x 1480 px Display  8 MP Rear & 5 MP Front Camera
#
#                       card           os
# 856  Memory Card Supported  Android v10

# %%
# before .
df.loc[856,'processor_name']
# Out:
# '(28 nm)'

# %%
# lets apply the assign operation.
df.loc[856,'processor_name'] = 'Mediatek MT6739'

# %%
df.loc[856,'processor_name']
# Out:
# 'Mediatek MT6739'

# %% [markdown]
# now make a new column called processor brand .

# %%
df['processor_name'].str.split(' ')
# Out:
# 0       [Snapdragon, 8, Gen2]
# 1           [Snapdragon, 695]
# 2              [Exynos, 1330]
# 3         [Snapdragon, , 695]
# 4           [Dimensity, 1080]
#                 ...
# 1015    [Snapdragon, 8, Gen1]
# 1016     [Snapdragon, , 480+]
# 1017        [Dimensity, 8100]
# 1018        [Snapdragon, 695]
# 1019                     None
# Name: processor_name, Length: 982, dtype: object

# %%
df['processor_name'].str.split(' ').str.get(0).str.lower()
# Out:
# 0       snapdragon
# 1       snapdragon
# 2           exynos
# 3       snapdragon
# 4        dimensity
#            ...
# 1015    snapdragon
# 1016    snapdragon
# 1017     dimensity
# 1018    snapdragon
# 1019          None
# Name: processor_name, Length: 982, dtype: object

# %%
processor_brand= df['processor_name'].str.split(' ').str.get(0).str.lower()
processor_brand
# Out:
# 0       snapdragon
# 1       snapdragon
# 2           exynos
# 3       snapdragon
# 4        dimensity
#            ...
# 1015    snapdragon
# 1016    snapdragon
# 1017     dimensity
# 1018    snapdragon
# 1019          None
# Name: processor_name, Length: 982, dtype: object

# %%
df.insert(11,'processor_brand',processor_brand)

# %%
df.head()
# Out:
#    index brand_names                      model  price  rating  \
# 0      2     oneplus              OnePlus 11 5G  54999    89.0
# 1      3     oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4     samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5    motorola       Motorola Moto G62 5G  14999    81.0
# 4      6      realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# ...

# %%
# lets check the num cores
df['num_cores'].value_counts()
# Out:
# num_cores
#  Octa Core              865
#  Hexa Core               31
#  Quad Core               31
#  Octa Core Processor     19
# Octa Core Processor       9
#  Hexa Core Processor      8
# Quad Core                 6
# Octa Core                 5
#  Dual Core                1
# Name: count, dtype: int64

# %%
df['num_cores'] = df['num_cores'].str.strip()
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_14972\1868154006.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_cores'] = df['num_cores'].str.strip()

# %%
df['num_cores'].value_counts()
# Out:
# num_cores
# Octa Core              870
# Quad Core               37
# Hexa Core               31
# Octa Core Processor     28
# Hexa Core Processor      8
# Dual Core                1
# Name: count, dtype: int64

# %%
# replace it  the octo core
df['num_cores'] = df['num_cores'].str.replace('Octa Core Processor','Octa Core')
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_14972\1170573373.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_cores'] = df['num_cores'].str.replace('Octa Core Processor','Octa Core')

# %%
# replace it hexa core
df['num_cores'] = df['num_cores'].str.replace('Hexa Core Processor','Hexa Core')
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_14972\1822141873.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_cores'] = df['num_cores'].str.replace('Hexa Core Processor','Hexa Core')

# %%
df['num_cores'].value_counts()
# Out:
# num_cores
# Octa Core    898
# Hexa Core     39
# Quad Core     37
# Dual Core      1
# Name: count, dtype: int64

# %%
# wow full clean table so you can do analysis on it.

# %%
# now lets anlysis the processor speed

# %%
df['processor_speed'].value_counts()
# Out:
# processor_speed
# 2 GHz Processor       146
# 2.2 GHz Processor     134
# 2.4 GHz Processor     128
# 3.2 GHz Processor      94
# 2.3 GHz Processor      86
# 3 GHz Processor        53
# 2.84 GHz Processor     36
# 2.05 GHz Processor     28
# 2.5 GHz Processor      23
# 1.8 GHz Processor      23
# 1.6 GHz Processor      20
# 2.85 GHz Processor     19
# 3.22 GHz Processor     18
# 3.1 GHz Processor      15
# 2.6 GHz Processor      14
# 2.9 GHz Processor      13
# 1.82 GHz Processor     10
# 1.3 GHz Processor      10
# 2.73 GHz Processor      9
# 2.8 GHz Processor       9
# 3.05 GHz Processor      8
# 2.36 GHz Processor      8
# 2.7 GHz Processor       5
# 1.4 GHz Processor       5
# 2.65 GHz Processor      5
# 1.5 GHz Processor       4
# 2.96 GHz Processor      3
# 2.86 GHz Processor      3
# 1.1 GHz Processor       2
# 3.13 GHz Processor      2
# 2.35 GHz Processor      1
# 2.37 GHz Processor      1
# 1.99 GHz Processor      1
# 1.95 GHz Processor      1
# 2.1 GHz Processor       1
# ...

# %%
# now huma gega hertz ya number chaya . 
# word lika hona ki jarruat nahi ha 
df['processor_speed'].str.strip().str.split()
# Out:
# 0        [3.2, GHz, Processor]
# 1        [2.2, GHz, Processor]
# 2        [2.4, GHz, Processor]
# 3        [2.2, GHz, Processor]
# 4        [2.6, GHz, Processor]
#                  ...
# 1015       [3, GHz, Processor]
# 1016     [2.2, GHz, Processor]
# 1017    [2.85, GHz, Processor]
# 1018     [2.2, GHz, Processor]
# 1019                       NaN
# Name: processor_speed, Length: 982, dtype: object

# %%
# isma unicode character ha for split lakin na default unicdoe par hi kar diya

df['processor_speed'].str.strip().str.split().str.get(0)
# Out:
# 0        3.2
# 1        2.2
# 2        2.4
# 3        2.2
# 4        2.6
#         ...
# 1015       3
# 1016     2.2
# 1017    2.85
# 1018     2.2
# 1019     NaN
# Name: processor_speed, Length: 982, dtype: object

# %%
df['processor_speed'].str.strip().str.split().str.get(0).astype(np.float64)
# Out:
# 0       3.20
# 1       2.20
# 2       2.40
# 3       2.20
# 4       2.60
#         ...
# 1015    3.00
# 1016    2.20
# 1017    2.85
# 1018    2.20
# 1019     NaN
# Name: processor_speed, Length: 982, dtype: float64

# %%
# before
df['processor_speed']
# Out:
# 0         3.2 GHz Processor
# 1         2.2 GHz Processor
# 2         2.4 GHz Processor
# 3         2.2 GHz Processor
# 4         2.6 GHz Processor
#                ...
# 1015        3 GHz Processor
# 1016      2.2 GHz Processor
# 1017     2.85 GHz Processor
# 1018      2.2 GHz Processor
# 1019                    NaN
# Name: processor_speed, Length: 982, dtype: object

# %%
# now assign it to processor 
df['processor_speed'] = df['processor_speed'].str.strip().str.split().str.get(0).astype(np.float64)
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_14972\632766245.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['processor_speed'] = df['processor_speed'].str.strip().str.split().str.get(0).astype(np.float64)

# %%
df['processor_speed']
# Out:
# 0       3.20
# 1       2.20
# 2       2.40
# 3       2.20
# 4       2.60
#         ...
# 1015    3.00
# 1016    2.20
# 1017    2.85
# 1018    2.20
# 1019     NaN
# Name: processor_speed, Length: 982, dtype: float64

# %%
# deko abhi na upar ek matrix ki value ko dursa matrix ki value sa replace kiya
# aor hamna ek scaler ko dursa scaler sa replace kiya

# %% [markdown]
# ## ram
# ram have two things
# - ram and internal memory
# - task to to make two new columns

# %%
df['ram']
# Out:
# 0       12 GB RAM, 256 GB inbuilt
# 1        6 GB RAM, 128 GB inbuilt
# 2         4 GB RAM, 64 GB inbuilt
# 3        6 GB RAM, 128 GB inbuilt
# 4        6 GB RAM, 128 GB inbuilt
#                   ...
# 1015     8 GB RAM, 128 GB inbuilt
# 1016     6 GB RAM, 128 GB inbuilt
# 1017     8 GB RAM, 256 GB inbuilt
# 1018     6 GB RAM, 128 GB inbuilt
# 1019     8 GB RAM, 128 GB inbuilt
# Name: ram, Length: 982, dtype: object

# %%
df['ram'].str.split()
# Out:
# 0       [12, GB, RAM,, 256, GB, inbuilt]
# 1        [6, GB, RAM,, 128, GB, inbuilt]
# 2         [4, GB, RAM,, 64, GB, inbuilt]
# 3        [6, GB, RAM,, 128, GB, inbuilt]
# 4        [6, GB, RAM,, 128, GB, inbuilt]
#                       ...
# 1015     [8, GB, RAM,, 128, GB, inbuilt]
# 1016     [6, GB, RAM,, 128, GB, inbuilt]
# 1017     [8, GB, RAM,, 256, GB, inbuilt]
# 1018     [6, GB, RAM,, 128, GB, inbuilt]
# 1019     [8, GB, RAM,, 128, GB, inbuilt]
# Name: ram, Length: 982, dtype: object

# %%
ram_capacity = df['ram'].str.split().str.get(0).astype(np.int32)
ram_capacity
# Out:
# 0       12
# 1        6
# 2        4
# 3        6
# 4        6
#         ..
# 1015     8
# 1016     6
# 1017     8
# 1018     6
# 1019     8
# Name: ram, Length: 982, dtype: int32

# %%
# ram ko insert karo
df.insert(15,'ram_capacity',ram_capacity)

# %%
df.head()
# Out:
#    index brand_names                      model  price  rating  \
# 0      2     oneplus              OnePlus 11 5G  54999    89.0
# 1      3     oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4     samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5    motorola       Motorola Moto G62 5G  14999    81.0
# 4      6      realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... processor_brand  \
# ...

# %%
internal_memory = df['ram'].str.split().str.get(3).astype(np.float32)
internal_memory
# Out:
# 0       256.0
# 1       128.0
# 2        64.0
# 3       128.0
# 4       128.0
#         ...
# 1015    128.0
# 1016    128.0
# 1017    256.0
# 1018    128.0
# 1019    128.0
# Name: ram, Length: 982, dtype: float32

# %%
df.insert(16,'internal_memory',internal_memory)

# %%
df.head()
# Out:
#    index brand_names                      model  price  rating  \
# 0      2     oneplus              OnePlus 11 5G  54999    89.0
# 1      3     oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4     samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5    motorola       Motorola Moto G62 5G  14999    81.0
# 4      6      realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ...  num_cores  \
# ...

# %%
df[df['ram_capacity'] == 1]
# Out:
#      index brand_names                    model  price  rating  \
# 399    401        itel                 itel P36   6490     NaN
# 477    479        vivo                 Vivo Y25   7499     NaN
# 735    737       tecno           Tecno Pop 5 Go   6999     NaN
# 744    746        itel                 itel S16   5990     NaN
# 794    796        itel                 itel A56   5490     NaN
# 856    858     samsung  Samsung Galaxy A01 Core   4999     NaN
# 907    909        itel             Itel A23 Pro   3999     NaN
#
#                                 sim  has_5g  has_nfc  has_ir_blaster  \
# 399  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 477         Dual Sim, 3G, 4G, Wi-Fi   False    False           False
# 735             Dual Sim, 3G, Wi-Fi   False    False           False
# 744  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 794  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# ...

# %%
df[df['ram_capacity'] > 16]
# Out:
#      index brand_names                             model   price  rating  \
# 271    273       nokia                 Nokia 2720 V Flip    6199     NaN
# 280    282        asus           Asus ROG Phone 6 Pro 5G   89999    88.0
# 410    412        asus                  Asus ROG Phone 7   75990    87.0
# 439    441       apple            Apple iPhone SE 3 2022   43900     NaN
# 483    485      huawei  Huawei Mate 50 RS Porsche Design  239999    81.0
# 486    488       nokia                     Nokia 8000 4G    6899     NaN
# 627    629       nokia                      Nokia 225 4G    3589     NaN
# 762    764       apple                 Apple iPhone SE 4   49990    60.0
#
#                                                  sim  has_5g  has_nfc  \
# 271                   Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False
# 280          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 410          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# ...

# %%
# 18 wala tik ha tho
df[(df['ram_capacity'] > 16) & (df['ram_capacity'] != 18)]
# Out:
#      index brand_names                             model   price  rating  \
# 271    273       nokia                 Nokia 2720 V Flip    6199     NaN
# 439    441       apple            Apple iPhone SE 3 2022   43900     NaN
# 483    485      huawei  Huawei Mate 50 RS Porsche Design  239999    81.0
# 486    488       nokia                     Nokia 8000 4G    6899     NaN
# 627    629       nokia                      Nokia 225 4G    3589     NaN
# 762    764       apple                 Apple iPhone SE 4   49990    60.0
#
#                                                  sim  has_5g  has_nfc  \
# 271                   Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster   False     True
# 486                          Dual Sim, 3G, 4G, Wi-Fi   False    False
# 627                          Dual Sim, 3G, 4G, VoLTE   False    False
# ...

# %%
# before
df.loc[[439,762],['ram_capacity','internal_memory']]
# Out:
#      ram_capacity  internal_memory
# 439            64              NaN
# 762            64              NaN

# %%
# assign the matrix
df.loc[[439,762],['ram_capacity','internal_memory']] = [[4,64],[4,64]]

# %%
# after
df.loc[[439,762],['ram_capacity','internal_memory']]
# Out:
#      ram_capacity  internal_memory
# 439             4             64.0
# 762             4             64.0

# %%
df[df['ram_capacity'] >= 16]
# Out:
#      index brand_names                             model   price  rating  \
# 17      19        oppo              OPPO Reno 9 Pro Plus   45999    86.0
# 118    120       tesla                    Tesla Pi Phone   69999    83.0
# 141    143        oppo                OPPO Reno 9 Pro 5G   39999    86.0
# 271    273       nokia                 Nokia 2720 V Flip    6199     NaN
# 280    282        asus           Asus ROG Phone 6 Pro 5G   89999    88.0
# 308    310     oneplus    OnePlus 10T (16GB RAM + 256GB)   55999    87.0
# 320    322        iqoo        iQOO 11 (16GB RAM + 256GB)   64999    89.0
# 410    412        asus                  Asus ROG Phone 7   75990    87.0
# 445    447        asus   Asus ROG Phone 6 Batman Edition   72999    88.0
# 463    465        oppo                  OPPO Reno 10 Pro   42990    86.0
# 483    485      huawei  Huawei Mate 50 RS Porsche Design  239999    81.0
# 486    488       nokia                     Nokia 8000 4G    6899     NaN
# ...
