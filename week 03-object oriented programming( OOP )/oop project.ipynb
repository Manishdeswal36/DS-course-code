# %%
# we use pratice-ds 
#api key = d87230ff2dfe37a7f8089a125d3989b07cb0fe21

# %% [markdown]
# Install libarary

# %%
# %pip install nlpcloud
# Out:
# Collecting nlpcloudNote: you may need to restart the kernel to use updated packages.
#
#   Downloading nlpcloud-1.1.46-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: requests in c:\users\sumit\miniconda3\envs\pratice_ds\lib\site-packages (from nlpcloud) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sumit\miniconda3\envs\pratice_ds\lib\site-packages (from requests->nlpcloud) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sumit\miniconda3\envs\pratice_ds\lib\site-packages (from requests->nlpcloud) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sumit\miniconda3\envs\pratice_ds\lib\site-packages (from requests->nlpcloud) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sumit\miniconda3\envs\pratice_ds\lib\site-packages (from requests->nlpcloud) (2023.11.17)
# Installing collected packages: nlpcloud
# Successfully installed nlpcloud-1.1.46

# %%
# 3 steps
# open notebook
# download Nlpclodu library
# make account on Nlpcloud

# %% [markdown]
# # Create Structure  of app

# %% [markdown]
# # flow of program
# - create a class name NLPapp
# - create constructore
# - create a dict with name database where we store user data
# - make your attributies private
# - in Our class we have 2 level menu
# - First level menu
#     - Registration
#     - login
#     - exit
# - Second level menu
#     - Named Entity Recogination
#     - language identification
#     - Sentiment Analysis
# - why  make all attribute and method private
#     - Because hum sara kam menu ka through karwana chata ha tho isliya apko method ko bhar sa call karna ki jarrot nhi pada gi

# %% [markdown]
# ## menu

# %%
class NLPapp:
    def __init__(self) -> None:
    # make class attributies private by double underscore
        self.__database = {}
    
    
    def __first_menu(self):
        first_input = input("""
        Hello How would you like to procced
        1. Not a Member ? Register
        2. Already Member ? login
        3. Galti sa aa gaya ? Exit 
            """)

# %% [markdown]
# ## menu with Conditionals
# if user click on  the button then function call execute

# %%
class NLPapp:
    def __init__(self) -> None:
    # make class attributies private by double underscore
        self.__database = {}
    
    
    def __first_menu(self):
        first_input = input("""
        Hello How would you like to procced
        1. Not a Member ? Register
        2. Already Member ? login
        3. Galti sa aa gaya ? Exit 
            """)
        
        if first_input =='1':
            self.__register()
        elif first_input =='2':
            self.__login()
        else:
            exit()
        
    def __register(self):
        pass
    def __login(self):
        pass
    def exit(self):
        pass

# %% [markdown]
# ## check code of menu
# we make skeletion code

# %%
class NLPapp:
    def __init__(self) -> None:
    # make class attributies private by double underscore
        self.__database = {}
        self.__first_menu() # call menu from the constructor 
    # so wehen object create it called 
    def __first_menu(self):
        first_input = input("""
        Hello How would you like to procced
        1. Not a Member ? Register
        2. Already Member ? login
        3. Galti sa aa gaya ? Exit 
            """)
        
        if first_input =='1':
            self.__register()
        elif first_input =='2':
            self.__login()
        else:
            exit()
        
    def __register(self):
        print('Register success fully ')
    def __login(self):
        print('logic successfully ')
    def exit(self):
        pass

sample_object = NLPapp()
# Out:
# logic successfully

# %% [markdown]
# ## Register function

# %%
class NLPapp:
    
    def __init__(self) -> None:
    # make class attributies private by double underscore
        self.__database = {}
        self.__first_menu() 
        
    def __first_menu(self):
        first_input = input("""
        Hello How would you like to procced
        1. Not a Member ? Register
        2. Already Member ? login
        3. Galti sa aa gaya ? Exit 
            """)
        
        if first_input =='1':
            self.__register()
        elif first_input =='2':
            self.__login()
        else:
            exit()
        
    def __register(self):
        name = input('enter your name')
        email = input('enter your email')
        password = input('enter your password')
    # why not use self with this name
    # because ya sirf register function ma hi use hoga aor kisi ma nahi
    def __login(self):
        print('logic successfully ')
    def exit(self):
        pass

sample_object = NLPapp()

# %% [markdown]
# ## how we store data in Database

# %%
#dict = {key : value }
dict = {'abc@gmail.com':['Name','password']}
# why Because keys used be unique 
# so gmail is key and in value we have list of name and password

# %% [markdown]
# ## store user data in database

# %%
class NLPapp:
    
    def __init__(self) -> None:
    
        self.__database = {}
        self.__first_menu() 
        
    def __first_menu(self):
        first_input = input("""
        Hello How would you like to procced
        1. Not a Member ? Register
        2. Already Member ? login
        3. Galti sa aa gaya ? Exit 
            """)
        
        if first_input =='1':
            self.__register()
        elif first_input =='2':
            self.__login()
        else:
            exit()
        
    def __register(self):
        name = input('enter your name')
        email = input('enter your email')
        password = input('enter your password')
        print('your info-->',self.__database)
        
    # check if user email  is existed in database  yes or not
        if email in self.__database:
            print('email already existed')
            # add the user is database if email is new 
        else:
            self.__database[email]= [name,password]
            print('login on it ')
        
    def __login(self):
        print('logic successfully ')
    def exit(self):
        pass

sample_object = NLPapp()

# %% [markdown]
# ## login code

# %% [markdown]
# ### take email and password

# %%
class NLPapp:
    
    def __init__(self) -> None:
    
        self.__database = {}
        self.__first_menu() 
        
    def __first_menu(self):
        first_input = input("""
        Hello How would you like to procced
        1. Not a Member ? Register
        2. Already Member ? login
        3. Galti sa aa gaya ? Exit 
            """)
        
        if first_input =='1':
            self.__register()
        elif first_input =='2':
            self.__login()
        else:
            exit()
        
    def __register(self):
        name = input('enter your name')
        email = input('enter your email')
        password = input('enter your password')
        print('your info-->',self.__database)
        
    # check if user email  is existed in database  yes or not
        if email in self.__database:
            print('email already existed')
            # add the user is database if email is new 
        else:
            self.__database[email]= [name,password]
            print('login on it ')
        
    def __login(self):
        email = input('enter email')
        password = input('enter password ')
    def exit(self):
        pass

sample_object = NLPapp()

# %% [markdown]
# ### Verfiy email in database

# %%
class NLPapp:
    
    def __init__(self) -> None:
    
        self.__database = {}
        self.__first_menu() 
        
    def __first_menu(self):
        first_input = input("""
        Hello How would you like to procced
        1. Not a Member ? Register
        2. Already Member ? login
        3. Galti sa aa gaya ? Exit 
            """)
        
        if first_input =='1':
            self.__register()
        elif first_input =='2':
            self.__login()
        else:
            exit()
        
    def __register(self):
        name = input('enter your name')
        email = input('enter your email')
        password = input('enter your password')
        print('your info-->',self.__database)
        
    # check if user email  is existed in database  yes or not
        if email in self.__database:
            print('email already existed')
            # add the user is database if email is new 
        else:
            self.__database[email]= [name,password]
            print('login on it ')
        
    def __login(self):
        email = input('enter email')
        password = input('enter password ')
        
        if email in self.__database:
            # if email is correct 
            pass
        else:
            print('your email is not registere please first login')
            
    def exit(self):
        pass

sample_object = NLPapp()

# %% [markdown]
# ### then Verfify password

# %%
class NLPapp:
    
    def __init__(self) -> None:
    
        self.__database = {}
        self.__first_menu() 
        
    def __first_menu(self):
        first_input = input("""
        Hello How would you like to procced
        1. Not a Member ? Register
        2. Already Member ? login
        3. Galti sa aa gaya ? Exit 
            """)
        
        if first_input =='1':
            self.__register()
        elif first_input =='2':
            self.__login()
        else:
            exit()
        
    def __register(self):
        name = input('enter your name')
        email = input('enter your email')
        password = input('enter your password')
        print('your info-->',self.__database)
        
    # check if user email  is existed in database  yes or not
        if email in self.__database:
            print('email already existed')
            # add the user is database if email is new 
        else:
            self.__database[email]= [name,password]
            print('login on it ')
        
    def __login(self):
        login_email = input('enter email')
        login_password = input('enter password ')
        
        if login_email in self.__database:
            # if email is correct then check password
            # convert into list --> it is 2d list 
            db_values = list(self.__database.values())
            #if db_values[0][1] == login_password:
            if self.__database[login_email][1]== login_password:
                print('login succesful')
            else:
                print('Wrong passord ')
            
        else:
            print('your email is not registere please first login')
            
    def exit(self):
        pass

sample_object = NLPapp()

# %% [markdown]
# ### call to second menu

# %%
dictionry = {1:['hello',5,6]}
print(list(dictionry.values()))
b = 5 
type(dictionry.values())
a = list(dictionry.values())
a[0][1] == b
# Out:
# [['hello', 5, 6]]
# True

# %%
class NLPapp:
    
    def __init__(self) -> None:
    
        self.__database = {}
        self.__first_menu() 
        
    def __first_menu(self):
        first_input = input("""
        Hello How would you like to procced
        1. Not a Member ? Register
        2. Already Member ? login
        3. Galti sa aa gaya ? Exit 
            """)
        
        if first_input =='1':
            self.__register()
        elif first_input =='2':
            self.__login()
        else:
            exit()
        
    def __register(self):
        name = input('enter your name')
        email = input('enter your email')
        password = input('enter your password')
        print('your info-->',self.__database)
        
    # check if user email  is existed in database  yes or not
        if email in self.__database:
            print('email already existed')
            # add the user is database if email is new 
        else:
            self.__database[email]= [name,password]
            print('login on it ')
        
    def __login(self):
        login_email = input('enter email')
        login_password = input('enter password ')
        
        if login_email in self.__database:
            # if email is correct then check password
            # convert into list --> it is 2d list 
            db_values = list(self.__database.values())
            #if db_values[0][1] == login_password:
            if self.__database[login_email][1]== login_password:
                print('login succesful')
                self.__second_menu()
            else:
                print('Wrong passord try again ')
                self.__login()
            
        else:
            print('your email is not registere please first login')
        
    def exit(self):
        pass

sample_object = NLPapp()

# %% [markdown]
# # Second menu

# %% [markdown]
# ### Design menu

# %%
class NLPapp:
    
    def __init__(self) -> None:
    
        self.__database = {}
        self.__first_menu() 
        
    def __first_menu(self):
        first_input = input("""
        Hello How would you like to procced
        1. Not a Member ? Register
        2. Already Member ? login
        3. Galti sa aa gaya ? Exit 
            """)
    
        
        if first_input =='1':
            self.__register()
        elif first_input =='2':
            self.__login()
        else:
            exit()
            
    def __second_menu(self):
        second_input = input("""
        Hello what NLP task you want to do 
        3. Named Entity Recogination
        4. language detection
        5. Sentiment analysis
        6. logout 
            """)
        if second_input =='3':
            pass
        elif second_input == '4':
            pass
        elif second_input =='5':
            pass
        else:
            exit()
        
    def __register(self):
        name = input('enter your name')
        email = input('enter your email')
        password = input('enter your password')
        print('your info-->',self.__database)
        
    # check if user email  is existed in database  yes or not
        if email in self.__database:
            print('email already existed')
            # add the user is database if email is new 
        else:
            self.__database[email]= [name,password]
            print('login on it ')
        
    def __login(self):
        login_email = input('enter email')
        login_password = input('enter password ')
        
        if login_email in self.__database:
            # if email is correct then check password
            # convert into list --> it is 2d list 
            #db_values = list(self.__database.values())
            #if db_values[0][1] == login_password:
            if self.__database[login_email][1]== login_password:
                print('login succesful')
                self.__second_menu()
            else:
                print('Wrong passord try again ')
                self.__login()
            
        else:
            print('your email is not registere please first login')


sample_object = NLPapp()

# %% [markdown]
# ## call to function

# %%
class NLPapp:
    
    def __init__(self):
    
        self.__database = {}
        self.__first_menu() 
        
    def __first_menu(self):
        first_input = input("""
        Hello How would you like to procced
        1. Not a Member ? Register
        2. Already Member ? login
        3. Galti sa aa gaya ? Exit 
            """)
    
        
        if first_input =='1':
            self.__register()
        elif first_input =='2':
            self.__login()
        else:
            exit()
            
    def __second_menu(self):
        second_input = input("""
        Hello what NLP task you want to do 
        3. Named Entity Recogination
        4. language detection
        5. Sentiment analysis
        6. logout 
            """)
        if second_input =='3':
            self.__NER()
        elif second_input == '4':
            self.__language_detection()
        elif second_input =='5':
            self.__sentiment_analysis()
        elif second_input == '6':
            self.__logout()
        else:
            exit()
        
        
    def __register(self):
        name = input('enter your name')
        email = input('enter your email')
        password = input('enter your password')
        print('your info-->',self.__database)
        
    # check if user email  is existed in database  yes or not
        if email in self.__database:
            print('email already existed')
            # add the user is database if email is new 
        else:
            self.__database[email]= [name,password]
            print('login on it ')
        
    def __login(self):
        login_email = input('enter email')
        login_password = input('enter password ')
        
        if login_email in self.__database:
            # if email is correct then check password
            # convert into list --> it is 2d list 
            #db_values = list(self.__database.values())
            #if db_values[0][1] == login_password:
            if self.__database[login_email][1]== login_password:
                print('login succesful')
                self.__second_menu()
            else:
                print('Wrong passord try again ')
                self.__login()
            
        else:
            print('your email is not registere please first login')
            
    def __NER(self):
        pass
    def __language_detection(self):
        pass
    def __sentiment_analysis(self):
        pass
    def __logout(self):
        pass


sample_object = NLPapp()
