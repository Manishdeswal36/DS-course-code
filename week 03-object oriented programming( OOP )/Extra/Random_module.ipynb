# %%
import random
dictionary = {
    1:'a',
    2: 'b',
    3 : 'c',
    4 : 'd',
    5 : 'e'
}
dictionary_keys = random.choice(list(dictionary.keys()))
dictionary_value = random.choice(list(dictionary.values()))
dictionary_items = random.choice(list(dictionary.items()))
print(dictionary_keys,dictionary_value,dictionary_items)
# Out:
# 5 a (1, 'a')

# %%
def check():
    print(dictionary_keys)
    if dictionary_keys == 2:
        print('you win',)
    else:
        print('lose',dictionary_keys)
check()
# Out:
# 5
# lose 5
