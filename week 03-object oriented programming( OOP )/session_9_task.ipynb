# %% [markdown]
# ### `Problem-1:` Class inheritence
#
# Create a **Bus** child class that inherits from the Vehicle class. The default fare charge of any vehicle is seating capacity * 100. If Vehicle is Bus instance, we need to add an extra 10% on full fare as a maintenance charge. So total fare for bus instance will become the final amount = total fare + 10% of the total fare.
#
# Note: The bus seating capacity is 50. so the final fare amount should be 5500. You need to override the fare() method of a Vehicle class in Bus class.

# %%
class Vehicle:
    def __init__(self,seating_capacity):
        self.seating_capacity = seating_capacity
        
    def fare(self):
        return self.seating_capacity * 100
    
class Bus(Vehicle):
    
    def total_fare(self):
        return super().fare() + 0.1 *super().fare()

bus_object = Bus(50)
print(bus_object.fare())
print(bus_object.total_fare())
#bus_object.amount()
# Out:
# 5000
# 5500.0

# %%
bus_object.amount()
# Out:
# 5500.0

# %% [markdown]
# ### `Problem-2:` Class Inheritence
#
# Create a Bus class that inherits from the Vehicle class. Give the capacity argument of *Bus.seating_capacity()* a default value of 50.
#
# Use the following code for your parent Vehicle class.

# %%
# same ques like one

# %% [markdown]
# ### `Problem-3:` Write a program that has a class Point. Define another class Location which has two objects (Location & Destination) of class Point. Also define a function in Location that prints the reflection of Destination on the x axis.

# %%
class Point:
    def __init__(self, x,y ) -> None:
        self.x = x
        self.y = y
        
    def __str__(self) -> str:
        return 'point x: {},y: {}'.format(self.x,self.y)
    
class Location(Point):
    
    def __init__(self, x1, y1,x2,y2) -> None:
        self.source = Point(x1,y1)
        self.destination = Point(x2,y2)
        
    def show(self):
        print("source are ",self.source.__str__())
        print("destination are ",self.destination.__str__())
    
    # so first quardant to fourth quardant
    def reflection_on_Xaxis(self):
        self.destination.y = -self.destination.y
        print('Relection is',self.destination.__str__())
    

Location_object = Location(0,0,2,2)
print(Location_object.show())
# Out:
# source are  point x: 0,y: 0
# destination are  point x: 2,y: 2
# None

# %%
Location_object.reflection_on_Xaxis()
# Out:
# Relection is point x: 2,y: -2

# %% [markdown]
# ### `Problem-4:` Write a program that has an abstract class Polygon. Derive two classes Rectangle and Triamgle from Polygon and write methods to get the details of their dimensions and hence calculate the area.

# %%
from abc import ABC, abstractmethod
class Polygon(ABC):
    def __init__(self,sides) -> None:
        self.sides = sides
        
    
    @abstractmethod
    def num_of_sidess(self):
        print('tell the number of sidess ',)
        
class Rectangle(Polygon):
    def __init__(self, sides,length,breath) -> None:
        super().__init__(sides)
        self.length = length
        self.breath = breath
    
    def Rectangle_area(self):
        return self.length * self.breath
    
    def num_of_sidess(self):
        print('tell the number of sidess is four ',self.sides)
    
class Traingle(Polygon):
    def __init__(self, sides,base,height) -> None:
        super().__init__(sides)
        self.base = base
        self.height = height
        
        
    def num_of_sidess(self):
        print('the number of sidess is three is',self.sides)
        
    def triangle_area(self):
        return 0.5 * self.base * self.height

var1 = Traingle(3,2,10)
var1.triangle_area()
# Out:
# 10.0

# %% [markdown]
# ### `Problem-5:` Write a program with class Bill. The users have the option to pay the bill either by cheque or by cash. Use the inheritance to model this situation.

# %%
# one parent class have two childs hierachy 
class Bill:
    def __init__(self,name,bill_id,bill_amount) -> None:
        self.name = name
        self.bill_id = bill_id
        self.bill_amount = bill_amount

class Cheque(Bill):
    def __init__(self, name, bill_id, bill_amount,pay) -> None:
        super().__init__(name, bill_id, bill_amount)
        self.pay = pay
    def pay_amount(self):
        # think cases when payment amount is 
        # less payment bill please pay moreamount
        if self.pay > self.bill_amount:
            money_left_to_pay = self.pay-self.bill_amount
            print('please pay more mount.',money_left_to_pay)
        # more payment bill give back money
        elif self.pay < self.bill_amount:
            money_more_give_back = self.pay-self.bill_amount
            print('please pay more mount.',money_more_give_back)
        # if paymnent bill == bill amount bill successful
        #if self.pay == self.bill_amount:
        else:
            print('your bill amount pay successful')
class Cash(Bill):
    def __init__(self, name, bill_id, bill_amount,cash_pay) -> None:
        super().__init__(name, bill_id, bill_amount,)
        self.cash_pay = cash_pay
        
    def Cash_pay_amount(self):
        # less payment bill please pay moreamount
        if self.cash_pay > self.bill_amount:
            money_left_to_pay = self.cash_pay-self.bill_amount
            print('please pay more mount.',money_left_to_pay)
        # more payment bill give back money
        if self.cash_pay < self.bill_amount:
            money_more_give_back = self.cash_pay-self.bill_amount
            print('please return your more mount.',money_more_give_back)
        # if paymnent bill == bill amount bill successful
        #
        if self.cash_pay == self.bill_amount:
            print('your bill amount pay successful')

cash_bill_object =Cash('ram',101,2000,1800)
cash_bill_object.Cash_pay_amount()
# Out:
# please return your more mount. -200

# %% [markdown]
# ###`Q-6:` FlexibleDict
# As of now we are accessing values from dictionary with exact keys. Now we want to amend accessing values functionality. if a dict have key `1` (int) the even if we try to access values by giving `'1'` (1 as str) as key, we should get the same result and vice versa.
#
# Write a class `FlexibleDict` upon builtin `dict` class with above required functionality.
#
# Hint- `dict[key] => dict.__getitem__(key)`

# %% [markdown]
# Ex.
# ```
# fd = FlexibleDict()
# fd['a'] = 100
# print(fd['a']) # Like regular dict
#
# fd[5] = 500
# print(fd[5]) # Like regular dict
#
# fd[1] = 100
# print(fd['1']) # actual Key is int but still trying to access through str key.
# fd['1'] = 100
# print(fd[1])
#
# ```
# `Output:`
# ```
# 100
# 500
# 100
# 100
#
# ```

# %%
class flexibleDict:
    pass
