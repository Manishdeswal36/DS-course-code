# %%
# today we work on text data nlp analysis
# agar apka dataset ma coloumns text ha tho aap kasa basic nlp analysis kar sakta ho
# text based data ma kasa navigate karna using pandas

# %%
# this class on intersection of pandas and nlp 
# love it and very excited sapana par pahala kadam

# %%
# so tho jab aap nlp ma start karta ho 
# so you work on basic dataset like imbd movies review
# amozon review # whatsup chat analysis # twitter tweets

# %%
# so imbd dataset have two coloumns
# review
# sentiment of the movie 
# 50,000 movies ka review

# %%
# ek machine learning ya deep learning enginer ka kam hota ha ki vo future
# koi naya review diya jayaga tho vo automatically predict kar paya ga ki sentiment kiya ha
# nlp bhut jaga ha apka keyborad ma recommend karta ha words ko 
# email ma who email ko read karta ha aor spam ha ki nahi ha 
# wo bhi sentiment analysis kar raha ha

# %%
# deko amozon ,flipkart na ek product launch kiya
# aor us par 20,000 reviews aya ab koi bhi un reviews ko baad kar nahi padega amazon company ma
# wo ek sentiment model baneya
# aor bolega 70% are postive 30% are negative something like this

# %%
import pandas as pd
df = pd.read_csv('IMDB Dataset.csv')

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df.shape
# 2 col
# 50 thousand rows
# Out:
# (50000, 2)

# %%
# kisi ek movie ka review kasa dikta ha 
df['review'][0]
# Out:
# "One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the 
# ...

# %%
# huma kiya karna ha 
# imagine yourself you are working in a company
# company na apki team ko bola apko ek sentiment analysis system banana ha 
# wo revies pad ka bata paya reviews positive ha ki negative ha
# or apko apna model is data par train karna ha
# now you are the part of the team
# apko kam diya gaya ha
# data ko clean karna ,uska upar eda karna ,aor features create karna

# %%
# review  |sentiment
#   ---       +ve 
#   ---       -ve 
# .... 

#---------------------------
# you have to make a ml or dl model
# that you give a new review it can inference
# it is postive or negative
#---------------------------

# a_new_review | +ve/-ve
# ...

# %% [markdown]
# # model building steps
# 1. Data Gathering
# 2. Data Cleaning

# %% [markdown]
# ## Data gathering
# step is already done of 50 k movies

# %%
# so famous line in ml
# garbage in garabage out
# so your data is super clean for models

# %% [markdown]
# ## Data Cleaning
# 1. lowering
# 2. removing leading and trailing spaces
# 3. removing html tags
# 4. removing url
# 5. expanding abbreviations
# 6. spelling correction
# 7. punctuations
# 8. remove special characters

# %% [markdown]
# 1. lowering = sabhi words ko lowercase karna kahi capital kahi small hota ha
# 2. removing leading and trailing spaces = extra spaces ko remove karna
# 3. removing html tags= data gathering wala na web scraping kiya tha usma kuch html tags ha huma vo remove karna hoga
# 4. removing url = kyuki vo meaning ma contribute nahi karaga isliya remove url
# 5. expanding abbreviations => kahi does n't -> isko does not couldn't -> could not
# 6. spelling correction -> kahi par night ha aor user na nigh lika ml model isa alag treat karaga isliya
# 7. punctuations = ?,! ya meaning ma kuch contribute nahi karta so we remove
# 8. remove special characters = @, #,$

# %%
# ek given sentence ya word ha --sentiment-> uska meaning

# %% [markdown]
# ## Data Preprocessing
# aap data ko is format ma lata ho jissa us par machine learning model kam kar paya
# - tokenization
# - stopward removal
# - stemming

# %% [markdown]
# - tokonization -> breaks sentences into words or words into letters I am Energetic ->[I,am,Energetic]
# - stopward removal -> jasa(and,I have,could) ya meaning ma contribute nahi kar raha ha
# - stemming -> words ko root form ma la kar aa jata ho (dance,danced ,danced) ko dance ma convert karna

# %% [markdown]
# ## Eda
# `Explorarity Data analysis`

# %% [markdown]
# ## make features
# feature matlab coloumns you can create new coloumns for ml models
# one example is number of words.

# %%
# revies     number of words
# - r1              12
# - r2              3
# - r3              7
# ...

# %%
# may be this new col(feature) help our machine learning model
# aap esa kuch logic bana sakta ho ki postive reviews are short and negative are long.

# %% [markdown]
# ## vectorization
# machine learning models works only numbers. lakin hamra string english alphaets ma ha hama kuch jugaad lagana hoga aor usa numbers ma convert karna hoga. 50 thousand review ko numbers ma convert karna ha

# %% [markdown]
# various techniques are
# - bag of words
# - tf idf
# - word2vector

# %% [markdown]
# ## modeiling
# modeling ka matlab aap apna data ka upar alag alag machine learning  model or deep learning models try karta ho aor dekta ho konsa better perfrom kar raha ha .

# %% [markdown]
# ## evaluate
# aap best model ko select karta ho .

# %% [markdown]
# ## Deploy
# website ya app ma convert karka server par dal deta ho.

# %% [markdown]
# ## Monitar
# kuch gadbad hua usa dekna new data add karna

# %% [markdown]
# # What we do today
# 1. Data Gathering
# 2. Data cleaning
# 3. Data preprocessing
# 4. Eda
# 5. Make features
# 6. vectorization
# 7. modeling
# 8. evaluation
# 9. deploy
# 10. monitar

# %% [markdown]
# aap team ma ek data analyst ho tho aap step 6 tak kara ga.

# %% [markdown]
# we also use other libararies in today session because sara kam pandas nahi kar sakta scikit learn,nltk,textblob

# %% [markdown]
# hum pandas sa thoda aga aor nlp ka thoda picha ha

# %% [markdown]
# # check missing and duplicated data

# %% [markdown]
# ### check missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
# no missing values

# %% [markdown]
# ### check duplicated values

# %%
df.duplicated().sum()
# Out:
# np.int64(418)

# %%
# there are 418 duplicate values 
# now drop them 
df.drop_duplicates(inplace=True)

# %%
# after permanent drop values 
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [49582 rows x 2 columns]

# %%
df['review'].count()
# Out:
# np.int64(49582)

# %%
# we filter the data

# %% [markdown]
# # cleaning data

# %% [markdown]
# ### lowercase
# kuch capital letters ha kuch small letters ha who apko nahi chaya --> apko uniformaity chaya

# %%
# so pandas support vectorization
# one operation on multiple string 
df['review'].str.lower()
# Out:
# 0        one of the other reviewers has mentioned that ...
# 1        a wonderful little production. <br /><br />the...
# 2        i thought this was a wonderful way to spend ti...
# 3        basically there's a family where a little boy ...
# 4        petter mattei's "love in the time of money" is...
#                                ...
# 49995    i thought this movie did a down right good job...
# 49996    bad plot, bad dialogue, bad acting, idiotic di...
# 49997    i am a catholic taught in parochial elementary...
# 49998    i'm going to have to disagree with the previou...
# 49999    no one expects the star trek movies to be high...
# Name: review, Length: 49582, dtype: object

# %%
# make it permant by assign  it 
df['review'] = df['review'].str.lower()

# %% [markdown]
# ### remove trailing space
# apka data ma aga ya picha spaces aa sakta ha .

# %%
df['review'].str.strip()
# Out:
# 0        one of the other reviewers has mentioned that ...
# 1        a wonderful little production. <br /><br />the...
# 2        i thought this was a wonderful way to spend ti...
# 3        basically there's a family where a little boy ...
# 4        petter mattei's "love in the time of money" is...
#                                ...
# 49995    i thought this movie did a down right good job...
# 49996    bad plot, bad dialogue, bad acting, idiotic di...
# 49997    i am a catholic taught in parochial elementary...
# 49998    i'm going to have to disagree with the previou...
# 49999    no one expects the star trek movies to be high...
# Name: review, Length: 49582, dtype: object

# %%
# make it permanent by assigning it 
df['review'] = df['review'].str.strip()

# %% [markdown]
# ### remove html tags
# because user na webscrapping kiya usma kuch aa gaya hoga.

# %%
import re 
def remove_html(data):
    data = re.sub(pattern=r'<.*?>',repl='',string=data )
    return data

remove_html('<p>I am in focus and flow </p>,<br><img>')
# Out:
# 'I am in focus and flow ,'

# %%
df['review'].apply(remove_html)
# Out:
# 0        one of the other reviewers has mentioned that ...
# 1        a wonderful little production. the filming tec...
# 2        i thought this was a wonderful way to spend ti...
# 3        basically there's a family where a little boy ...
# 4        petter mattei's "love in the time of money" is...
#                                ...
# 49995    i thought this movie did a down right good job...
# 49996    bad plot, bad dialogue, bad acting, idiotic di...
# 49997    i am a catholic taught in parochial elementary...
# 49998    i'm going to have to disagree with the previou...
# 49999    no one expects the star trek movies to be high...
# Name: review, Length: 49582, dtype: object

# %%
# also use the replace function 
df['review'].str.replace(r'<.*?>','' )
# Out:
# 0        one of the other reviewers has mentioned that ...
# 1        a wonderful little production. <br /><br />the...
# 2        i thought this was a wonderful way to spend ti...
# 3        basically there's a family where a little boy ...
# 4        petter mattei's "love in the time of money" is...
#                                ...
# 49995    i thought this movie did a down right good job...
# 49996    bad plot, bad dialogue, bad acting, idiotic di...
# 49997    i am a catholic taught in parochial elementary...
# 49998    i'm going to have to disagree with the previou...
# 49999    no one expects the star trek movies to be high...
# Name: review, Length: 49582, dtype: object

# %%
# make in permant by reassign it 
df['review'] = df['review'].str.replace(r'<.*?>','',regex=True )

# %%
# ya pandas ka default function so it is fast and optimised

# %% [markdown]
# ### remove url

# %%
# it's something like 
# http://campusx.in www.campusx.in www.campusx.co.in

def remove_url(data):
    data=re.sub(r"https?://\S+|www\.\S+",'',data)
    return data

remove_url('to register and login in www.campusx.in')
# Out:
# 'to register and login in '

# %%
remove_html('this is testing https://campusx..in')
# Out:
# 'this is testing https://campusx..in'

# %%
df['review'].replace(r"https?://\S+|www\.\S+",'',regex=True)
# Out:
# 0        one of the other reviewers has mentioned that ...
# 1        a wonderful little production. the filming tec...
# 2        i thought this was a wonderful way to spend ti...
# 3        basically there's a family where a little boy ...
# 4        petter mattei's "love in the time of money" is...
#                                ...
# 49995    i thought this movie did a down right good job...
# 49996    bad plot, bad dialogue, bad acting, idiotic di...
# 49997    i am a catholic taught in parochial elementary...
# 49998    i'm going to have to disagree with the previou...
# 49999    no one expects the star trek movies to be high...
# Name: review, Length: 49582, dtype: object

# %%
## find the urls
df['review'].str.contains(r"https?://\S+|www\.\S+").sum()
# Out:
# np.int64(194)

# %%
# see the 195 urls
df[df['review'].str.contains(r"https?://\S+|www\.\S+")].values[0]
# Out:
# array(['mario lewis of the competitive enterprise institute has written a definitive 120-page point-by-point, line-by-line refutation of this mendacious film, which should be titled a convenient lie. the website address where his debunking report, which is titled "a skeptic\'s guide to an inconvenient truth" can be found at is :www.cei.org. a shorter 10-page version can be found at: www.cei.org/pdf/5539.pdf once you read those demolitions, you\'ll realize that alleged "global warming" is no more real or dangerous than the y2k scare of 1999, which gore also endorsed, as he did the pseudo-scientific film the day after tomorrow, which was based on a book written by alleged ufo abductee whitley strieber. as james "the amazing" randi does to psychics, and philip klass does to ufos, and gerald posner does to jfk conspir-idiocy theories, so does mario lewis does to al gore\'s movie and the whole "global warming" scam.',
#        'negative'], dtype=object)

# %%
# see the 195 urls
df[df['review'].str.contains(r"https?://\S+|www\.\S+")]
# Out:
#                                                   review sentiment
# 742    mario lewis of the competitive enterprise inst...  negative
# 907    following directly from where the story left o...  positive
# 1088   this quasi j-horror film followed a young woma...  negative
# 1137   i really think i should make my case and have ...  positive
# 1141   this show has to be my favorite out of all the...  positive
# ...                                                  ...       ...
# 48887  trite and unoriginal. it's like someone watche...  negative
# 49063  trick or treat, quickie review this zany romp ...  positive
# 49596  this is absolutely the best 80s cartoon ever, ...  positive
# 49637  if you liked the richard chamberlain version o...  positive
# 49951  "scientists at a remote lab experiment on (ins...  negative
#
# [194 rows x 2 columns]

# %%
# now permantely remove it 
df['review'] = df['review'].replace(r"https?://\S+|www\.\S+", '', regex=True)

# %%
# count thr urls 
df['review'].str.contains(r"https?://\S+|www\.\S+").sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### expanding abbreviations
# - doesn't ha tho --> does not
# - couldn't ha tho --> could not
# - you need a lot of big dictionary for it

# %%
def remove_abb(data):
    data = re.sub(r"he's", "he is", data)
    data = re.sub(r"there's", "there is", data)
    data = re.sub(r"We're", "We are", data)
    data = re.sub(r"That's", "That is", data)
    data = re.sub(r"won't", "will not", data)
    data = re.sub(r"they're", "they are", data)
    data = re.sub(r"Can't", "Cannot", data)
    data = re.sub(r"wasn't", "was not", data)
    data = re.sub(r"don\x89Ûªt", "do not", data)
    data= re.sub(r"aren't", "are not", data)
    data = re.sub(r"isn't", "is not", data)
    data = re.sub(r"What's", "What is", data)
    data = re.sub(r"haven't", "have not", data)
    data = re.sub(r"hasn't", "has not", data)
    data = re.sub(r"There's", "There is", data)
    data = re.sub(r"He's", "He is", data)
    data = re.sub(r"It's", "It is", data)
    data = re.sub(r"You're", "You are", data)
    data = re.sub(r"I'M", "I am", data)
    data = re.sub(r"shouldn't", "should not", data)
    data = re.sub(r"wouldn't", "would not", data)
    data = re.sub(r"i'm", "I am", data)
    data = re.sub(r"I\x89Ûªm", "I am", data)
    data = re.sub(r"I'm", "I am", data)
    data = re.sub(r"Isn't", "is not", data)
    data = re.sub(r"Here's", "Here is", data)
    data = re.sub(r"you've", "you have", data)
    data = re.sub(r"you\x89Ûªve", "you have", data)
    data = re.sub(r"we're", "we are", data)
    data = re.sub(r"what's", "what is", data)
    data = re.sub(r"couldn't", "could not", data)
    data = re.sub(r"we've", "we have", data)
    data = re.sub(r"it\x89Ûªs", "it is", data)
    data = re.sub(r"doesn\x89Ûªt", "does not", data)
    data = re.sub(r"It\x89Ûªs", "It is", data)
    data = re.sub(r"Here\x89Ûªs", "Here is", data)
    data = re.sub(r"who's", "who is", data)
    data = re.sub(r"I\x89Ûªve", "I have", data)
    data = re.sub(r"y'all", "you all", data)
    data = re.sub(r"can\x89Ûªt", "cannot", data)
    data = re.sub(r"would've", "would have", data)
    data = re.sub(r"it'll", "it will", data)
    data = re.sub(r"we'll", "we will", data)
    data = re.sub(r"wouldn\x89Ûªt", "would not", data)
    data = re.sub(r"We've", "We have", data)
    data = re.sub(r"he'll", "he will", data)
    data = re.sub(r"Y'all", "You all", data)
    data = re.sub(r"Weren't", "Were not", data)
    data = re.sub(r"Didn't", "Did not", data)
    data = re.sub(r"they'll", "they will", data)
    data = re.sub(r"they'd", "they would", data)
    data = re.sub(r"DON'T", "DO NOT", data)
    data = re.sub(r"That\x89Ûªs", "That is", data)
    data = re.sub(r"they've", "they have", data)
    data = re.sub(r"i'd", "I would", data)
    data = re.sub(r"should've", "should have", data)
    data = re.sub(r"You\x89Ûªre", "You are", data)
    data = re.sub(r"where's", "where is", data)
    data = re.sub(r"Don\x89Ûªt", "Do not", data)
    data = re.sub(r"we'd", "we would", data)
    data = re.sub(r"i'll", "I will", data)
    data = re.sub(r"weren't", "were not", data)
    data = re.sub(r"They're", "They are", data)
    data = re.sub(r"Can\x89Ûªt", "Cannot", data)
    data = re.sub(r"you\x89Ûªll", "you will", data)
    data = re.sub(r"I\x89Ûªd", "I would", data)
    data = re.sub(r"let's", "let us", data)
    data = re.sub(r"it's", "it is", data)
    data = re.sub(r"can't", "cannot", data)
    data = re.sub(r"don't", "do not", data)
    data = re.sub(r"you're", "you are", data)
    data = re.sub(r"i've", "I have", data)
    data = re.sub(r"that's", "that is", data)
    data = re.sub(r"i'll", "I will", data)
    data = re.sub(r"doesn't", "does not",data)
    data = re.sub(r"i'd", "I would", data)
    data = re.sub(r"didn't", "did not", data)
    data = re.sub(r"ain't", "am not", data)
    data = re.sub(r"you'll", "you will", data)
    data = re.sub(r"I've", "I have", data)
    data = re.sub(r"Don't", "do not", data)
    data = re.sub(r"I'll", "I will", data)
    data = re.sub(r"I'd", "I would", data)
    data = re.sub(r"Let's", "Let us", data)
    data = re.sub(r"you'd", "You would", data)
    data = re.sub(r"It's", "It is", data)
    data = re.sub(r"Ain't", "am not", data)
    data = re.sub(r"Haven't", "Have not", data)
    data = re.sub(r"Could've", "Could have", data)
    data = re.sub(r"youve", "you have", data)  
    data = re.sub(r"donå«t", "do not", data)
    
    return data

# %%
# testing of it . 
remove_abb(" I don't know and I couldn't tell you")
# Out:
# ' I do not know and I could not tell you'

# %%
df['review'] = df['review'].apply(remove_abb)

# %%
df['review']
# Out:
# 0        one of the other reviewers has mentioned that ...
# 1        a wonderful little production. the filming tec...
# 2        i thought this was a wonderful way to spend ti...
# 3        basically there is a family where a little boy...
# 4        petter mattei's "love in the time of money" is...
#                                ...
# 49995    i thought this movie did a down right good job...
# 49996    bad plot, bad dialogue, bad acting, idiotic di...
# 49997    i am a catholic taught in parochial elementary...
# 49998    I am going to have to disagree with the previo...
# 49999    no one expects the star trek movies to be high...
# Name: review, Length: 49582, dtype: object

# %% [markdown]
# ### spelling correction
# - input -> incorrect spelling
# - output -> correct speeling
# - ya khud ma ek model bana ha bhut bada task ha so we use the library usma ya feature ha

# %%
from textblob import TextBlob

our_text = 'hi I can drie at nigt'
TextBlob(our_text).correct().string
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 from textblob import TextBlob
#       3 our_text = 'hi I can drie at nigt'
#       4 TextBlob(our_text).correct().string
#
# ModuleNotFoundError: No module named 'textblob'

# %%
def spelling_correction(inp_text):
    return TextBlob(inp_text).correct().string
    
# df['review'] = df['review'].apply(spelling_correction)

# %%
# from textblob import TextBlob
# from functools import lru_cache

# @lru_cache(maxsize=50000)
# def correct_text_cached(text):
#     return str(TextBlob(text).correct())

# df['review'] = df['review'].apply(correct_text_cached)

# %% [markdown]
# ### puncatation

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_puctuation(text):
    
    for i in string.punctuation:
        if i in text:
            text = text.replace(i,'')
            
    return text

remove_puctuation('hi ! how are you ?')
# Out:
# 'hi  how are you '

# %%
# optimised code using vectorisatuib u

# %%
import pandas as pd
import string

# Create translation table
translator = str.maketrans('', '', string.punctuation)

# Apply it using vectorized str method
df['review'] = df['review'].str.translate(translator)

# %%
df['review']
# Out:
# 0        one of the other reviewers has mentioned that ...
# 1        a wonderful little production the filming tech...
# 2        i thought this was a wonderful way to spend ti...
# 3        basically there is a family where a little boy...
# 4        petter matteis love in the time of money is a ...
#                                ...
# 49995    i thought this movie did a down right good job...
# 49996    bad plot bad dialogue bad acting idiotic direc...
# 49997    i am a catholic taught in parochial elementary...
# 49998    I am going to have to disagree with the previo...
# 49999    no one expects the star trek movies to be high...
# Name: review, Length: 49582, dtype: object

# %%
# social media slangs like gn = good night
# inka koi file apko mil gaya google ya github ka
# aap ek project bano aor usa open source kar do 
# kuch bhi loophole mila usa use karo
# hamesa download nahi kabhi upload bhi karo.

# %% [markdown]
# ### remove special characters
# koi emoji wagara hota ,usko remove karna ya koi aor bhasa ko hota

# %%
# 90 percent nlp projects ma apko yahi cleaning karni padti ha

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## tokenization
# string ko list of string ma convert karaga

# %% [markdown]
# two types of tokization
# - word level
# - sentence level

# %%
import nltk
print(nltk.__version__)
# Out:
# 3.9.1

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sumit\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
print(nltk.data.path)
# Out:
# ['C:\\Users\\sumit/nltk_data', 'c:\\Users\\sumit\\miniconda3\\envs\\my_env\\nltk_data', 'c:\\Users\\sumit\\miniconda3\\envs\\my_env\\share\\nltk_data', 'c:\\Users\\sumit\\miniconda3\\envs\\my_env\\lib\\nltk_data', 'C:\\Users\\sumit\\AppData\\Roaming\\nltk_data', 'C:\\nltk_data', 'D:\\nltk_data', 'E:\\nltk_data', 'C:\\Users\\sumit/AppData/Roaming/nltk_data']

# %%
text = "NLP is transforming the way we interact with computers!"
tokens = word_tokenize(text= text)
print(tokens)

# %%
import nltk
import os
nltk.data.path.append(os.path.expanduser('~/AppData/Roaming/nltk_data'))
nltk.download('punkt')

from nltk.tokenize import word_tokenize

text = "NLP is transforming the way we interact with computers!"
tokens = word_tokenize(text)
print(tokens)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sumit\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[116], line 9
#       6 from nltk.tokenize import word_tokenize
#       8 text = "NLP is transforming the way we interact with computers!"
# ----> 9 tokens = word_tokenize(text)
#      10 print(tokens)
#
# File c:\Users\sumit\miniconda3\envs\my_env\Lib\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)    140     :type preserve_line: bool
#     141     """
# ...

# %%
import nltk
nltk.download('punkt')  # Step to avoid LookupError

# from nltk.tokenize import word_tokenize
# df['tokens'] = df['review'].apply(word_tokenize)
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# False

# %%
from nltk.tokenize import word_tokenize
#df['review'].apply(word_tokenize)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from nltk.tokenize import word_tokenize
#       2 df['review'].apply(word_tokenize)
#
# ModuleNotFoundError: No module named 'nltk'

# %%
import nltk
nltk.download('punkt')  # Download it cleanly
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sumit\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import os
import nltk

# Set correct data path manually
nltk.data.path.append(os.path.expanduser('~/AppData/Roaming/nltk_data'))

from nltk.tokenize import word_tokenize

# Now use it
df['tokens'] = df['review'].apply(word_tokenize)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[59], line 10
#       7 from nltk.tokenize import word_tokenize
#       9 # Now use it
# ---> 10 df['tokens'] = df['review'].apply(word_tokenize)
#
# File c:\Users\sumit\miniconda3\envs\my_env\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)   4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)   4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...

# %% [markdown]
# ## remove stopwords
