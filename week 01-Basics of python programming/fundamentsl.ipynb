# %% [markdown]
# # python output

# %% [markdown]
# how to idenity function or variable in python

# %%
# x() x ki jagh kuch bhi yadi barcket ha tho vo function ha 
# structure
# function_name( inputs ) -->
#        processs 
#      output in screen

# %% [markdown]
# Important points

# %% [markdown]
# what is case senstaive in python ?

# %%
#meaning
print() # this is different 
# Print() 
 # tip : yadi variable ka name capital ma tho program ma dhyan rakna
# Out:
# 4

# %% [markdown]
# ### What is print function

# %%
print("consisent in your journey")
# Out:
# consisent in your journey

# %%
#print(focus on work) # use carly bracket to print words that python know it is a string

# %%
print
# if I type function without bracket then it will tell me the doc
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
print(2) # any number in
# Out:
# 2

# %%
print(7.7) # any decimal number
# Out:
# 7.7

# %%
print(True ) # print bollean also

# %% [markdown]
# # print func power

# %%
print('focus', 56, 35.5 , False)
# it print all data types
# and kitni bhi chezza print func ka andr dalo ya print kar da ga
# 4 ho ya 400
# Out:
# focus 56 35.5 False

# %% [markdown]
# ## Reading manual

# %%
print()
# type and wait har ek function bta rha ha ki usa use karna ha 
# yani user manual  # 
print(print.__doc__)
# Out:
# Prints the values to a stream, or to sys.stdout by default.
#
#   sep
#     string inserted between values, default a space.
#   end
#     string appended after the last value, default a newline.
#   file
#     a file-like object (stream); defaults to the current sys.stdout.
#   flush
#     whether to forcibly flush the stream.

# %% [markdown]
# ## Default setting in func

# %%
print()
#print(*values: object, sep: str | None = " ", end: str |
#       None = "\n", file: SupportsWrite[str] |
#       None = None, flush: Literal[False] = False) -> None)

# %%
#aap chaho tho function ma default setting change 
# kar sakta ho 
# example 
print('focus', 56, 35.5 , False)
# Out:
# focus 56 35.5 False

# %%
#notice they are separated by space
print('focus', 56, 35.5 , False ,sep='/')
# now they are separated by slash /
# Out:
# focus/56/35.5/False

# %%
print('hello')
print('world')
# two print statements have different line
# Out:
# hello
# world

# %%
print('hello', end='-')
print('world')
# Out:
# hello-world

# %% [markdown]
# # Data types

# %%
# do it copy i reacall 
# data type = information store kari ha iss tarika sa
# and data strucutre  ar
# data = pieces of information
# data structure information ko store karna ka tarika

# %% [markdown]
# # type function

# %%
type(print())
# type is like detectective 
#isma koi bhi data type dalo vo detect kar laga aor apko bta dega
# Out:
# NoneType

# %%
type([1,2,3])
# Out:
# list

# %%
type(345)
# Out:
# int

# %% [markdown]
# # variable

# %%
#they are container(store information) for future use  
#exmaple : website homepage example of user name

# %% [markdown]
# static and dyanmic typing

# %%
# static typing = matlab apko phala btana hoga ki jo variable aap
# store kar raho ho vo kis data type ka ha  

# in C/C++ 
'''    int variable = 5    '''

# but in python
variable = 30
print(variable)
# matlab python ka interpetaor intelligent enough ha ki 
# usa pata ha variable ka data type kya ha
# Out:
# 30

# %% [markdown]
# static and dyamic binding

# %%
# dyamic binding
var = 4
print(var)
var = "flow"
print(var)
# ouput kya aa gya
# Out:
# 4
# flow

# %% [markdown]
# carefull point on variable define

# %%
# yahi ek varialbe ma hum dursa data type store kar sakta ha 
print(var)
# dhyan sa  aab value new data type ki hogi gi

# ya kabi kabi aa ka project ma error kar sakta ha 
# matlab apna ek variable bnaya beech ma ek dum variable ki value 
# change mat kariya ga  known as poor progamming
# Out:
# flow

# %%
# static binding
'''   int var =  5'''
# is progamme var dursa int var store kar sakta ha lakin dursa data type 
# store nhi kar sakta


#dyamic typing 
# in python var koi bhi data type store kar sakta ha promblem ka bitch ma
#

# %% [markdown]
# ## Stylish ways to declare variable

# %% [markdown]
# normal

# %%
a = 1
b = 5
c = 4
print(a, b, c)
# Out:
# 1 5 4

# %% [markdown]
# combined way to store diff var

# %%
a, b, c = 1,5, 4
print(a, b, c)
# Out:
# 1 5 4

# %% [markdown]
# sabhi var ek sath ek value

# %%
a = b = c = 7
print(a, b, c)
# Out:
# 7 7 7

# %% [markdown]
# Code snippet

# %%
# chota line ka code 
# chota kitna bhi ho sakta ha  1 ya 2 ya fir 5 bhi

# %% [markdown]
# # Comments and usefullness

# %%
# for interperator = line  execute nhi hoga
# it helps other and you as future self  to understand
# what's the logic and what you try to do 

# aap progam ka upar hi liko ki aap karna kya chata ho 
# apko team ma kam karna hoga tho write comments always

# %% [markdown]
# # keyword

# %%
# har ek progamming languange ma kuch reserved word hota ha 
# specific tak karna ka liya

# %% [markdown]
# question

# %%
# what values are not be tha name of  variable    = keywords

# %% [markdown]
# # Identifiers

# %%
# user defined 
# variable name , function name , class name  know as identifiers
# matlab jo bhi hum name defined kara vo identifiers ha 

var = 3

def fun_name():
    return None
fun_name()

#class

# %% [markdown]
# Condtions to defined identifiers
# ''' matlab naming karna ka tarika '''

# %% [markdown]
# do not start with digit

# %%
# 1var = 3
# print(1var)

# but varialbe ka baad name use kar sakta ha 
var1 = 'clarity'
print(var1)
# Out:
# clarity

# %% [markdown]
# specail charactor
# ''' only use underscore ( _ )
# not  any @ # $ %^ -

# %% [markdown]
# dont use keywords
# ''' as identifiers

# %% [markdown]
# # coding tip  to do

# %%
# phala dimag ma fir keyborad ma fir ma code karta hu
# steps phala ma dimag ma visulaize and code karta hu
# fir ma comments likta hu
# fir ma comments ka andar code  likta hu 
# matlab big promblem ko break karo and
# order(sequence of steps) ma liko

# %% [markdown]
# # Input

# %% [markdown]
# task to add number
# '' given from user ''

# %%
#take  2 num from user store in variable
f_num = input('enter the first num')
s_num = input('enter the second  num')
#add the variable
result = f_num + s_num
# print the result
print(result)

# observe ya tho input nhi aaya jo huma chaya tha 
# huma tho numbers ko matmatically add karna tha
# Out:
# 3456

# %% [markdown]
# identify promblem
# ''' to detect the data type

# %%
#take  2 num from user store in variable
f_num = input('enter the first num')
s_num = input('enter the second  num')
print(type(f_num))
print(type(s_num))
 # hmm ya tho string  data type ha
# Out:
# <class 'str'>
# <class 'str'>

# %% [markdown]
# ## why input is string datatype

# %%
# string yani sequence of charactar
# string ek univeral formate ha
# yahi ki koi bhi data type ko hum string ma convert kar sakta ha
# converstion b/w
# int , float ,complex  <--> string 
a = '4'
print(type(a))
# Out:
# <class 'str'>

# %% [markdown]
# # Type Conversion

# %% [markdown]
# implicit change

# %%
# yani internally python apna app data type convert kar la ga
a  = 4
b =  4.5458
print(a + b)
print(type(a) , type(b))
# Out:
# 8.5458
# <class 'int'> <class 'float'>

# %% [markdown]
# observe

# %%
# 2 different data type ka bitch operation
# mathmatical yahi real world ma hota ha tho
# programming ma bhi hota ha 
# another example 
c = "54"
d =  34
#print(c + d)
# because operation b/w  string and number b/w no sense 
# because it take no logical religionship adding a word to a number

# %% [markdown]
# complex and int

# %%
e = 4 + 5j
f = 3
print(e + f)
# Out:
# (7+5j)

# %% [markdown]
# Interesting concept

# %%
# aap ma type converstion kiya  result ma
#take  2 num from user store in variable
f_num = input('enter the first num')
s_num = input('enter the second  num')
#add the variable
result = int(f_num) + int(s_num)
# print the result
print(result)
# Out:
# 47

# %% [markdown]
# explicit  change

# %%
# yahi apni marzi sa programmer change kar sakta ha

# %% [markdown]
# What is the data type of fnum

# %%
#  question str ya int
# ans int kyu ki humna type converstion kar diya ha but...

#take  2 num from user store in variable
f_num = input('enter the first num')
s_num = input('enter the second  num')
#add the variable
result = int(f_num) + int(s_num)
# print the result
print(result)
print(type(f_num))
#
# Out:
# 48
# <class 'str'>

# %%
f_num = input('enter the first num')
s_num = input('enter the second  num')
#add the variable
result = int(f_num) + int(s_num)
# print the result
print(result)
print(id(f_num))
print(id((int(f_num))))
# Out:
# 27
# 1688110831216
# 140708202775688

# %% [markdown]
# observe

# %%
# ya tho string hi ha 
# concept ja hum type converstion karta ha tho 
#asal ma python ek nya object create kar deta ha jo uss
# muja same fnum hi chaya but uska data type int hona chaya 

# python old data type ma koi change nhi karta
# balki ek naya data type bana ta ha

# %% [markdown]
# peramanet change in data type

# %%
# ab mana input ma variable liya fir mana usa store kiya
# fir uska  baad mana usa variable yani fnum ma store kiya
# input --> convert in int --> store in fnum

# %%
#take  2 num from user store in variable
f_num = int(input('enter the first num'))
s_num = int(input('enter the second  num'))
#add the variable
result = f_num + s_num
# print the result
print(result)
print(type(f_num))
# Out:
# 22
# <class 'int'>

# %%
#take  2 num from user store in variable
f_num = int(input('enter the first num'))
s_num = int(input('enter the second  num'))
#add the variable
result = int(f_num) + int(s_num)
# print the result
print(result)
print(type(f_num))
# Out:
# 24
# <class 'int'>

# %% [markdown]
# # literals

# %%
#variable operator literal 
# |          |        |
a            =        4 

# literals yahi jo value variable ka andr store ha

# %% [markdown]
# ## Number systerm literals

# %% [markdown]
# Binary sytem

# %%
a = 0o0010 
print(a)
# application in raspbhiary pi 
# if you do hardware work or robotics
# Out:
# 8

# %% [markdown]
# Decimal system

# %%
a = 100
print(a)
# we humans do math in decimal system
# Out:
# 100

# %% [markdown]
# Hexadecimal system

# %%
c = 0x123
print(c)
# application used to define colour RGB
# used in computer vision
# Out:
# 291

# %% [markdown]
# octahedral number

# %%
d = 0o1234
print(d)
# Out:
# 668

# %% [markdown]
# ## float literal

# %% [markdown]
# simple

# %%
var2 = 3.14
print(var2)
# Out:
# 3.14

# %% [markdown]
# scientific notion

# %%
# for big numbers
var3 = 1.2e3 # yahni 1.2 * 10^2
print(var3)
# Out:
# 1200.0

# %%
# for small numbers
var4 = 4e-3  # yahni 4 * 10^-3
print(var4)
# e stand fro exponent
# Out:
# 0.004

# %% [markdown]
# ## complex literal

# %%
num = 5 + 3j
num
# Out:
# (5+3j)

# %% [markdown]
# Real part

# %%
num.real
# Out:
# 5.0

# %% [markdown]
# imagniary part

# %%
num.imag
# and you do many more operation learn complex number
# beautiful geomatary and do it on computer wonderful
# Out:
# 3.0

# %% [markdown]
# ## String literals

# %% [markdown]
# Comma in string

# %%
# string use single inverted comma
d1 = ' direct focus direct life '
#string use double  inverted comma
d2 = "direct focus direct life"
# string use triple  inverted comma
d3 = ''' direct focus direct life'''
# all same
print(d1,d2,d3)
# Out:
#  direct focus direct life  direct focus direct life  direct focus direct life

# %% [markdown]
# unicode raw str

# %%
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\U0001f600\U0001F606\U0001F923" # use to make program fun 
raw_str = r"raw  \n string"

print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is a multiline string with more than one line code.
# 😀😆🤣
# raw\n string

# %% [markdown]
# ## Boolean literals

# %%
a = True + 4
b = False + 10

print("a:", a)
print("b:", b)
# python treat 
# true as 1
# false as 0
# Out:
# a: 5
# b: 10

# %% [markdown]
# ## None literals

# %%
# none meaning not a number 
# reprsent nothing
v1 = None
print(v1)
# Out:
# None

# %% [markdown]
# Variable declaration

# %%
# application image apko 3 variable chaya a,b,c = int
# mana ena baad ma use karu ga program ya aap karta ho
# others programming language ma
# example tho k naam sa ek variable bhanya jisa hum baad ma use kara ga
#k = 
a = 5
b = 4
print("progrm exec")
# python bola ga jab use karna hoga tab bana lena lakin
# k bata  tho hum

# %%
# ko to None set kar diya 
# ki future ma use karu ga
k = None
a = 5
b = 4
print("progrm exec")

# %% [markdown]
# # use of None

# %%
# in ML algo 
# kabhi aap ko ek variable use karna ha 
# lakin apko bta nhi ha uska value kya raka  ha 
# tho aap usa None set kar do
