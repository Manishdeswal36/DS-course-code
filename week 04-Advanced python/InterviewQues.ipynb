# %%
# todays concept is easy and important the combination is awesome

# %%
# In your data Science journey you use a lot of modules ana package
# what are they . what we mean of that
# numpy ,pandas, sklearn ,tenserflow
# this are packages in python

# %%
# what do you mean by __name__ == '__main__'

# %%
__name__ == '__main__'

# %% [markdown]
# # module
# Any file of exention .py is called module in python
# Whenever we execute program it's module name is `__main__` and stored in `__name__` variable

# %%
# Any independent piece of code in python is called module
# agar aapna apni jindki ma koi bhi file banyi ha tho vo module ha
# example in gui nlp project we make 3 files app.py ,myapi.py , mydb.py
# so their are 3 modules 
# python ko koi bhi indepndent code run kar sakta ha tho usa module bulta ha
# jab bhi aap program run karta ho tho python us file ko __main__ bulta ha 
# see in the example

# %%
def display():
    print('hello world')
display()
print(__name__)
# Out:
# hello world
# __main__

# %%
# whenever you print(__name__) inside any file it should be always output
# __main__
# I test it by creating two files in learn files
# test module1.py
# test module2.py
# it when I type print(__name__)
# ouput is __main__
# python interpeter call current execution  file  is __main__

# %%
# whenever you have file then you 
# print(__name__)
# __main__
# Out:
# __main__

# %%
import test_module_1
print(test_module_1.__name__)
# vo apna file ka name print karta ha
# Out:
# test_module_1

# %%
# har file jab vo apna ma run hoti ha tho vo __main__ ka name sa
# run hoti ha

# lakin jab kisi aor file ma run hoti ha tho apna file_name sa run hoti ha 
# name la leti ha

# %%
import test_module_1
user_input = int(input('enter your number'))

test_module_1.square(user_input)
# output is 
# 

# Question ha ya 1 to 100 output kyu aya 
# Reason : This piece of code
# for i in range(1,11):
#     square(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 4
#       1 import test_module_1
#       2 user_input = int(input('enter your number'))
# ----> 4 test_module_1.square(2)
#
# AttributeError: module 'test_module_1' has no attribute 'square'

# %% [markdown]
# ## mental mode what mean of import

# %%
# when you use 
import test_module_1 
# matlab test_module_1 ka sara code ab test_module_2

# file ma aa chuka ha

# %%
##question aap ya avoid kar sakta ho 1 to 100 ko how ?
# ma jab square to run karu modul2 ma tho 25 print na ki 1 to 100

# %%
# in test modulue 1 
def square(num):
    print(num**2)

if __name__ == 'main':
    for i in range(1,11):
        square(i)
# agar file ka name __main_ ha tho tabhi iss code ko execute karna

# %%
# run in test_module 2 file 
import test_module_1
user_input = int(input('enter your num : '))
test_module_1.square(user_input)
# now ab output 
25 # aya

# %%
if __name__ == 'main':
    for i in range(1,11):
        square(i)

# %%
if __name__ == 'main':
    pass
# It is actually a blocking syntax 
# ya actually kar kiya  raha ha 
# ya kuch piece of code ko chupa
# da raha ha  samna wali  file sa 
# jo file apka code ko use kar rahi ha 
# ya code ko chupna ka  tarika ha 
# acctually very useful

# kahi bar aap asa code liko ga jo dursi file use karagi
# aor kahi bar aap asa code liko ga jo apka personal private code ha
# apki file ko use karna ha 
# us code ko app 
if __name__ == '__main__':
    pass
# ka andr dal deta ha

# %% [markdown]
# ## give option

# %%
# what happen ki ma test module 2 ko option deta hu ki agar vo chaya
# tho 
#if __name__ == 'main':
# ka andr ka code use kar sakti ha 
if __name__ == 'main':
    for i in range(1,11):
        square(i)

# %%
# agar man ho tho use kar lena varna mat karna 
# kiya aap koi bitch ka tarika nikal sakta ho
# you create a function main() jis sa us file ko code execute
# whenever we call
# write code in test module 1 fiel 
def square(num):
    print(num**2)
    
def main():
    for i in range(1,11):
        square(i)
    
if __name__== '__main__':
    main()
 
# output in test_module_1 file    
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %%
# code run in test_module_2 file and its output
import test_module_1
user_input = int(input('enter your num : '))
test_module_1.square(user_input)
# now I have an option to 
test_module_1.main()
# enter your num : 5
# 25
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %% [markdown]
# ## 3 options

# %%
# example you are working in team 
# you team programer use your some file code

# %%
# so you have 3 options
# paka milaga
# nahi milaga
# lena tho la lena

# %% [markdown]
# paka mileaga

# %%
def square(num):
    print(num**2)

for i in range(1,11):
    square(i)

# %% [markdown]
# nahi mileaga

# %%
def square(num):
    print(num**2)

if __name__== '__main__':
    for i in range(1,11):
        square(i)

# %% [markdown]
# lena ho tho la lena

# %%
def square(num):
    print(num**2)
    
def main():
    for i in range(1,11):
        square(i)
    
if __name__== '__main__':
    main()

# %%
# agar same file ma na ho tho kiya file ko import kiya ja sak tha ha
# actually when you are importing
# tho python ka namespace usko alag tarika ka nameing
# da da raha ha

# %% [markdown]
# # Importing the module

# %% [markdown]
# ## why you need to import module
#  2 Reasons for creating module
# - code modularity
# - code reusablity

# %%
# humna kal jo nlp gui project banya tha usma humna 
# 3 module banya tha  
# sab ek module ma hi bana do itna sara module ki
# kya jaroot ha

# %%
# code modularity
# jab bhi aap kisi bada project par kam karoga
# jo top levle programmer hota ha vo code modularity
# par bhut jada focus karta ha 
# code modularity helps you to manage the code.
# jap aap ek large project par kam karta ho 
# yadi aap sara code ek hi file ma write karo ga
# then usko samjna ,manage karna,nahi cheeza add karna and 
# usko debug karna bhut muskil ho jaya ga 
# so people prefer code modularity
# code modulariy matlab jis cheez ka jaha 
# kam ha vo vahi rahagi 
# database jaho code hona chaya whia usa hona chaya
# kal ko agar koi database ka sath kam karna cha tha ha tho 
# wo us file ko import kar ka sath kar sak tha ha 
# warna muja char jaga alag same code likna padta database ka login karna ka 
# registation karna ka 

# in software devlopment modules is complusary
# aap ek bar code lik raho ho fir dubara use kar raha ho

# %% [markdown]
# ## import  module

# %% [markdown]
# ### create and import it

# %%
# create a module by name test write a function hello
# and import in interviewques.ipynb

# %%
import test
test.hello('ram')
# Out:
# hello ram

# %% [markdown]
# ### import multiple modules
# user defined + built_in

# %%
import math
import test

print(math.pi) # built in 
test.hello('krishna') # user defined
# Out:
# 3.141592653589793
# hello krishna

# %% [markdown]
# ## Variations of import statment

# %% [markdown]
# ### normal

# %%
import math
import random

# %% [markdown]
# ### clubbing together

# %%
import math,random,os

# %% [markdown]
# ### import specific names from modulue

# %%
# sometimes library is too big so I use specific function
# from the library which I need 
# this is used in when you deploy on server you are super
# serious about memory useage

# %%
from math import sin,factorial
from random import randrange
from test import hello

print(factorial(5)) # use function that i import the library
print(ceil(2.8 ))# type: ignore 
# function exixt in library but i did not import it
# Out:
# 120
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       3 from test import hello
#       5 print(factorial(5)) # use function that i import the library
# ----> 6 print(ceil(2.8 )) # function exixt in library but i did not import it
#
# NameError: name 'ceil' is not defined

# %%
# * meaning whatever function you want to imported it will added 
from math import * # type: ignore
pi
# Out:
# 3.141592653589793

# %%
ceil(4.5) # now works 
# you did not specifice name but you can import function 
# and save memory useage
# Out:
# 5

# %% [markdown]
# ## Renaming module

# %%
# sometimes some libraries name is so big and writing 
# names is tedious sometimes
# we use short nickname using keyword as

# %%
import math as m
m.factorial(5)
# it work same as we do early
# Out:
# 120

# %%
# in next week we learn
# import numpy as np
# import pandas as pd

# %%
# you can also specify specific function nickname 
# also in y

# %%
from math import factorial as fact 
fact(5)
# Out:
# 120

# %% [markdown]
# ## order of execution of program

# %%
import sys
for p in sys.path:
    print(p)
# ya order of module libraries ha 
# ki pahala vo module ko apka project file ma khoja ga
# fir pyhon 310 zip 
# fir dlls
# fir library .... and so on 
# agar usa modulue nhi milta tho vo
# ModuleNotFoundError raise kart ha
# Out:
# c:\Users\sumit\My_code_files\Data Science codes\week 4 -Advanced python
# c:\Users\sumit\miniconda3\python310.zip
# c:\Users\sumit\miniconda3\DLLs
# c:\Users\sumit\miniconda3\lib
# c:\Users\sumit\miniconda3
#
# c:\Users\sumit\miniconda3\lib\site-packages
# c:\Users\sumit\miniconda3\lib\site-packages\win32
# c:\Users\sumit\miniconda3\lib\site-packages\win32\lib
# c:\Users\sumit\miniconda3\lib\site-packages\Pythonwin

# %% [markdown]
# # summary

# %%
# we learn __name__ = '__main__'
# we learn module
# we learn How to import modulue 
# we learn How to work with it 
# in which modulue order search 
# module is just a file 
# in python case
# collection of modules is package or library
# difference between library and fraemwork

# %%
# How other people use our function and file
# the answer is package
# kya module/file same folder ma hona jarrai ha
# nahi abhi apna deka ki order of execution of module 
# man lo apka modulue kis or folder ma ha tho aap 
# uska path add kar sakt ho uska location apna path /environment ma
# add kar do vo automatically khoj la ga 
# agar vo system variable ma nahi ha 
# tho aap usa environment variable ma dal sakta hao
# apna youtube par bhut tutorial deka ha evironment variable ma 
# dalo and promblem solve but How and why

# %% [markdown]
# # package
# A package in python is direcetory continaing similar sub packages and module
# - A particula directory is treated as package if it has `__init__.py` files in it
# - The `__init__.py` file may be empty or contain some intialization code related to the package

# %%
# repo
# directory
# package -------> modules
# folder           files

# %%
# a package is a folder jiska andr folder ya files hoti ha

# %%
# agar apko koi libarary bnani ha tho aap uska andr files dalo
# jo apna write ki ha 
# and fir dursa log usa download kar ka dek sakta ha

# %%
# packages ka andr folder  hota ha 
# lakin sabhi folder package nahi hota
# wahi folder package hota ha jinka andr __init__.py file  hoti ha 
# tabhi python interpretor ko laga ga vo package ha 
#The `__init__.py` file may be empty or contain some intialization code related to the package
# ki usko install kasa karna ha use kasa karna ha
# most of the time __init__.py file is empty
# what is folder
# collection of similar files
# folder of images,folder of videos,folder of text

# %% [markdown]
# ### create a simple package

# %%
# or create a own library and package 
# mymath
# jiska andr hoga 
# subpackages hoga trignometry, geometery, linear algebra
# subpackage ka andr module file hogi

# %%
# now access
from mymath.trignometry.sin import mysin
# mymath --> package 
# trigonmetry --> subpackage
# sin ---> module/file ha
# mysin ---> function ha 
print(mysin(45))
# output 
8

# %%
# we do same in machine learning like this
from sklearn.linear_model import LinearRegression # type: ignore
# sklearn --> package ha 
# linear_model --> uska andr ka file ha
# LinearRegression --> file ka andr class ha

# %% [markdown]
# # 3rd party package

# %%
# python community is so dyanmic 
# aap deko ki aapko har kisi domain ma package mil jaya gaya
# log apni apni field ma liya package bana tha ha 
# web development
# game development
# app devleopment
# scietific computing numpy,pandas ,sklearn
# animation manim

# %% [markdown]
# ### What are 3rd party packages?
#
# - The python community creates packages and make it available for other programmers
# - PyPI -> Python Package Index
# - You can upload your own package
# - You can also install packages from PyPI and install using pip
# - pip is a package manager utility
# - it is automatically installed with python

# %% [markdown]
# ## difference betwen framework and library

# %%
# library and package are same
# but their is a difference between framework and library 
# you understand it when you do code
# In machine learning their is no difference b/w library and framework
# but in web development have
# you lisen names angular.js and react.js 
# one is library and other is framework
# both library and framwork have a Same mission
# make your life easier as a programmer
# for example if I want to make a library related to math
# then why i write factorial ,ceil code again
# I can import someone library usma muja function mil jata ha
# and I just call the function and get result .
# both are same but their is subtle difference
# library ma programmer ka pas control hota ha 
# muja kab kis cheez ko use karna ha ya control programmer ka 
# hath ma ha
# while framework  control framework ka pas hota ha
# framework apko bola ga ki aap ek tarika sa kam karo
# pahala ya piece of code liko fir ya piece of code liko
# fir aap apni merzi sa koi bhi code liko
