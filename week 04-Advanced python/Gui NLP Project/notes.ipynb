# %% [markdown]
# # What is GUI
# Graphical user interface

# %% [markdown]
# last time we make using textual interface in nlp now we make using gui

# %% [markdown]
#  we use function to make changes in ui
# actually learn just basic your work is to make model you can
# use gui to demo your team how product look like

# %% [markdown]
# today conconcepts we use
# - oop
# - file handling
# - exception handling
# - How to hit api /or use some nlp python library

# %% [markdown]
# # plan of action
# draw digram in notebook

# %% [markdown]
# whenever I don't use self in function it mean ki vo variable function ma hi use hoga and self variable ka agaya lagya then vo function ka bhar bhi use hoga

# %% [markdown]
# # We try to Make code modular
#  example gui bana na ka code ek file ma
#  api ko hit karna ka code dusri file ma hoga
#  file handling ka code alag file ma hoga

# %% [markdown]
# # constructor

# %% [markdown]
# ## create screen

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        # we create a object self.root of Tk class in tkinter library 
        self.root = Tk()
        # now self.root access attribuites and method in Tk class
        # to hold screen  on windows we use mainloop method
        # otherwise it disapper in fration of second
        self.root.mainloop()
# create object of nlpapp class and run it
nlp = NLPApp()

# %% [markdown]
# ## make title

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.mainloop() 
        
nlp = NLPApp()

# %% [markdown]
# ## change icon
# if every icon is fevicon icon in each website you have to convert your image to fevicon
# fevicon

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.mainloop() 
        
nlp = NLPApp()

# %% [markdown]
# ## control size of gui

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600') 
        # 350 pixel width 600 pixel height
        self.root.mainloop() 
        
nlp = NLPApp()

# %% [markdown]
# ## change background
# you can configure your custom colour by searching on html colour code templeate

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='red')
        self.root.mainloop() 
        
nlp = NLPApp()

# %% [markdown]
# # login gui
# now make login gui
# we do a old technqiue make a different function for login gui and call from the constructor ki program chalu ho tho login function ka code execute ho jaya

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='#5d6d7e')
        self.login_gui()
        self.root.mainloop() 
        
    def login_gui(self):
        pass
        
nlp = NLPApp()

# %% [markdown]
# ## make heading

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='#5d6d7e')
        self.login_gui()
        self.root.mainloop() 
        
    def login_gui(self):
        
        heading = Label(self.root,text='NLP App')
        # nothing happen whenever you create a ui component
        # apko explicity btana padta ha ki usko gui ka upar
        # bhi dalo vo batano ka tarika hota geomatary manager
        # think of geometry manager kisi element ko place karna
        # we use pack 
nlp = NLPApp()

# %% [markdown]
# ## show heading using pack method

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='#5d6d7e')
        self.login_gui()
        self.root.mainloop() 
        
    def login_gui(self):
        
        heading = Label(self.root,text='NLP App')
        heading.pack()
        
nlp = NLPApp()

# %% [markdown]
# ## change font size ,font style, make bold

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='#5d6d7e')
        self.login_gui()
        self.root.mainloop() 
        
    def login_gui(self):
        
        heading = Label(self.root,text='NLP App')
        heading.pack()
        heading.configure(font=('verdana',24,'bold'))
nlp = NLPApp()

# %% [markdown]
# ## change backfround colour and font colour

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='#5d6d7e')
        self.login_gui()
        self.root.mainloop() 
        
    def login_gui(self):
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack()
        heading.configure(font=('verdana',24,'bold'))
nlp = NLPApp()

# %% [markdown]
# ## change position
# upar sa nicha 30 pixel and gap of 30 pixel

# %% [markdown]
# ## add email text

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='#5d6d7e')
        self.login_gui()
        self.root.mainloop() 
        
    def login_gui(self):
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
nlp = NLPApp()

# %% [markdown]
# ## add email input and configure it

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='#5d6d7e')
        self.login_gui()
        self.root.mainloop() 
        
    def login_gui(self):
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
        self.email_input = Entry(self.root,width=50)
        self.email_input.pack(pady=(5,10))
nlp = NLPApp()

# %% [markdown]
# ## make for password like same

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='#5d6d7e')
        self.login_gui()
        self.root.mainloop() 
        
    def login_gui(self):
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
        self.email_input = Entry(self.root,width=50)
        self.email_input.pack(pady=(5,10),ipady=7)
        
        label_2 = Label(self.root,text='Enter password')
        label_2.pack(pady=(10,10))
        
        self.password_input = Entry(self.root,width=50)
        self.password_input.pack(pady=(5,10),ipady=7)
        
nlp = NLPApp()

# %% [markdown]
# ## make login button

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='#5d6d7e')
        self.login_gui()
        self.root.mainloop() 
        
    def login_gui(self):
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
        self.email_input = Entry(self.root,width=50)
        self.email_input.pack(pady=(5,10),ipady=7)
        
        label_2 = Label(self.root,text='Enter password')
        label_2.pack(pady=(10,10))
        
        self.password_input = Entry(self.root,width=50)
        self.password_input.pack(pady=(5,10),ipady=7)
        
        login_button = Button(self.root,text='login',width=30,height=2)
        login_button.pack(pady=(10,10))
        
nlp = NLPApp()

# %% [markdown]
# ## not a member label

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='#5d6d7e')
        self.login_gui()
        self.root.mainloop() 
        
    def login_gui(self):
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
        self.email_input = Entry(self.root,width=50)
        self.email_input.pack(pady=(5,10),ipady=7)
        
        label_2 = Label(self.root,text='Enter password')
        label_2.pack(pady=(10,10))
        
        self.password_input = Entry(self.root,width=50)
        self.password_input.pack(pady=(5,10),ipady=7)
        
        login_button = Button(self.root,text='login',width=30,height=2)
        login_button.pack(pady=(10,10))
        
        label_3 = Label(self.root,text='Not a member')
        label_3.pack(pady=(10,10))
        
nlp = NLPApp()

# %% [markdown]
# ## hide password

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='#5d6d7e')
        self.login_gui()
        self.root.mainloop() 
        
    def login_gui(self):
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
        self.email_input = Entry(self.root,width=50)
        self.email_input.pack(pady=(5,10),ipady=7)
        
        label_2 = Label(self.root,text='Enter password')
        label_2.pack(pady=(10,10))
        
        self.password_input = Entry(self.root,width=50,show='*')
        self.password_input.pack(pady=(5,10),ipady=7)
        
        login_button = Button(self.root,text='login',width=30,height=2)
        login_button.pack(pady=(10,10))
        
        label_3 = Label(self.root,text='Not a member')
        label_3.pack(pady=(10,10))
        
        redirect_button = Button(self.root,text='Register Now',width=15,height=1)
        redirect_button.pack(pady=(10,10))
nlp = NLPApp()

# %% [markdown]
# # Register gui
# whenever you click on reigister butoon then register code executed

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='#5d6d7e')
        self.login_gui()
        self.root.mainloop() 
        
    def login_gui(self):
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
        self.email_input = Entry(self.root,width=50)
        self.email_input.pack(pady=(5,10),ipady=7)
        
        label_2 = Label(self.root,text='Enter password')
        label_2.pack(pady=(10,10))
        
        self.password_input = Entry(self.root,width=50,show='*')
        self.password_input.pack(pady=(5,10),ipady=7)
        
        login_button = Button(self.root,text='login',width=30,height=2)
        login_button.pack(pady=(10,10))
        
        label_3 = Label(self.root,text='Not a member')
        label_3.pack(pady=(10,10))
        
        redirect_button = Button(self.root,text='Register Now',width=15,height=1,command=self.register_gui())
        redirect_button.pack(pady=(10,10))
        
    def register_gui(self):
        print('register wala code')
    
nlp = NLPApp()

# %% [markdown]
# ## clear the existing gui

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='#5d6d7e')
        self.login_gui()
        self.root.mainloop() 
        
    def login_gui(self):
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
        self.email_input = Entry(self.root,width=50)
        self.email_input.pack(pady=(5,10),ipady=7)
        
        label_2 = Label(self.root,text='Enter password')
        label_2.pack(pady=(10,10))
        
        self.password_input = Entry(self.root,width=50,show='*')
        self.password_input.pack(pady=(5,10),ipady=7)
        
        login_button = Button(self.root,text='login',width=30,height=2)
        login_button.pack(pady=(10,10))
        
        label_3 = Label(self.root,text='Not a member')
        label_3.pack(pady=(10,10))
        
        redirect_button = Button(self.root,text='Register Now',width=15,height=1,command=self.register_gui())
        redirect_button.pack(pady=(10,10))
        
    def register_gui(self):
        # clear the existing gui 
        for i in self.root.pack_slaves():
            print(i)
    
nlp = NLPApp()

# %% [markdown]
# ## copy same code you write in login

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='#5d6d7e')
        self.login_gui()
        self.root.mainloop() 
        
    def login_gui(self):
        self.clear()
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
        self.email_input = Entry(self.root,width=50)
        self.email_input.pack(pady=(5,10),ipady=7)
        
        label_2 = Label(self.root,text='Enter password')
        label_2.pack(pady=(10,10))
        
        self.password_input = Entry(self.root,width=50,show='*')
        self.password_input.pack(pady=(5,10),ipady=7)
        
        login_button = Button(self.root,text='login',width=30,height=2)
        login_button.pack(pady=(10,10))
        
        label_3 = Label(self.root,text='Not a member')
        label_3.pack(pady=(10,10))
        
        redirect_button = Button(self.root,text='Register Now',width=15,height=1,command=self.register_gui)
        redirect_button.pack(pady=(10,10))
        
    def register_gui(self):
        self.clear()
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_0 = Label(self.root,text='Enter Name')
        label_0.pack(pady=(10,10))
        self.name_input = Entry(self.root,width=50)
        self.name_input.pack(pady=(5,10),ipady=7)
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
        self.email_input = Entry(self.root,width=50)
        self.email_input.pack(pady=(5,10),ipady=7)
        
        label_2 = Label(self.root,text='Enter password')
        label_2.pack(pady=(10,10))
        
        self.password_input = Entry(self.root,width=50,show='*')
        self.password_input.pack(pady=(5,10),ipady=7)
        
        register_button = Button(self.root,text='Register',width=30,height=2)
        register_button.pack(pady=(10,10))
        
        label_3 = Label(self.root,text=' Already amember')
        label_3.pack(pady=(10,10))
        
        redirect_button = Button(self.root,text='login',width=15,height=1,command=self.login_gui)
        redirect_button.pack(pady=(10,10))
        
    def clear(self):
        # clear the existing gui 
        for i in self.root.pack_slaves():
            i.destroy()
        
    
nlp = NLPApp()

# %% [markdown]
# # make database in dictinary

# %% [markdown]
# we use dictionary instead of database but what are the promblem
# whenever you re run the code the dicitionary is empty so we don't want  this feature. us file ma uska data rahega just like database  we are creating a json file in which we store information of users email ko key and value ko name and password

# %% [markdown]
# we use modular coding gui ka code ek taraf now database ka code ek taraf

# %% [markdown]
# ## flow of program

# %%
# nlp app ha user click on register 
# create name, email and  password
# --> we fetch the email and passowrd data using python and store 
# in a dictionary

# %%
import json
# we import this class in gui app 
class DataBase:
    
    def add_data(self,name,email,password):
        
        with open('db.json','r') as readfileobject:
            data_base = json.dump(readfileobject)
            
        if email in data_base:
            return 0 # not register email already exist
        else:
            data_base[email]= [name,password]
            with open('db.json','w') as writefileobject:
                json.dump(data_base,writefileobject)
                
            return 1 # you are registed

# %% [markdown]
# # perform registation
# fetch data from gui and store in a dict

# %%
from tkinter import *

class NLPApp:
    
    def __init__(self) -> None:
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='#5d6d7e')
        self.login_gui()
        self.root.mainloop() 
        
    def login_gui(self):
        self.clear()
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
        self.email_input = Entry(self.root,width=50)
        self.email_input.pack(pady=(5,10),ipady=7)
        
        label_2 = Label(self.root,text='Enter password')
        label_2.pack(pady=(10,10))
        
        self.password_input = Entry(self.root,width=50,show='*')
        self.password_input.pack(pady=(5,10),ipady=7)
        
        login_button = Button(self.root,text='login',width=30,height=2)
        login_button.pack(pady=(10,10))
        
        label_3 = Label(self.root,text='Not a member')
        label_3.pack(pady=(10,10))
        
        redirect_button = Button(self.root,text='Register Now',width=15,height=1,command=self.register_gui)
        redirect_button.pack(pady=(10,10))
        
    def register_gui(self):
        self.clear()
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_0 = Label(self.root,text='Enter Name')
        label_0.pack(pady=(10,10))
        self.name_input = Entry(self.root,width=50)
        self.name_input.pack(pady=(5,10),ipady=7)
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
        self.email_input = Entry(self.root,width=50)
        self.email_input.pack(pady=(5,10),ipady=7)
        
        label_2 = Label(self.root,text='Enter password')
        label_2.pack(pady=(10,10))
        
        self.password_input = Entry(self.root,width=50,show='*')
        self.password_input.pack(pady=(5,10),ipady=7)
        
        register_button = Button(self.root,text='Register',width=30,height=2,command=self.perform_registration)
        register_button.pack(pady=(10,10))
        
        label_3 = Label(self.root,text=' Already amember')
        label_3.pack(pady=(10,10))
        
        redirect_button = Button(self.root,text='login',width=15,height=1,command=self.login_gui)
        redirect_button.pack(pady=(10,10))
        
    def clear(self):
        # clear the existing gui 
        for i in self.root.pack_slaves():
            i.destroy()
            
    def perform_registration(self):
        # fetch data from gui 
        name = self.name_input.get()
        email = self.email_input.get()
        password = self.password_input.get()
        print(name)
    
        
    
nlp = NLPApp()

# %% [markdown]
# ## connection to mydb and perform registation function

# %%
from tkinter import *
from mydb import DataBase
class NLPApp:
    
    def __init__(self) -> None:
        # create a object of database class
        self.dbobject = DataBase()
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='#5d6d7e')
        self.login_gui()
        self.root.mainloop() 
        
    def login_gui(self):
        self.clear()
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
        self.email_input = Entry(self.root,width=50)
        self.email_input.pack(pady=(5,10),ipady=7)
        
        label_2 = Label(self.root,text='Enter password')
        label_2.pack(pady=(10,10))
        
        self.password_input = Entry(self.root,width=50,show='*')
        self.password_input.pack(pady=(5,10),ipady=7)
        
        login_button = Button(self.root,text='login',width=30,height=2)
        login_button.pack(pady=(10,10))
        
        label_3 = Label(self.root,text='Not a member')
        label_3.pack(pady=(10,10))
        
        redirect_button = Button(self.root,text='Register Now',width=15,height=1,command=self.register_gui)
        redirect_button.pack(pady=(10,10))
        
    def register_gui(self):
        self.clear()
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_0 = Label(self.root,text='Enter Name')
        label_0.pack(pady=(10,10))
        self.name_input = Entry(self.root,width=50)
        self.name_input.pack(pady=(5,10),ipady=7)
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
        self.email_input = Entry(self.root,width=50)
        self.email_input.pack(pady=(5,10),ipady=7)
        
        label_2 = Label(self.root,text='Enter password')
        label_2.pack(pady=(10,10))
        
        self.password_input = Entry(self.root,width=50,show='*')
        self.password_input.pack(pady=(5,10),ipady=7)
        
        register_button = Button(self.root,text='Register',width=30,height=2,command=self.perform_registration)
        register_button.pack(pady=(10,10))
        
        label_3 = Label(self.root,text=' Already amember')
        label_3.pack(pady=(10,10))
        
        redirect_button = Button(self.root,text='login',width=15,height=1,command=self.login_gui)
        redirect_button.pack(pady=(10,10))
        
    def clear(self):
        # clear the existing gui 
        for i in self.root.pack_slaves():
            i.destroy()
            
    def perform_registration(self):
        # fetch data from gui 
        name = self.name_input.get()
        email = self.email_input.get()
        password = self.password_input.get()
        response = self.dbobject.add_data(
            name=name, # input object = database object 
            email= email,
            password=password
            )
        if response:
            print('successful registration')
        else:
            print('emial exist')
    
        
    
nlp = NLPApp()

# %% [markdown]
# # message tho programmer ko dik raha ha huma user ka dikana ha

# %%
from tkinter import *
from mydb import DataBase
from tkinter import messagebox
class NLPApp:
    
    def __init__(self) -> None:
        # create a object of database class
        self.dbobject = DataBase()
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='#5d6d7e')
        self.login_gui()
        self.root.mainloop() 
        
    def login_gui(self):
        self.clear()
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
        self.email_input = Entry(self.root,width=50)
        self.email_input.pack(pady=(5,10),ipady=7)
        
        label_2 = Label(self.root,text='Enter password')
        label_2.pack(pady=(10,10))
        
        self.password_input = Entry(self.root,width=50,show='*')
        self.password_input.pack(pady=(5,10),ipady=7)
        
        login_button = Button(self.root,text='login',width=30,height=2)
        login_button.pack(pady=(10,10))
        
        label_3 = Label(self.root,text='Not a member')
        label_3.pack(pady=(10,10))
        
        redirect_button = Button(self.root,text='Register Now',width=15,height=1,command=self.register_gui)
        redirect_button.pack(pady=(10,10))
        
    def register_gui(self):
        self.clear()
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_0 = Label(self.root,text='Enter Name')
        label_0.pack(pady=(10,10))
        self.name_input = Entry(self.root,width=50)
        self.name_input.pack(pady=(5,10),ipady=7)
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
        self.email_input = Entry(self.root,width=50)
        self.email_input.pack(pady=(5,10),ipady=7)
        
        label_2 = Label(self.root,text='Enter password')
        label_2.pack(pady=(10,10))
        
        self.password_input = Entry(self.root,width=50,show='*')
        self.password_input.pack(pady=(5,10),ipady=7)
        
        register_button = Button(self.root,text='Register',width=30,height=2,command=self.perform_registration)
        register_button.pack(pady=(10,10))
        
        label_3 = Label(self.root,text=' Already amember')
        label_3.pack(pady=(10,10))
        
        redirect_button = Button(self.root,text='login',width=15,height=1,command=self.login_gui)
        redirect_button.pack(pady=(10,10))
        
    def clear(self):
        # clear the existing gui 
        for i in self.root.pack_slaves():
            i.destroy()
            
    def perform_registration(self):
        # fetch data from gui 
        name = self.name_input.get()
        email = self.email_input.get()
        password = self.password_input.get()
        response = self.dbobject.add_data(
            name=name, # input object = database object 
            email= email,
            password=password
            )
        if response:
            messagebox.showinfo(title='sucess',message='registration succesfully.you can login now ')
        else:
            messagebox.showerror(title='Erro',message='Email already existed ')

    
        
    
nlp = NLPApp()

# %% [markdown]
# # performe login
# we fetch the data gmail and passowrd and check it match the user

# %%
from tkinter import *
from mydb import DataBase
from tkinter import messagebox
class NLPApp:
    
    def __init__(self) -> None:
        # create a object of database class
        self.dbobject = DataBase()
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='#5d6d7e')
        self.login_gui()
        self.root.mainloop() 
        
    def login_gui(self):
        self.clear()
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
        self.email_input = Entry(self.root,width=50)
        self.email_input.pack(pady=(5,10),ipady=7)
        
        label_2 = Label(self.root,text='Enter password')
        label_2.pack(pady=(10,10))
        
        self.password_input = Entry(self.root,width=50,show='*')
        self.password_input.pack(pady=(5,10),ipady=7)
        
        login_button = Button(self.root,text='login',width=30,height=2,command=self.perform_login)
        login_button.pack(pady=(10,10))
        
        label_3 = Label(self.root,text='Not a member')
        label_3.pack(pady=(10,10))
        
        redirect_button = Button(self.root,text='Register Now',width=15,height=1,command=self.register_gui)
        redirect_button.pack(pady=(10,10))
        
    def register_gui(self):
        self.clear()
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_0 = Label(self.root,text='Enter Name')
        label_0.pack(pady=(10,10))
        self.name_input = Entry(self.root,width=50)
        self.name_input.pack(pady=(5,10),ipady=7)
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
        self.email_input = Entry(self.root,width=50)
        self.email_input.pack(pady=(5,10),ipady=7)
        
        label_2 = Label(self.root,text='Enter password')
        label_2.pack(pady=(10,10))
        
        self.password_input = Entry(self.root,width=50,show='*')
        self.password_input.pack(pady=(5,10),ipady=7)
        
        register_button = Button(self.root,text='Register',width=30,height=2,command=self.perform_registration)
        register_button.pack(pady=(10,10))
        
        label_3 = Label(self.root,text=' Already amember')
        label_3.pack(pady=(10,10))
        
        redirect_button = Button(self.root,text='login',width=15,height=1,command=self.login_gui)
        redirect_button.pack(pady=(10,10))
        
    def clear(self):
        # clear the existing gui 
        for i in self.root.pack_slaves():
            i.destroy()
            
    def perform_registration(self):
        # fetch data from gui 
        name = self.name_input.get()
        email = self.email_input.get()
        password = self.password_input.get()
        response = self.dbobject.add_data(
            name=name, # input object = database object 
            email= email,
            password=password
            )
        if response:
            messagebox.showinfo(title='sucess',message='registration succesfully.you can login now ')
        else:
            messagebox.showerror(title='Error',message='Email already existed ')

    def perform_login(self):
        email = self.email_input.get()
        password = self.password_input.get()
        # input email = database email 
        response = self.dbobject.search(email=email, password= password)
        
        if response:
            messagebox.showinfo('success','login sucessfully')
            self.home_gui()
        else:
            messagebox.showerror('error',"your email and password is incorrect")
            
    def home_gui(self):
        pass
nlp = NLPApp()

# %% [markdown]
# # Home gui
# becuase it is home for user where it see 3 options

# %%
from tkinter import *
from mydb import DataBase
from tkinter import messagebox
class NLPApp:
    
    def __init__(self) -> None:
        # create a object of database class
        self.dbobject = DataBase()
        # login ka gui code load hoga
        self.root = Tk()
        self.root.title('NLp App')
        self.root.iconbitmap(r'resources/favicon.ico')
        self.root.geometry('350x600')
        self.root.config(background='#5d6d7e')
        self.login_gui()
        self.root.mainloop() 
        
    def login_gui(self):
        self.clear()
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
        self.email_input = Entry(self.root,width=50)
        self.email_input.pack(pady=(5,10),ipady=7)
        
        label_2 = Label(self.root,text='Enter password')
        label_2.pack(pady=(10,10))
        
        self.password_input = Entry(self.root,width=50,show='*')
        self.password_input.pack(pady=(5,10),ipady=7)
        
        login_button = Button(self.root,text='login',width=30,height=2,command=self.perform_login)
        login_button.pack(pady=(10,10))
        
        label_3 = Label(self.root,text='Not a member')
        label_3.pack(pady=(10,10))
        
        redirect_button = Button(self.root,text='Register Now',width=15,height=1,command=self.register_gui)
        redirect_button.pack(pady=(10,10))
        
    def register_gui(self):
        self.clear()
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        label_0 = Label(self.root,text='Enter Name')
        label_0.pack(pady=(10,10))
        self.name_input = Entry(self.root,width=50)
        self.name_input.pack(pady=(5,10),ipady=7)
        
        label_1 = Label(self.root,text='Enter Email')
        label_1.pack(pady=(10,10))
        
        self.email_input = Entry(self.root,width=50)
        self.email_input.pack(pady=(5,10),ipady=7)
        
        label_2 = Label(self.root,text='Enter password')
        label_2.pack(pady=(10,10))
        
        self.password_input = Entry(self.root,width=50,show='*')
        self.password_input.pack(pady=(5,10),ipady=7)
        
        register_button = Button(self.root,text='Register',width=30,height=2,command=self.perform_registration)
        register_button.pack(pady=(10,10))
        
        label_3 = Label(self.root,text=' Already amember')
        label_3.pack(pady=(10,10))
        
        redirect_button = Button(self.root,text='login',width=15,height=1,command=self.login_gui)
        redirect_button.pack(pady=(10,10))
        
    def clear(self):
        # clear the existing gui 
        for i in self.root.pack_slaves():
            i.destroy()
            
    def perform_registration(self):
        # fetch data from gui 
        name = self.name_input.get()
        email = self.email_input.get()
        password = self.password_input.get()
        response = self.dbobject.add_data(
            name=name, # input object = database object 
            email= email,
            password=password
            )
        if response:
            messagebox.showinfo(title='sucess',message='registration succesfully.you can login now ')
        else:
            messagebox.showerror(title='Error',message='Email already existed ')

    def perform_login(self):
        email = self.email_input.get()
        password = self.password_input.get()
        # input email = database email 
        response = self.dbobject.search(email=email, password= password)
        
        if response:
            messagebox.showinfo('success','login sucessfully')
            self.home_gui()
        else:
            messagebox.showerror('error',"your email and password is incorrect")
            
    def home_gui(self):
        self.clear()
        
        heading = Label(self.root,text='NLP App',background='#5d6d7e',foreground='white')
        heading.pack(pady=(30,30))
        heading.configure(font=('verdana',24,'bold'))
        
        sentiment_button = Button(self.root,text='Sentiment Analysis ',width=30,height=4,command=self.perform_registration)
        sentiment_button.pack(pady=(15,15))
        
        ner_button = Button(self.root,text='Named Entity Recognitation ',width=30,height=4,command=self.perform_registration)
        ner_button.pack(pady=(15,15))
        
        emotion_button = Button(self.root,text='Emotion Predection',width=30,height=4,command=self.perform_registration)
        emotion_button.pack(pady=(15,15))
        
        logout_button = Button(self.root,text='logout ',width=10,height=1,command=self.login_gui)
        logout_button.pack(pady=(15,10))
        
nlp = NLPApp()
