# %%
# Divide your Data Science journey into parts 
# Data Science learning 
# -- watch lectures
# -- solve task ques

# Data Science Portfoilo 
# don't focus on kitna pacha ha 
# focus on just today

# %% [markdown]
# today we learn some audio processing with python
# - audio format
# - signal paremters
# - wave module
# - plot waveform
# - mircrophone recording with python
# - How to load other file formats like mp3 ... etc

# %% [markdown]
# # concepts

# %% [markdown]
# ## audio formats
# - .mp3
# - .flac
# - .wave

# %% [markdown]
# .mp3  is popular one you may know but it is lossy compression of data during this process we can loss data. we can  lose information

# %% [markdown]
# .flac is loss less compression it allows to compress data but it only reconstruct the data

# %% [markdown]
# . wave is a uncompressed data format it store the data in uncompressed way. the audio quality is best but file size also the largest in the among

# %%
# we work with wave module 
# working is easy because it is built in module
# wave stands for wave for audio formats
import wave

# %% [markdown]
# ## audio signal parameters
# - number of channel
# - sample width
# - framerate/sample_rate
# - number of frames
# - values of a frame

# %% [markdown]
# number of channel
# are 1 for mono
# and 2 for sterero
# number of independent audio channels
# for example stero 2 there are two different sounds
# they are coming from two different directions

# %% [markdown]
# ### number width
# number of bytes for each sample so this will get more clear later when
