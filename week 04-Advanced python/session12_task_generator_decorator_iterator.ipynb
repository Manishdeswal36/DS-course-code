# %% [markdown]
# ## Namespace and Scope

# %% [markdown]
# ###`Q1:` Write `Person` Class as given below and then display it's namespace.

# %% [markdown]
# ```
# Class Name - Person
#
# Attributes:
# name - public
# state - public
# city - private
# age - private
#
# Methods:
# address - public
# It give address of the person as "<name>, <city>, <state>"
# ```

# %%
class Person:
    
    def __init__(self,name,state) -> None:
        self.name = name
        self.state = state
        self.__city = None
        self.__age = None
        # city and age are private variable so we make getter and setter for both
        
    def get_city(self):
        return self.__city
    def set_city(self,city):
        self.__city = city
        return self.__city
    def get_age(self):
        return self.__age
    def set_age(self,age):
        self.__age = age
        return self.__age
        
    def address(self):
        return "<{}>, <{}>, <{}>".format(self.name,self.state,self.__city)
    
person_object = Person(name='Manish',state='Haryana')
person_object.set_city('Sonipat')
person_object.set_age(20)

person_object.address()
for  i in Person.__dict__:
    print(i)
# Out:
# __module__
# __init__
# get_city
# set_city
# get_age
# set_age
# address
# __dict__
# __weakref__
# __doc__

# %%
print(person_object.address())
print(person_object.get_city())
print(person_object.get_age())
# Out:
# <Manish>, <Haryana>, <Sonipat>
# Sonipat
# 20

# %%
class Person:
    
    def __init__(self,name,state,city,age) -> None:
        self.name = name
        self.state = state
        self.__city = city
        self.__age = age
        
    def address(self):
        return "<{}>, <{}>, <{}>".format(self.name,self.state,self.__city)
    
person_object = Person(name='Manish',state='Haryana',city='sonipat',age=21)
person_object.address()
# Out:
# '<Manish>, <Haryana>, <sonipat>'

# %% [markdown]
# ###`Q2:` Write a program to show namespace of object/instance of above(Person) class.

# %%
class Person:
    
    def __init__(self,name,state) -> None:
        self.name = name
        self.state = state
        self.__city = None
        self.__age = None
        # city and age are private variable so we make getter and setter for both
        
    def get_city(self):
        return self.__city
    def set_city(self,city):
        self.__city = city
        return self.__city
    def get_age(self):
        return self.__age
    def set_age(self,age):
        self.__age = age
        return self.__age
        
    def address(self):
        return "<{}>, <{}>, <{}>".format(self.name,self.state,self.__city)
    
person_object = Person(name='Manish',state='Haryana')
person_object.set_city('Sonipat')
person_object.set_age(20)

person_object.address()
for  i in person_object.__dict__:
    print(i)
# Out:
# name
# state
# _Person__city
# _Person__age

# %% [markdown]
# ###`Q3:` Write a recursive program to to calculate `gcd` and print no. of function calls taken to find the solution.
# ```
# gcd(5,10) -> result in 5 as gcd and function call 4
# ```

# %%
counter = 0
def gcd(a,b):
    global counter
    counter += 1
    if b == 0:
        return a
    else:
        return gcd(b, a%b)
print(gcd(10, 5), counter)

# %% [markdown]
# ## Itterator And Generator

# %% [markdown]
# ###`Q4:` Create MyEnumerate class,
# Create your own `MyEnumerate` class such that someone can use it instead of enumerate. It will need to return a `tuple` with each iteration, with the first element in the tuple being the `index` (starting with 0) and the second element being the `current element` from the underlying data structure. Trying to use `MyEnumerate` with a noniterable argument will result in an error.
#
# ```
# for index, letter in MyEnumerate('abc'):
#     print(f'{index} : {letter}')
# ```
#
# Output:
# ```
# 0 : a
# 1 : b
# 2 : c
# ```

# %%
# what is enumerator
# input ma iter object do usko sath apap usko index print kar sakta ho
# example
our_list = [10,20,30,40]
print(enumerate(our_list))
list(enumerate(our_list))
# Out:
# ...
# [(0, 10), (1, 20), (2, 30), (3, 40)]

# %%
def myenumerator(sequence,start=0):
    start = 0
    for i in sequence:
        start = start +1 
        yield start,i 
# loop chalo uska andr index dal do 
list(myenumerator([10,20,40,50]))
# Out:
# [(1, 10), (2, 20), (3, 40), (4, 50)]

# %%
class MyEnumerator:
    def __init__(self,sequence,start=0):
        self.sequence = sequence
        self.start = start
        # call the myenumerator function from contructro 
        #self.myenumerator()
        # store in a list 
        #list(self.myenumerator())
        print(list(self.myenumerator()))
    def myenumerator(self):
        start = self.start
        for i in self.sequence:
            start = start +1 
            yield start,i 
# obj = MyEnumerator([10,20,30,40,50])
# list(obj.myenumerator())

str_obj = MyEnumerator('abc')
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %%
class MyEnumerator:
    def __init__(self,sequence,mystart=0):
        self.sequence = sequence
        mystart = 0
        for i in self.sequence:
            mystart = mystart +1
            yield mystart,i
obj = MyEnumerator([11,12,13,14,15])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 8
#       6             mystart = mystart +1
#       7             yield mystart,i
# ----> 8 obj = MyEnumerator([11,12,13,14,15])
#
# TypeError: __init__() should return None, not 'generator'

# %%
# Out:
# 0 : a
# 1 : b
# 2 : c

# %% [markdown]
# ###`Q5:` Iterate in circle
# Define a class, `Circle`, that takes two arguments when defined: a sequence and a number. The idea is that the object will then return elements the defined number of times. If the number is greater than the number of elements, then the sequence  repeats as necessary. You can define an another class used as a helper (like I call `CircleIterator`).
#
# ```
# c = Circle('abc', 5)
# d = Circle('abc', 7)
# print(list(c))
# print(list(d))
# ```
#
# Output
# ```
# [a, b, c, a, b]
# [a, b, c, a, b, c, a]
# ```

# %%
class Circle:
    def __init__(self, data, max_iters):
        self.data = data
        self.index = 0
        self.max_iters = max_iters
    
    def __iter__(self):
        return self
    def __next__(self):
        if self.index >= self.max_iters:
            raise StopIteration
        value = self.data[self.index % len(self.data)]
        self.index += 1
        return value
c = Circle('abc', 5)
d = Circle('abc', 7)
print(list(c))
print(list(d))
# Out:
# ['a', 'b', 'c', 'a', 'b']
# ['a', 'b', 'c', 'a', 'b', 'c', 'a']

# %%
num = [[1,3],[4,5]]
#       0     1
num[0][1]
# Out:
# 3

# %%
# ek function ma list aor number of times iterate karna ha us 
# list ma agar jitna time iter variable ki value ha
# list ma iterate karo
#while True sa aap ek infinite loop chalo jab tak genrtor ka number katam na hojaya
#

ls = 'abc'
def our_iter_func(sequence):
    for i in sequence:
        yield i
        #print(next(i))

gen_obj = our_iter_func(ls)
next(gen_obj)
next(gen_obj)
next(gen_obj) # it remember function call 
next(gen_obj)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[18], line 14
#      12 next(gen_obj)
#      13 next(gen_obj)
# ---> 14 next(gen_obj)
#
# StopIteration:

# %%
# define a class circle which takes two arguments
# in constuctor
# check the length using conditinals if else 
class Circle:
    def __init__(self,sequence,number) -> None:
        self.sequence = sequence
        self.number = number
        self.print_gen_object()
        if self.number > len(self.sequence):
            pass# call circle iterator function
            # ab aap deko kitna jada ha 
        elif self.number == len(self.sequence):
            self.print_gen_object()# run the loop
        else:
            print('not allowed please enter greator number')
            
    def circle_iterator(self):
        for i in self.sequence:
            yield i 
        # it is a generator object 
        
    def print_gen_object(self):
        print(list(self.circle_iterator()))
circle_object = Circle('abc',10)
# Out:
# ['a', 'b', 'c']

# %%
# Out:
# ['a', 'b', 'c', 'a', 'b']
# ['a', 'b', 'c', 'a', 'b', 'c', 'a']

# %%
# Out:
# ['a', 'b', 'c', 'a', 'b']

# %% [markdown]
# ###`Q6:` Generator time elapsed
# Write a generator function whose argument must be iterable. With each iteration, the generator will return a two-element tuple. The first element in the tuple will be an integer indicating how many seconds have passed since the previous iteration. The tuple’s second element will be the next item from the passed argument.
#
# Note that the timing should be relative to the previous iteration, not when the
# generator was first created or invoked. Thus the timing number in the first iteration
# will be 0
#
# ```
# for t in elapsed_since('abcd'):
#     print(t)
#     time.sleep(2)
# ```
#
# Output:
# ```
# (0.0, 'a')
# (2.005651817999933, 'b')
# (2.0023095009998997, 'c')
# (2.001949742000079, 'd')
# ```
# Note: Your output may differ because of diffrent system has different processing configuration.

# %%
import time

def cal_time_in_iteration(sequence):
    start = time.time()
    for iter in sequence:
        time.sleep(2)  # 2 second gap in runing iteration 
        #       finish  - start 
        yield (time.time() - start,iter)
a = cal_time_in_iteration('abcd')
tuple(a)
# Out:
# ((2.0066492557525635, 'a'),
#  (4.021978378295898, 'b'),
#  (6.035199880599976, 'c'),
#  (8.040935277938843, 'd'))

# %% [markdown]
# ## Decorators

# %% [markdown]
# ###`Q7:` Write a Python program to make a chain of function decorators (bold, italic, underline etc.) on a given function which prints "hello world"
#
# ```
# def hello():
#     return "hello world"
# ```
#
# ```
# bold - wrap string with <b> tag. <b>Str</b>
# italic - wrap string with <i> tag. <i>Str</i>
# underline- wrap string with <u> tag. <u>Str</u>
# ```

# %%
# tags not working then use The ANSI codes for bold, italic, and underline are: 
# Bold: \u001b[1m 
# Italic: \u001b[3m 
# Underline: \u001b[4m

# %%
print('\u001b[1mhello')
# Out:
# hello

# %%
# input ma string do uska baad ek decorator bano jo us string ko
# bold ,italic underline ma decorate kara
def string_decorator(func):
    
    def wrapper():
        # we use ansi code for bold,itatlic,underline 
        bold = '\u001b{}'.format(func())
        print(bold)
        italic = '\u001b[3m{}'.format(func())
        print(italic)
        underline = '\u001b[4m{}'.format(func())
        print(underline)
    
    return wrapper 
@string_decorator
def hello():
    return 'hello world'

# now call the func
hello()
# Out:
# hello world
# hello world
# hello world

# %%
print('<b>Str</b>')
# tag not working use code in python
# Out:
# <b>Str</b>

# %%
text = 'hello world'
bold = '\033[1m{}'.format(text)
print(bold)
# Out:
# hello world

# %% [markdown]
# ###`Q8:` Write a decorator called `printer` which causes any decorated function to print their return values. If the return value of a given function is `None`, printer should do nothing.

# %%
# it is good pratice to use functions with wraps to hide internal
from functools import wraps
def printer(func):
    @wraps(func)
    def inner(*args,**kwargs):
        return_value = func(*args,**kwargs)
        if return_value is not None:
            print(return_value)
        return return_value
    
    return inner

@printer
def text(string):
    return string

#text(None)
text('focus on process')
# Out:
# focus on process
# 'focus on process'

# %%
help(printer)
# Out:
# Help on function printer in module __main__:
#
# printer(func)

# %% [markdown]
# ###`Q9:` Make a decorator which calls a given function twice. You can assume the functions don't return anything important, but they may take arguments.
# ```
# #Lets say given function
# def hello(string):
#     print(string)
#
# #on calling after specified decorator is inplaced
# hello('hello')
# ```
#
# Output:
# ```
# hello
# hello
# ```

# %%
# wrapper ma jaho aor two times call karo
def call_twice(func):
    def wrapper():
        func()
        func()
    return wrapper

@call_twice
def print_text():
    print('simple string')

print_text()
# Out:
# simple string
# simple string

# %% [markdown]
# ### `Q10:` Write a decorator which doubles the return value of any function. And test that decoratos is working correctly or not using `asert`.
#
# ```
# add(2,3) -> result in 10. Without decorator it should be 5.
# ```

# %%
def double(func):
    
    def inner(*args ,**kwargs):
        return func(*args,**kwargs)*2
    return inner

@double
def add_with_Decorator(a,b):
    return a +b
# check with decoreator

def add(a,b):
    return a+b
# check if different 

a = 2
b = 3
#assert add(a,b) == add_with_Decorator(a,b)
assert add(a,b)*2 == add_with_Decorator(a,b)

# %%
# How assert work
# it is used in testing a lot 
assert 1 == 1
# if equal operation things same do nothing
# but if different it raise an asseration error
