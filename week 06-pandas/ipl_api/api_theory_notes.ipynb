# %% [markdown]
# today season is so intersting  and important
# seassion api development on flask . ki kisi ek student ka placement ho jaya ga

# %% [markdown]
# # plan of the session
# - what is API
# - we make a small project and we use flask,pandas
# - we merge both and make a small interseting project

# %% [markdown]
# # what is API
# - The full form is Application Programming interface
# - it is broker between two parties  connector between two things
# - it is a  pipeline between two different software

# %% [markdown]
# ### example story of colour change bulb
# tho philips na ek naya bulb banya tha ki vo colour change ho sakta ha
# so some friends sitting on home . and one friend have that bulb . so the white bulb changes its colour to blue , than green How the colour change of the bulb happen ?
# so the friend answer it -> it is api . whenver someone in my facebook like my post it changes in blue when someone comments on it it's colour change to green
# so their is a good connection between hardware and software .
# and facebook data is api which sents data from software to hardware

# %% [markdown]
# ### train ticket book example
# for example muja delhi to mumbai jana ha tho mena ticket book b8 ki 17 number ki ticket book kar di from make my trip sa aap muja vo ticket paytm ,phone pa ,indigo, irctc sabhi website par vo ticket already book dhik rahi ha

# %% [markdown]
# in sab ka bitch information share kasa ho rahi ha ya data ha irctc ka pass jo sabko available kara da raha ha

# %% [markdown]
# data center ma ek jaga ha aor us sa har koi software bhat kar pa raha ha paytm,make my trip,irctc

# %% [markdown]
# api ki waja sa two parties ka bitch communication possible ha

# %% [markdown]
# ### api Concept notes

# %% [markdown]
# ```mermaid
# flowchart LR
#   node_1["Software 1"]
#   node_2["Software 2"]
#   node_1 -- API --> node_2
# ```

# %% [markdown]
# In simple Terms
# -  **API is just a  function**
# jo function apna abhi tak python ma banaya the only different thing about the function is ki ya function hamara *server* par hota ha tho agar ya server par ha iska ek url hota ha tho koi bhi is url par hit kar sakta ha aor input provide kara ka ouput la sakta ha

# %% [markdown]
# example we make a api function is_even() on the campusx.in Website
# - our function name is  = campusx.in/is_even()
# - `campusx.in/is_even() ` ya hamara url ho gaya
# - ab puri duniya ma is website(url) ko hit(access) karka `campusx.in/is_even(27)
# - now ya number 27 isko input mila is function ka logic hoga koi
# - logic ma ya bata ta ha ki  ya number even ha ki odd
# - aor output ma jan sakta ha ya number even ha ki odd

# %% [markdown]
# so api is just a function with url on server
# takes input and provide you output .

# %% [markdown]
# ### summary notes
# if someone ask you what is api
# - api is a function .
# - but that function is online(have url)
# - and the url on the server.
# - anybody can access url give input and take output
# - the only difference is the output data format is Json python dictionary key value pair

# %% [markdown]
# ```mermaid
# flowchart TD
#   node_1["What is Api in Programming "]
#   node_2["Api is a function "]
#   node_3["that function is online having url"]
#   node_4["and the url on the server "]
#   node_5["anybody can accesson url give input and take output  "]
#   node_1 --> node_2
#   node_2 --> node_3
#   node_3 --> node_4
#   node_4 --> node_5
# ```

# %% [markdown]
# ### what is JSON
# javascript on notation it is universal data format jisko har ek programming lanuage samaj sakta ha c,java,python ,php

# %% [markdown]
# ### irctc Diagram
# - tho irctc ka database ha
# - usna en database ka upar kuch function bana diya hoga
# - vo function is database ka data bhar uta uta kar dikata ha
# - tho inka data json hoga unko alag alag platform la raha ha
# - example software 1(paytm) ka code java ma hoga vo bhi api sa bhat kar sakta ha
# - example software 2(Make my trip )ma python ma ha vo bhi bhat kar sakta ha
# - ya sabhi us sa bhat kar sakta ha

# %% [markdown]
# ```mermaid
# flowchart LR
#   node_1["irctc database"]
#   node_2["function(API) "]
#   node_3['Make My trip']
#   node_4['Paytm']
#   node_5['Rail Yatri']
#   node_1 -- Data --> node_2
#   node_2 --jSON --> node_3
#   node_2 --jSON --> node_4
#   node_2 --jSON --> node_5
# ```

# %%
# database ---> api ---> many softwares

# %% [markdown]
# - tho aaj hum multiple api yani multiples functions banya ga
# - ya functions banya ga hum ipl dataset ka upar
# - hum pandas sa data analysis kara ipl dataset par fir unko hum function(api) ma convert kara ga
# - fir koi bhi brwoser sa api ko hit karaga aor answer la paya ga

# %% [markdown]
# ek api banaya ga team ka name bhejoga api ma vo apko uska apka website kuch asa dikyi dega `website/api/teamname` jasi api hit and provide input `website/api/teamname/csk` so our flask website return json data that team ka overall performance in ipl
# - csk na kitna match kahal kitna hara kitna draw hua
# - csk ka team wise performance kasa ka comparsion ma  agaisnt mumbain indian ,rcb etc..

# %% [markdown]
# dursa hoga batsman ka api aap usko hit karoga apko information milaga
# - kitna 50,100, runs banya
# - kitna 4,6 lagaya ha jindagi ma
# - all the teams uska record kiya ha

# %% [markdown]
# ek aor api bana sakta ha hum bowlers ka liya

# %% [markdown]
# two teams ka name doga unka comparsion ma track record bana dega hamara api

# %% [markdown]
# now koi bhi front end developer apki website services ko use karaka apni  website bana sakta ha

# %% [markdown]
# ab sir 2 hrs ma us project ko complete nahi kar paya ga lakin yadi aap usko full expand karo  api  develop kar paya  it actually give you good placement .

# %% [markdown]
# aap kisi bhi data ka upar api Service bana sakta ho

# %% [markdown]
# As a Data scientist,ml enginer  apko pata hona chaya ki api kasa banta ha kyuki jab aap Data Analysis ya ml model banaga tho usko aap api ma convert kar sakta ho fir aap uska upar software bana sakta ho

# %% [markdown]
# one api can do many things  but that's not good idea
# but generally you have many api's for various  tasks

# %% [markdown]
# guys ,jisko bhi api samaj ma nahi aya jada load mat lo jap aap karta ho na jap apko asli ma samaj ma ata ha

# %% [markdown]
# coding,programming ma things are very practical jab aap honsetly 100% jabi samaz ma ata ha jab aap bana ka dekto ho .

# %% [markdown]
# ## api to make

# %% [markdown]
# 1. teams = { _ , _ , _ } ipl ma jitni bhi team ha vo aa jaya gi
# 2. player = { _ , _ , _ } ya player ki infromation dega
# 3. team vs team = { _ , _ , _ } ya apko two teams ma kitna match hua kon jita ya bataya  rcb vs csk
# 4. team_record  = { _ , _ , _ }  ya apko sari teams ka record dega kitna match play kara ,performance hara kitna jita kitna
# 5. batsman_record = { _ , _ , _ }  e.g. virat kohli kitna run 50,60 ,team ki khilaf kasa match rah
# 6. bowlers_record = { _ , _ , _ }

# %% [markdown]
# ab dekta iska baad apka imagination kitna aap kitna api services bana sakta ho last ma ham usa deploy bhi kara ga

# %% [markdown]
# deploy ka matlab ab online usa koi bhi use kar sakta ha

# %% [markdown]
# # Programming start

# %% [markdown]
# ## Make home route

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/')
def home():
    return 'Hello World'

app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# c:\Users\sumit\miniconda3\envs\pratice_ds\Lib\site-packages\IPython\core\interactiveshell.py:3516: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# from flask library you import the Flask Class
# create an variable object name app store the Flass class and run the file
# python usa __name__ bulta ha 
# @app decorator add funcatlites ko function 
# . route(/) hit the url 
# function ko print karwan
# app object  ko run kiya ek functin debug = True sa 
# automatically update the code when we changes

# %% [markdown]
# ## import the ipl dataset in ipy.py

# %%
import pandas as pd 
#ipl_matches = "https://docs.google.com/spreadsheets/d/e/2PACX-1vRy2DUdUbaKx_Co9F0FSnIlyS-8kp4aKv_I0-qzNeghiZHAI_hw94gKG22XTxNJHMFnFVKsO4xWOdIs/pub?gid=1655759976&single=true&output=csv"
ipl_matches = r'C:\Users\sumit\My_code_files\Data Science codes\week 6 - pandas\ipl-matches.csv'
matches = pd.read_csv(ipl_matches)
matches
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# ## create team api

# %% [markdown]
# ### do data analysis file

# %%
# so humko ipl ki sari teams ko dikana ha 
# add team
matches['Team1'] + matches['Team1']
matches['Team1'].unique()
matches['Team2'].unique()
list(matches['Team1'].unique())
list(matches['Team2'].unique())

list(matches['Team1'].unique()) + list(matches['Team2'].unique())
set(list(matches['Team1'].unique()) + list(matches['Team2'].unique()))
# final answer
list(set(list(matches['Team1'].unique()) + list(matches['Team2'].unique())))
# Out:
# ['Delhi Daredevils',
#  'Deccan Chargers',
#  'Delhi Capitals',
#  'Chennai Super Kings',
#  'Gujarat Titans',
#  'Mumbai Indians',
#  'Sunrisers Hyderabad',
#  'Rising Pune Supergiant',
#  'Punjab Kings',
#  'Kings XI Punjab',
#  'Rising Pune Supergiants',
#  'Lucknow Super Giants',
#  'Gujarat Lions',
#  'Pune Warriors',
#  'Royal Challengers Bangalore',
#  'Kochi Tuskers Kerala',
#  'Kolkata Knight Riders',
#  'Rajasthan Royals']

# %%
# solution two 
matches['Team1'] + matches['Team2']
# convert into list the sum series
list(matches['Team1']) + list(matches['Team2'])
# now to find the unique item convert into set 
# because than repeat item not allowerd in set
set(list(matches['Team1']) + list(matches['Team2']))
# doing operation perform on set is tought so we again convert into list
list(set(list(matches['Team1']) + list(matches['Team2'])))
# Out:
# ['Delhi Daredevils',
#  'Deccan Chargers',
#  'Delhi Capitals',
#  'Chennai Super Kings',
#  'Gujarat Titans',
#  'Mumbai Indians',
#  'Sunrisers Hyderabad',
#  'Rising Pune Supergiant',
#  'Punjab Kings',
#  'Kings XI Punjab',
#  'Rising Pune Supergiants',
#  'Lucknow Super Giants',
#  'Gujarat Lions',
#  'Pune Warriors',
#  'Royal Challengers Bangalore',
#  'Kochi Tuskers Kerala',
#  'Kolkata Knight Riders',
#  'Rajasthan Royals']

# %% [markdown]
# ### do in the app file

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/')
def home():
    return 'Hello World'

@app.route('/api/teams')
def teams():
    return 'Teams wala api'
# so tho jasa hi user route '/api/teams' par url hit karaga
# teams ka function trigger ho jaya ga

app.run(debug=True)

# %%
# jab bhi aap naya file bana kar code likta ho tho you have to re run the code

# %% [markdown]
# ## create team api function in ipl.py

# %%
def team_api():
    
    teams = list(set(list(matches['Team1']) + list(matches['Team2'])))
    return teams
team_api()
# wow hamara function huma teams ka name list format ma return kar raha ha lakin huma json format ma chaya kyuki api jo ha vo 
# json format ma data returen karti ha
# Out:
# ['Delhi Daredevils',
#  'Deccan Chargers',
#  'Delhi Capitals',
#  'Chennai Super Kings',
#  'Gujarat Titans',
#  'Mumbai Indians',
#  'Sunrisers Hyderabad',
#  'Rising Pune Supergiant',
#  'Punjab Kings',
#  'Kings XI Punjab',
#  'Rising Pune Supergiants',
#  'Lucknow Super Giants',
#  'Gujarat Lions',
#  'Pune Warriors',
#  'Royal Challengers Bangalore',
#  'Kochi Tuskers Kerala',
#  'Kolkata Knight Riders',
#  'Rajasthan Royals']

# %%
def team_api():
    # it will return the json format
    # we create a dictionary wit team dictionary names  
    teams = list(set(list(matches['Team1']) + list(matches['Team2'])))
    team_dict = {
        'teams': teams
    }
    return team_dict
team_api()
# Out:
# {'teams': ['Delhi Daredevils',
#   'Deccan Chargers',
#   'Delhi Capitals',
#   'Chennai Super Kings',
#   'Gujarat Titans',
#   'Mumbai Indians',
#   'Sunrisers Hyderabad',
#   'Rising Pune Supergiant',
#   'Punjab Kings',
#   'Kings XI Punjab',
#   'Rising Pune Supergiants',
#   'Lucknow Super Giants',
#   'Gujarat Lions',
#   'Pune Warriors',
#   'Royal Challengers Bangalore',
#   'Kochi Tuskers Kerala',
#   'Kolkata Knight Riders',
#   'Rajasthan Royals']}

# %% [markdown]
# ## use the jsontify function
# to convert dictionary to json

# %%
from flask import Flask ,jsonify
# import the ipl file 
import ipl
app = Flask(__name__)

@app.route('/')
def home():
    return 'Hello World'

@app.route('/api/teams')
def teams():
    teams = ipl.team_api()
    return jsonify(teams)
    

app.run(debug=True)

# %% [markdown]
# ## Postman Software
# - ki koi dursa software apki api ko kasa access kar sakta ha
# - a famous tool postman is a service and  software
# - It is used to test the api
# - ki api tik sa kam kar raha ha ki nahi kar raha ha
# postman software ko download karka aap usma apni api Website ko Test kar sakta ha

# %% [markdown]
# ## two teams api

# %%
# Do some Data Analysis 
# so we filter out where team 1 and team 2 matches are playing 
team_1 = "Rajasthan Royals"
team_2 = "Royal Challengers Bangalore"
# rows nikal ka do jaha par team_1 = RR ha and team_2 RCB ha
matches[(matches['Team1'] == team_1) & (matches['Team2'] == team_2) ]
# ab asa bhi ho sakta ha ki team_1 ma rajastan royals ho 
matches[(matches['Team1'] == team_2) & (matches['Team2'] == team_1) ]

teams_df = matches[(matches['Team1'] == team_1) & (matches['Team2'] == team_2) | (matches['Team1'] == team_2) & (matches['Team2'] == team_1)]

# find the total matches by team
total_matches = teams_df.shape[0]
total_matches
# Out:
# 27

# %%
# find the total mathces  win by bewtween teams 
teams_df['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Royal Challengers Bangalore    13
# Rajasthan Royals               12
# Name: count, dtype: int64

# %%
matches_won_team1 = teams_df['WinningTeam'].value_counts()[team_1]
matches_won_team2 = teams_df['WinningTeam'].value_counts()[team_2]
draw_matches = total_matches - (matches_won_team1 + matches_won_team2)
# Out:
# 2

# %%
# now combine all pieces and make a function
def team_vs_team(team_1,team_2):
    teams_df = matches[(matches['Team1'] == team_1) & (matches['Team2'] == team_2) | (matches['Team1'] == team_2) & (matches['Team2'] == team_1)]
    total_matches = teams_df.shape[0]
    matches_won_team1 = teams_df['WinningTeam'].value_counts()[team_1]
    matches_won_team2 = teams_df['WinningTeam'].value_counts()[team_2]
    draw_matches = total_matches - (matches_won_team1 + matches_won_team2)
    response = {
        'total matches': total_matches ,
        team_1 : matches_won_team1 , 
        team_2 : matches_won_team2 , 
        'draw matches': draw_matches
    }
    return response
    
team_vs_team(team_1 = "Rajasthan Royals",team_2 = "Royal Challengers Bangalore")
# Out:
# {'total matches': 27,
#  'Rajasthan Royals': 12,
#  'Royal Challengers Bangalore': 13,
#  'draw matches': 2}

# %%
team_vs_team(team_1 = "Mumbai Indians",team_2 = "Royal Challengers Bangalore")
# Out:
# {'total matches': 30,
#  'Mumbai Indians': 17,
#  'Royal Challengers Bangalore': 13,
#  'draw matches': 0}

# %%
team_vs_team(team_1 = 'Chennai Super Kings',team_2 = "Royal Challengers Bangalore")
# Out:
# {'total matches': 29,
#  'Chennai Super Kings': 19,
#  'Royal Challengers Bangalore': 10,
#  'draw matches': 0}

# %% [markdown]
# http://127.0.0.1:5000/api/teams_vs_team?team1=Chennai Super Kings&team2=Royal Challengers Bangalore

# %%
team_1 , team_2 # variable already string ha

# %% [markdown]
# ## how to sent input to api

# %% [markdown]
# - /api/teams_vs_team
# - ? for input team1 = rcb
# - & for continue input

# %% [markdown]
# http://127.0.0.1:5000/api/teams_vs_team?team1=rcb&team2=csk

# %%
from flask import Flask ,jsonify,request
import ipl
# import the ipl file 
app = Flask(__name__)

@app.route('/')
def home():
    return 'Hello World'

@app.route('/api/teams')
def teams():
    teams = ipl.team_api()
    return jsonify(teams)

@app.route('/api/teams_vs_team')
def check_teams():
    #return 'this is 2 teams compariosn '
    team1 = request.args.get('team1')
    team2 = request.args.get('team2')
    
    return team1 + " " + team2
    
# tho jo bhi input diya ja raha ha api ko vo python tak puch ja raha ha

# %% [markdown]
# ## error coming
# TypeError: Object of type int64 is not JSON serializable
# - solution convert interger to string universla data format

# %% [markdown]
# ## now the ipl.py file is

# %%
# this is our Data Analysis file 
import numpy as np
import pandas as pd 
#ipl_matches = "https://docs.google.com/spreadsheets/d/e/2PACX-1vRy2DUdUbaKx_Co9F0FSnIlyS-8kp4aKv_I0-qzNeghiZHAI_hw94gKG22XTxNJHMFnFVKsO4xWOdIs/pub?gid=1655759976&single=true&output=csv"
ipl_matches = r'C:\Users\sumit\My_code_files\Data Science codes\week 6 - pandas\ipl-matches.csv'
matches = pd.read_csv(ipl_matches)

def team_api():
    # it will return the json format 
    teams = list(set(list(matches['Team1']) + list(matches['Team2'])))
    team_dict = {
        'teams': teams
    }
    return team_dict

def team_vs_team_api(team_1,team_2):
    teams_df = matches[(matches['Team1'] == team_1) & (matches['Team2'] == team_2) | (matches['Team1'] == team_2) & (matches['Team2'] == team_1)]
    total_matches = teams_df.shape[0]
    matches_won_team1 = teams_df['WinningTeam'].value_counts()[team_1]
    matches_won_team2 = teams_df['WinningTeam'].value_counts()[team_2]
    draw_matches = total_matches - (matches_won_team1 + matches_won_team2)
    response = {
        'total matches': str(total_matches) ,
        team_1 :  str(matches_won_team1)    , 
        team_2 : str(matches_won_team2) , 
        'draw matches': str(draw_matches)
    }
    return response
a = team_vs_team_api(team_1 = "Rajasthan Royals",team_2 = "Royal Challengers Bangalore")
print(a)

# %% [markdown]
# ## diff b/w api and website
# - jab aap website ka url hit karta ho tho html milta ha
# - jab aap api ka url hit karta ho tho json milta ha

# %% [markdown]
# ## api in business
# example bhut siri website apna product ma alexa use karta ha tho vo api ka through karta ha
# and alexa api ka through unko charge karta ha
# aap future ma ML model bano aap unko api ka through companies ko batch sakta ho .companies kiya karagi.
# companies apka api par hit karka time and money bachayagi because vo machine learning ya data scientiest ki team ko hire nahi kar sakti lakin muja sentiment analysis karna ha

# %% [markdown]
# convert your ml model into money through api .

# %% [markdown]
# this is a local url http://127.0.0.1:5000/ which is access by my machine

# %% [markdown]
# ## how to display json on your webiste
# apko javascript or  ma ek function bana padega jisa vo html ma website par display ho saka ya kam ha front end web devloper ka
