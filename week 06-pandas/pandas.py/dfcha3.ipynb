# %%
import numpy as np
import pandas as pd

generator = np.random.default_rng(seed=1234)
classes = ['english', 'math', 'history', 'chemistry', 'gym', 'civics', 'writing', 'engineering']

schedules = pd.DataFrame({
    'student_id':np.repeat(np.arange(100), 4),
    'class':generator.choice(classes, size=400, replace=True)
}).drop_duplicates()
schedules['grade'] = generator.integers(101, size=schedules.shape[0])

display(schedules)

# %%
class_groby = schedules.groupby(by='class')#.agg({'chemistry':'mean'},{'chemistry': 'median'})
class_groby

# %%
#class_groby = schedules.groupby(by='class').agg({'grade':['mean','median']})
#class_groby.loc['chemistry']

# %%
class_groby.ngroups

# %%
class_groby.size()

# %%
class_groby.get_group('chemistry')

# %%
import numpy as np
np.random.randint(1,4,size=(2,2))
# Out:
# array([[2, 2],
#        [3, 2]])
