# %%
import pandas as pd 
import numpy as np
df = pd.DataFrame({
    'A': ['foo', 'bar', 'foo', 'bar', 'bar', 'foo', 'foo'],
    'B': [False, True, False, True, True, True, True],
    'C': [2.1, 1.9, 3.6, 4.0, 1.9, 7.8, 2.8],
    'D': [50, np.nan, 30, 90, 10, np.nan, 10]
}).convert_dtypes()  
#convert_dtypes is a handy way to make sure we're using pandas' modern String and Integer datatypes
# which allow for NaN values. Without it, A would be type 'object', and D would be type 'float64'.
display(df)
# Out:
#      A      B    C     D
# 0  foo  False  2.1    50
# 1  bar   True  1.9  <NA>
# 2  foo  False  3.6    30
# 3  bar   True  4.0    90
# 4  bar   True  1.9    10
# 5  foo   True  7.8  <NA>
# 6  foo   True  2.8    10

# %%
df.groupby(by='A').first(4)
# Out:
#          B    C   D
# A
# bar   True  1.9  90
# foo  False  2.1  50

# %%
var = df.groupby(by='A')
var

# %%
print(id(var))
# Out:
# 3024703645872

# %%
print(id(df))
# Out:
# 3024704369952

# %%
#like this 
        # |     |  A  |   B   |  C  |   D  |
        # |:---:|:---:|:-----:|:---:|:----:|
        # |   1 | bar | True  | 1.9 | <NA> |
        # |   3 | bar | True  |   4 | 90   |
        # |   4 | bar | True  | 1.9 | 10   |
        # |-----|-----|-------|-----|------|
        # |   0 | foo | False | 2.1 | 50   |
        # |   2 | foo | False | 3.6 | 30   |
        # |   5 | foo | True  | 7.8 | <NA> |
        # |   6 | foo | True  | 2.8 | 10   |

# %%
var.__iter__()
# Out:
# <generator object BaseGrouper.get_iterator at 0x000002C03F16AB30>

# %%
var.groups
# Out:
# {'bar': [1, 3, 4], 'foo': [0, 2, 5, 6]}

# %%
var.indices
# Out:
# {'bar': array([1, 3, 4], dtype=int64), 'foo': array([0, 2, 5, 6], dtype=int64)}

# %%
var.get_group(var)

# %%
var.nunique()
# Out:
#      B  C  D
# A
# bar  1  2  2
# foo  2  4  3

# %% [markdown]
# how many groups are made

# %%
var.ngroups
# Out:
# 2

# %% [markdown]
# number of  rows in  each groups

# %%
var.size()
# Out:
# A
# bar    3
# foo    4
# dtype: int64

# %% [markdown]
# indexing in group

# %%
var.nth(0)
# Out:
#          B    C     D
# A
# bar   True  1.9  <NA>
# foo  False  2.1    50

# %% [markdown]
# groups keys and value

# %%
var.groups
# Out:
# {'bar': [1, 3, 4], 'foo': [0, 2, 5, 6]}

# %%
x = {'bar': [1, 3, 4], 'foo': [0, 2, 5, 6]}
for k,v in x.items():
    print(k,v)
# Out:
# bar [1, 3, 4]
# foo [0, 2, 5, 6]

# %% [markdown]
# using get you can extract one group

# %%
var.get_group('foo')
# Out:
#      A      B    C     D
# 0  foo  False  2.1    50
# 2  foo  False  3.6    30
# 5  foo   True  7.8  <NA>
# 6  foo   True  2.8    10

# %%
var.get_group('bar')
# Out:
#      A     B    C     D
# 1  bar  True  1.9  <NA>
# 3  bar  True  4.0    90
# 4  bar  True  1.9    10

# %%
var.groups
# Out:
# {'bar': [1, 3, 4], 'foo': [0, 2, 5, 6]}
