# %% [markdown]
# so now in the previous lecture we learn How to
# - `Create api`
# In this lecture we learn How to
# - `Consume api`

# %% [markdown]
# tho hamara project ka name ha
# ipl_web_app hamna jo api banyai hama usa yaha use karaga

# %% [markdown]
# # plan of action
# User ko dekata
# team 1 : select the team 1
# team 2 : select the team 2
# ya par hamra teams api call hoga hoga
# butoon : compare the teams
# ya par hammra team_vs_team api ko call hoga
# Result ma

# %% [markdown]
# ## create and consume api

# %% [markdown]
# aap example ma soch sakta ho ki
# - irctc hamra create api ha
# - and makemytrip hamara consume api ha

# %% [markdown]
# ```mermaid
# flowchart LR
#   node_1(" irctc")
#   node_2("make my trip")
#
#   node_1 == data ==> node_2
# ```

# %% [markdown]
# # select th port

# %% [markdown]
# http://127.0.0.1:5000/

# %% [markdown]
# - phala hamra port the 5000 for creating api our first url on server 1
# - ab ham dursa port lena padelag exampel 7000 for consuming api

# %% [markdown]
# # creat the file index.html in template folder

# %% [markdown]
# ## title and template

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>IPL Web Application</title>
</head>
<body>

    
</body>
</html>

# %% [markdown]
# ## heading

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>IPL Web Application</title>
</head>
<body>
    <h1>team vs team</h1>
    
    
</body>
</html>

# %% [markdown]
# ## form

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>IPL Web Application</title>
</head>
<body>
    <h1>team vs team</h1>
    
    <form>
        
    </form>
    
</body>
</html>

# %% [markdown]
# ## select option team 1

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>IPL Web Application</title>
</head>
<body>
    <h1>team vs team</h1>
    
    <form>
        <label>select team 1</label>
        <select>
            <option>csk</option>
            <option>rcb</option>
        </select>
        
    </form>
    
</body>
</html>

# %% [markdown]
# ## new line

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>IPL Web Application</title>
</head>
<body>
    <h1>team vs team</h1>
    
    <form>
        <label>select team 1</label>
        <select>
            <option>csk</option>
            <option>rcb</option>
        </select><br>
        
        
    </form>
    
</body>
</html>

# %% [markdown]
# ## select the team 2

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>IPL Web Application</title>
</head>
<body>
    <h1>team vs team</h1>
    
    <form>
        <label>select team 1</label>
        <select>
            <option>csk</option>
            <option>rcb</option>
        </select><br>
        <label>select team 2</label>
        <select>
            <option>csk</option>
            <option>rcb</option>
    </form>
    
</body>
</html>

# %% [markdown]
# ## now our api talk to ipl web app
# we need to now use the request library iska use karka aap api par hit karta ho json data lata ho aor python ko da deta ho
# - It is beautiful designed api jaha apko baas ek function use karna hota ha
# - muja homepage ma teams ka name dikana unko list dikana ha tho

# %% [markdown]
# ### store in the respone of website request url data

# %%
from flask import Flask,render_template
import requests
# current file
app = Flask(__name__)

# make a url router using decorator 
@app.route('/')
def home():
    respone = requests.get('http://127.0.0.1:5000/api/teams')
    print(respone)
    
    return render_template('index.html',teams = teams) # type: ignore


app.run(debug=True,port=7000)

# %% [markdown]
# ### print on the screen in the json(dict) format and extract the teams

# %%
from flask import Flask,render_template
import requests
# current file
app = Flask(__name__)

# make a url router using decorator 
@app.route('/')
def home():
    respone = requests.get('http://127.0.0.1:5000/api/teams')
    teams = respone.json()['teams']
    #print(teams)
    return render_template('index.html',teams = teams)


app.run(debug=True,port=7000)

# %% [markdown]
# aap asa soch saka ho ki ham irctc ki website par hi kar raha ha aor waha sa train ka data nikal raha ha

# %% [markdown]
# abhi ham apni ipl team wali website par hit kar raha ha aor waha sa ipl_teams name ko nikal raha ha

# %% [markdown]
# tho ma app.py ma request library sa json data la raha aor usko p tag ma index.html ko da rha hu yani paragraph ma

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>IPL Web Application</title>
</head>
<body>
    <h1>team vs team</h1>
    
    <form>
        <p>{{teams}}</p>
        <label>select team 1</label>
        <select>
            <option>csk</option>
            <option>rcb</option>
        </select><br><br>
        <label>select team 2</label>
        <select>
            <option>csk</option>
            <option>rcb</option>
    </form>
    
</body>
</html>

# %% [markdown]
# ['Gujarat Titans', 'Delhi Capitals', 'Rajasthan Royals', 'Rising Pune Supergiant', 'Rising Pune Supergiants', 'Royal Challengers Bangalore', 'Mumbai Indians', 'Pune Warriors', 'Kolkata Knight Riders', 'Kings XI Punjab', 'Deccan Chargers', 'Punjab Kings', 'Kochi Tuskers Kerala', 'Chennai Super Kings', 'Sunrisers Hyderabad', 'Lucknow Super Giants', 'Delhi Daredevils', 'Gujarat Lions']
#
# select team 1
# csk
#
#
# select team 2
# csk

# %% [markdown]
# ## loop syntax in html
# jinja template

# %% [markdown]
# ab hama es list ko is drop drown menu ma lana ha tho kasa laya?

# %% [markdown]
# tho apko option tag ko repeat karna ha kitni baar repeat karta jana ha
# jitna items es teams ka andr ha

# %% [markdown]
# ## sorted in app.py

# %%
from flask import Flask,render_template
import requests
# current file
app = Flask(__name__)

# make a url router using decorator 
@app.route('/')
def home():
    respone = requests.get('http://127.0.0.1:5000/api/teams')
    teams = respone.json()['teams']
    #print(teams)
    return render_template('index.html',teams = sorted(teams))


app.run(debug=True,port=7000)

# %% [markdown]
# ## same repeat for team2

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>IPL Web Application</title>
</head>
<body>
    <h1>team vs team</h1>
    
    <form>
        <p>{{teams}}</p>
        <label>select team 1</label>
        <select>
            {% for item in teams %}
            <option>{{ item }}</option>
            {%endfor%}
            
            
        </select><br><br>
        <label>select team 2</label>
        <select>
            {% for item in teams %}
            <option>{{ item }}</option>
            {%endfor%}
        </select><br><br> 
        
    
    </form>
    
</body>
</html>

# %% [markdown]
# ## add the button
# find track record

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>IPL Web Application</title>
</head>
<body>
    <h1>team vs team</h1>
    
    <form>
        
        <label>select team 1</label>
        <select>
            {% for item in teams %}
            <option>{{ item }}</option>
            {%endfor%}
            
            
        </select><br><br>
        <label>select team 2</label>
        <select>
            {% for item in teams %}
            <option>{{ item }}</option>
            {%endfor%}
        </select><br><br> 
        
        <input type = "submit" value = 'Find Track record'>
    </form>
    
</body>
</html>

# %% [markdown]
# # Gui Ready

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>IPL Web Application</title>
</head>
<body>
    <h1>team vs team</h1>
    
    <form>
        
        <label>select team 1</label>
        <select>
            {% for item in teams %}
            <option>{{ item }}</option>
            {%endfor%}
            
            
        </select><br><br>
        <label>select team 2</label>
        <select>
            {% for item in teams %}
            <option>{{ item }}</option>
            {%endfor%}
        </select><br><br> 

        <input type = "submit" value = 'Find Track record'>
    </form>
    
</body>
</html>

# %% [markdown]
# ## make a new router(url) of app.py

# %%
from flask import Flask,render_template
import requests
# current file
app = Flask(__name__)

# make a url router using decorator 
@app.route('/')
def home():
    respone = requests.get('http://127.0.0.1:5000/api/teams')
    teams = respone.json()['teams']
    #print(teams)
    return render_template('index.html',teams = sorted(teams))

@app.route('/team_vs_team')
def team_vs_team():
    return 'something good happen'

app.run(debug=True,port=7000)

# %% [markdown]
# ## connect the url team_vs_team to html
# if you click on track record than team_vs_team url open

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>IPL Web Application</title>
</head>
<body>
    <h1>team vs team</h1>
    
    <form action="team_vs_team",method = 'get'>
        
        <label>select team 1</label>
        <select>
            {% for item in teams %}
            <option>{{ item }}</option>
            {%endfor%}
            
            
        </select><br><br>
        <label>select team 2</label>
        <select>
            {% for item in teams %}
            <option>{{ item }}</option>
            {%endfor%}
        </select><br><br> 

        <input type = "submit" value = 'Find Track record'>
    </form>
    
</body>
</html>

# %% [markdown]
# ## apply sticker on the name
# tho jasa aap amazon sa parcel ata ha us par sticker hota ya konsa product ha mobile,laptop, cup ,etc usi tara app jab url(internet sa) cheez bhejao html ka thorught aap us par ek sticker laga tha ho

# %% [markdown]
# ## take input in the app.py file
# dhyan sa `request` jo ha vo flask library ka function ha and `requests` jo ha vo library ha

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>IPL Web Application</title>
</head>
<body>
    <h1>team vs team</h1>
    
    <form action="team_vs_team",method = 'get'>
        
        <label>select team 1</label>
        <select name="team1">
            {% for item in teams %}
            <option>{{ item }}</option>
            {%endfor%}
            
            
        </select><br><br>
        <label>select team 2</label>
        <select name="team2">
            {% for item in teams %}
            <option>{{ item }}</option>
            {%endfor%}
        </select><br><br> 

        <input type = "submit" value = 'Find Track record'>
    </form>
    
</body>
</html>

# %%
from flask import Flask,render_template,request
import requests
# current file
app = Flask(__name__)

# make a url router using decorator 
@app.route('/')
def home():
    respone = requests.get('http://127.0.0.1:5000/api/teams')
    teams = respone.json()['teams']
    #print(teams)
    return render_template('index.html',teams = sorted(teams))

@app.route('/team_vs_team')
def team_vs_team():
    team1 = request.args.get('team1')
    team2 = request.args.get('team2')
    return team1 + " " + team2

app.run(debug=True,port=7000)

# %% [markdown]
# ## now we use api of 5000 not 7000
# team_vs_team wala api fir usko display karaga

# %%
from flask import Flask,render_template,request
import requests
# current file
app = Flask(__name__)

# make a url router using decorator 
@app.route('/')
def home():
    respone = requests.get('http://127.0.0.1:5000/api/teams')
    teams = respone.json()['teams']
    #print(teams)
    return render_template('index.html',teams = sorted(teams))

@app.route('/team_vs_team')
def team_vs_team():
    team1 = request.args.get('team1')
    team2 = request.args.get('team2')
    response = requests.get(url='http://127.0.0.1:5000/api/teams_vs_team?team1={}&team2={}'.format(team1,team2))
    response = response.json()
    return response

app.run(debug=True,port=7000)

# %% [markdown]
# ## store in the result and sent to index.html

# %%
from flask import Flask,render_template,request
import requests
# current file
app = Flask(__name__)

# make a url router using decorator 
@app.route('/')
def home():
    respone = requests.get('http://127.0.0.1:5000/api/teams')
    teams = respone.json()['teams']
    #print(teams)
    return render_template('index.html',teams = sorted(teams))

@app.route('/team_vs_team')
def team_vs_team():
    team1 = request.args.get('team1')
    team2 = request.args.get('team2')
    response = requests.get(url='http://127.0.0.1:5000/api/teams_vs_team?team1={}&team2={}'.format(team1,team2))
    response = response.json()
    return render_template('index.html',result = response)

app.run(debug=True,port=7000)

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>IPL Web Application</title>
</head>
<body>
    <h1>team vs team</h1>
    
    <form action="team_vs_team",method = 'get'>
        
        <label>select team 1</label>
        <select name="team1">
            {% for item in teams %}
            <option>{{ item }}</option>
            {%endfor%}
            
            
        </select><br><br>
        <label>select team 2</label>
        <select name="team2">
            {% for item in teams %}
            <option>{{ item }}</option>
            {%endfor%}
        </select><br><br> 

        <input type = "submit" value = 'Find Track record'>
    </form>
    {% if result %}
        {% for i in result %}
            <p>{{ i }} : {{ result[i] }}</p>
        {% endfor %}
    {% endif %}


</body>
</html>

# %% [markdown]
# loop logic result ma check karo kuch ha ki nahi fir usma loop chalo aor dictionary key and dictionary value ko print karo or loop ko end kar do

# %% [markdown]
# ## again reload probmlem solved

# %%
from flask import Flask,render_template,request
import requests
# current file
app = Flask(__name__)

# make a url router using decorator 
@app.route('/')
def home():
    respone = requests.get('http://127.0.0.1:5000/api/teams')
    teams = respone.json()['teams']
    #print(teams)
    return render_template('index.html',teams = sorted(teams))

@app.route('/team_vs_team')
def team_vs_team():
    team1 = request.args.get('team1')
    team2 = request.args.get('team2')
    response = requests.get(url='http://127.0.0.1:5000/api/teams_vs_team?team1={}&team2={}'.format(team1,team2))
    response = response.json()
    
    respone1 = requests.get('http://127.0.0.1:5000/api/teams')
    teams = respone1.json()['teams']
    
    return render_template('index.html',result = response,teams = sorted(teams))

app.run(debug=True,port=7000)

# %% [markdown]
# aaj apna irctc app ka sath make my trip bhi bana liya

# %% [markdown]
# kal apna irctc banya tha
# create api and consume api .

# %% [markdown]
# apna backend api or frontend simple version dono banya app ka

# %% [markdown]
# if the methods changes in api
# than you have a home page of  different version of api in a place

# %% [markdown]
# for example irtc na apna new api ka method banya

# %% [markdown]
# than make my trip version 1
# rail yatra version 2
# and so on ...

# %% [markdown]
# you maintain all version using git

# %% [markdown]
# sir apko sari resources,lecture provide kar sakta ha lakin asli learning tap start hota ha jab aap suru karta ho vo bhut important ha
