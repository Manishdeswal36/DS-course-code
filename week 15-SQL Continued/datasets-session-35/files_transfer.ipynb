# %%
import pandas as pd
from sqlalchemy import create_engine

# Correctly encoded password
engine = create_engine("mysql+pymysql://root:improve%407@localhost/campusx")

# Query with pandas
df = pd.read_sql("SELECT * FROM USERS", engine)
df
# Out:
#    user_id    name             email password
# 0        1  manish  manish@gmail.com     1234
# 1        2   sumit   sumit@yahoo.com     1010
# 2        3   deepu   deepu@gmail.com     None
# 3        4  aditya              None     1234
# 4        5   anand   anand@gmail.com     1234
# 5        6   ayush   ayush@gmail.com    12345
# 6        7  piyush  piyush@gmail.com     6789

# %%
# Correctly encoded password
engine = create_engine("mysql+pymysql://root:improve%407@localhost/task_34")

# %%
pd.read_csv('country_ab.csv',sep = ';')
# Out:
#              Country  Edition       Region   A   B
# 0           Abkhazia     2022      Eurasia   5   8
# 1        Afghanistan     2022         Asia   0   0
# 2            Albania     2022       Europe   9  12
# 3            Algeria     2022       Africa   3   4
# 4            Andorra     2022       Europe  12  15
# ...              ...      ...          ...  ..  ..
# 2090       West Bank     2013  Middle East   2   5
# 2091  Western Sahara     2013       Africa   0   0
# 2092           Yemen     2013  Middle East   3   4
# 2093          Zambia     2013       Africa   9  12
# 2094        Zimbabwe     2013       Africa   3   5
#
# [2095 rows x 5 columns]

# %%
df = pd.read_csv('country_ab.csv',sep = ';')

# Write to SQL
df.to_sql(
    name="country_ab",         # table name in MySQL
    con=engine,
    if_exists="replace",  
    index=False           
)
# Out:
# 2095

# %%
df = pd.read_csv('country_cd.csv',sep = ';')

# Write to SQL
df.to_sql(
    name="country_cd",         # table name in MySQL
    con=engine,
    if_exists="replace",  
    index=False           
)
# Out:
# 2095

# %%
df = pd.read_csv('country_cl.csv',sep = ';')

# Write to SQL
df.to_sql(
    name="country_cl",         # table name in MySQL
    con=engine,
    if_exists="replace",  
    index=False           
)
# Out:
# 2095

# %%
df = pd.read_csv('country_efg.csv',sep = ';')

# Write to SQL
df.to_sql(
    name="country_efg",         # table name in MySQL
    con=engine,
    if_exists="replace",  
    index=False           
)
# Out:
# 2095

# %%
# now transfer the sales database in it

# %%
import pandas as pd
from sqlalchemy import create_engine

# Correctly encoded password
engine = create_engine("mysql+pymysql://root:improve%407@localhost/task_34")

# %%
pd.read_csv('Customers.csv')
# Out:
#       CustomerID FirstName MiddleInitial   LastName
# 0              1     Aaron           NaN  Alexander
# 1              2     Aaron           NaN     Bryant
# 2              3     Aaron           NaN     Butler
# 3              4     Aaron           NaN       Chen
# 4              5     Aaron           NaN    Coleman
# ...          ...       ...           ...        ...
# 1995        1996    Autumn             W        Gao
# 1996        1997    Bailey           NaN      Adams
# 1997        1998    Bailey           NaN      Baker
# 1998        1999    Bailey           NaN     Carter
# 1999        2000    Bailey           NaN    Collins
#
# [2000 rows x 4 columns]

# %%
df = pd.read_csv('Customers.csv')

# Write to SQL
df.to_sql(
    name="customers",         # table name in MySQL
    con=engine,
    if_exists="replace",  
    index=False           
)
# Out:
# 2000

# %%
pd.read_csv('Employees.csv')
# Out:
#     EmployeeID    FirstName MiddleInitial        LastName
# 0            1      Abraham             e          Bennet
# 1            2     Reginald             l  Blotchet-Halls
# 2            3       Cheryl             a          Carson
# 3            4       Michel             e        DeFrance
# 4            5        Innes             e    del Castillo
# 5            6          Ann             u            Dull
# 6            7     Marjorie             r           Green
# 7            8  Morningstar             r          Greene
# 8            9         Burt             r      Gringlesby
# 9           10       Sheryl             u          Hunter
# 10          11        Livia             a          Karsen
# 11          12     Charlene             o        Locksley
# 12          13      Stearns             a      MacFeather
# 13          14      Heather             c        McBadden
# 14          15      Michael             '         O'Leary
# ...

# %%
df = pd.read_csv('Employees.csv')

# Write to SQL
df.to_sql(
    name="employees",         # table name in MySQL
    con=engine,
    if_exists="replace",  
    index=False           
)
# Out:
# 23

# %%
pd.read_csv('Products.csv')
# Out:
#      ProductID                   Name   Price
# 0            1        Adjustable Race    1.60
# 1            2           Bearing Ball    0.80
# 2            3        BB Ball Bearing    2.40
# 3            4  Headset Ball Bearings    0.00
# 4            5                  Blade  189.60
# ..         ...                    ...     ...
# 499        500      ML Bottom Bracket  101.24
# 500        501      HL Bottom Bracket  121.49
# 501        502     Road-750 Black, 44  539.99
# 502        503     Road-750 Black, 48  539.99
# 503        504     Road-750 Black, 52  539.99
#
# [504 rows x 3 columns]

# %%
df = pd.read_csv('Products.csv')

# Write to SQL
df.to_sql(
    name="products",         # table name in MySQL
    con=engine,
    if_exists="replace",  
    index=False           
)
# Out:
# 504

# %%
pd.read_csv('Sales1.csv')
# Out:
#       SalesID  SalesPersonID  CustomerID  ProductID  Quantity
# 0           1             17       10482        500       500
# 1           2              5        1964        306       810
# 2           3              8       12300        123       123
# 3           4              1        4182        437       437
# 4           5             14       15723        246       750
# ...       ...            ...         ...        ...       ...
# 1995     1996             14       15723        246       750
# 1996     1997              4       17023        259       763
# 1997     1998             21       18723        276       780
# 1998     1999             15         664        293       797
# 1999     2000              5        1964        306       810
#
# [2000 rows x 5 columns]

# %%
df = pd.read_csv('Sales1.csv')

# Write to SQL
df.to_sql(
    name="sales",         # table name in MySQL
    con=engine,
    if_exists="replace",  
    index=False           
)
# Out:
# 2000

# %%
import pandas as pd
from sqlalchemy import create_engine

# Correctly encoded password
engine = create_engine("mysql+pymysql://root:improve%407@localhost/campusx")

# %%
df = pd.read_csv(r'C:\Users\sumit\My_code_files\Data Science codes\week 15-SQL Continued\flight project\flights.csv')
df
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0            Jet Airways      2019-01-03  Banglore   New Delhi
# 1               SpiceJet      2019-01-03  Banglore   New Delhi
# 2            Jet Airways      2019-01-03  Banglore   New Delhi
# 3              Air India      2019-01-03  Banglore   New Delhi
# 4            Jet Airways      2019-01-03  Banglore   New Delhi
# ...                  ...             ...       ...         ...
# 10678  Multiple carriers      2019-12-06     Delhi      Cochin
# 10679             IndiGo      2019-12-06   Kolkata    Banglore
# 10680        Jet Airways      2019-12-06     Delhi      Cochin
# 10681           Air Asia      2019-12-06   Kolkata    Banglore
# 10682        Jet Airways      2019-12-06     Delhi      Cochin
#
#                        Route Dep_Time  Duration Total_Stops  Price
# 0            BLR → BOM → DEL    11:40       785      1 stop  26890
# 1            BLR → HYD → DEL    15:35       485      1 stop   7744
# ...

# %%
df = pd.read_csv(r'C:\Users\sumit\My_code_files\Data Science codes\week 15-SQL Continued\flight project\flights.csv')


# Write to SQL
df.to_sql(
    name="flights",         # table name in MySQL
    con=engine,
    if_exists="replace",  
    index=False           
)
# Out:
# 10683

# %%
import pandas as pd
from sqlalchemy import create_engine

# Correctly encoded password
engine = create_engine("mysql+pymysql://root:improve%407@localhost/pratice")

# %%
pd.read_csv('athlete_events.csv')
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df = pd.read_csv('athlete_events.csv')
# Write to SQL
df.to_sql(
    name="olympics",         # table name in MySQL
    con=engine,
    if_exists="replace",  
    index=False           
)
# Out:
# 271116

# %%
pd.read_csv('noc_regions.csv')
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
df = pd.read_csv('noc_regions.csv')
# Write to SQL
df.to_sql(
    name="country",         # table name in MySQL
    con=engine,
    if_exists="replace",  
    index=False           
)
# Out:
# 230

# %%
file = r'C:\Users\sumit\My_code_files\Data Science codes\week 07-advanced pandas\ipl_deliveries.csv'
import pandas as pd
pd.read_csv(file).head()
# Out:
#         ID                            Team  innings  overs  ballnumber  \
# 0  1312200  Rajasthan RoyalsGujarat Titans        1      0           1
# 1  1312200  Rajasthan RoyalsGujarat Titans        1      0           2
# 2  1312200  Rajasthan RoyalsGujarat Titans        1      0           3
# 3  1312200  Rajasthan RoyalsGujarat Titans        1      0           4
# 4  1312200  Rajasthan RoyalsGujarat Titans        1      0           5
#
#         batter          bowler  non-striker extra_type  batsman_run  \
# 0  YBK Jaiswal  Mohammed Shami   JC Buttler        NaN            0
# 1  YBK Jaiswal  Mohammed Shami   JC Buttler    legbyes            0
# 2   JC Buttler  Mohammed Shami  YBK Jaiswal        NaN            1
# 3  YBK Jaiswal  Mohammed Shami   JC Buttler        NaN            0
# 4  YBK Jaiswal  Mohammed Shami   JC Buttler        NaN            0
#
#    extras_run  total_run  non_boundary  isWicketDelivery player_out kind  \
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Correctly encoded password
engine = create_engine("mysql+pymysql://root:improve%407@localhost/campusx")

# Query with pandas
df = pd.read_sql("SELECT * FROM USERS", engine)
df
# Out:
#    user_id    name             email password
# 0        1  manish  manish@gmail.com     1234
# 1        2   sumit   sumit@yahoo.com     1010
# 2        3   deepu   deepu@gmail.com     None
# 3        4  aditya              None     1234
# 4        5   anand   anand@gmail.com     1234
# 5        6   ayush   ayush@gmail.com    12345
# 6        7  piyush  piyush@gmail.com     6789

# %%
ipl_file = r'C:\Users\sumit\My_code_files\Data Science codes\week 07-advanced pandas\deliveries.csv'
df = pd.read_csv(ipl_file)
df
# Out:
#         (match_id  inning         batting_team                 bowling_team  \
# 0               1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1               1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2               1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3               1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4               1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...           ...     ...                  ...                          ...
# 179073      11415       2  Chennai Super Kings               Mumbai Indians
# 179074      11415       2  Chennai Super Kings               Mumbai Indians
# 179075      11415       2  Chennai Super Kings               Mumbai Indians
# 179076      11415       2  Chennai Super Kings               Mumbai Indians
# 179077      11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
ipl_file = r'C:\Users\sumit\My_code_files\Data Science codes\week 07-advanced pandas\deliveries.csv'
df = pd.read_csv(ipl_file)
# Write to SQL
df.to_sql(
    name="ipl",         # table name in MySQL
    con=engine,
    if_exists="replace",  
    index=False           
)
# Out:
# 179078
