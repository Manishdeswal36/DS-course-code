# %%
import mysql.connector

# app isko system variable ma chupa sakta hoa

mysql.connector.connect(
    host = '127.0.0.1',
    user = 'root',
    password = ''
)

# %%
import mysql.connector

# app isko system variable ma chupa sakta hoa
# store in a variable 
conn = mysql.connector.connect(
    host = '127.0.0.1',
    user = 'root',
    password = ''
)
# now this code is risky used in the try catch block

# %% [markdown]
# # connect to the database

# %%
import mysql.connector

# app isko system variable ma chupa sakta hoa

try :
    connector_object = mysql.connector.connect(
        host = 'localhost',
        user = 'root',
        password = 'improve@7'
    )
    mycursor = connector_object.cursor()
    print('Connection established')
except:
    print('Connection Error')

# %%
import mysql.connector

try :
    connector_object = mysql.connector.connect(
        host = 'localhost',
        user = 'root',
        password = 'improve@7',
        database = 'indigo'
    )
    mycursor = connector_object.cursor()
    print('Connection established')
except:
    print('Connection Error')
    
# create a database in the server 
# mycursor.execute('CREATE DATABASE indigo')
# connector_object.commit()

# create a table 
# name of airport airporot id | code |name

# %% [markdown]
# # create table

# %%
import mysql.connector

try :
    connector_object = mysql.connector.connect(
        host = 'localhost',
        user = 'root',
        password = 'improve@7'
    )
    mycursor = connector_object.cursor()
    print('Connection established')
except:
    print('Connection Error')
    
# create a database in the server 
mycursor.execute('CREATE DATABASE indigo')
connector_object.commit()

# %%
import mysql.connector

try :
    connector_object = mysql.connector.connect(
        host = 'localhost',
        user = 'root',
        password = 'improve@7',
        database = 'indigo'
    )
    mycursor = connector_object.cursor()
    print('Connection established')
except:
    print('Connection Error')
    
# create a database in the server 
# mycursor.execute('CREATE DATABASE indigo')
# connector_object.commit()

# create a table 
# name of airport airporot id | code |name |city
mycursor.execute('''
    CREATE TABLE airport(
        airport_id INTEGER PRIMARY KEY,
        code VARCHAR(10) NOT NULL,
        city VARCHAR(50) NOT NULL,
        name VARCHAR(255) NOT NULL,
    )
                ''')

connector_object.commit()

# %%
# jab bhi write operation hota ha tho commit
# read operation ma commit nahi hota
# we study in details about commit when we study transcations

# %% [markdown]
# ## insert the data

# %%
import mysql.connector

try :
    connector_object = mysql.connector.connect(
        host = 'localhost',
        user = 'root',
        password = 'improve@7',
        database = 'indigo'
    )
    mycursor = connector_object.cursor()
    print('Connection established')
except:
    print('Connection Error')
    
# create a database in the server 
# mycursor.execute('CREATE DATABASE indigo')
# connector_object.commit()

# create a table 
# name of airport airporot id | code |name |city
# mycursor.execute('''
#     CREATE TABLE airport(
#         airport_id INTEGER PRIMARY KEY,
#         code VARCHAR(10) NOT NULL,
#         city VARCHAR(50) NOT NULL,
#         name VARCHAR(255) NOT NULL
#     )
#                 ''')

# connector_object.commit()

# now we perform the crud operations in the table 
# cread ,retrive,update ,delelte 
# now add some airports data 

# Insert the data
mycursor.execute('''
    INSERT INTO  airport values
    (1,'DEL','New Delhi','IGIA'),
    (2 ,'CCU', 'kolkata','NSCA'),
    (3 ,'BOM', 'Mumbai','CSMA')
                ''')
connector_object.commit()

# %% [markdown]
# ## retrieve data

# %%
import mysql.connector

try :
    connector_object = mysql.connector.connect(
        host = 'localhost',
        user = 'root',
        password = 'improve@7',
        database = 'indigo'
    )
    mycursor = connector_object.cursor()
    print('Connection established')
except:
    print('Connection Error')
    
# create a database in the server 
# mycursor.execute('CREATE DATABASE indigo')
# connector_object.commit()

# create a table 
# name of airport airporot id | code |name |city
# mycursor.execute('''
#     CREATE TABLE airport(
#         airport_id INTEGER PRIMARY KEY,
#         code VARCHAR(10) NOT NULL,
#         city VARCHAR(50) NOT NULL,
#         name VARCHAR(255) NOT NULL
#     )
#                 ''')

# connector_object.commit()

# now we perform the crud operations in the table 
# cread ,retrive,update ,delelte 
# now add some airports data 

# Insert the data
# mycursor.execute('''
#     INSERT INTO  airport values
#     (1,'DEL','New Delhi','IGIA'),
#     (2 ,'CCU', 'kolkata','NSCA'),
#     (3 ,'BOM', 'Mumbai','CSMA')
#                 ''')
# connector_object.commit()

# retreive the data 
mycursor.execute('SELECT * FROM airport WHERE airport_id > 1')
data = mycursor.fetchall()
print(data)

# %%
import mysql.connector

try :
    connector_object = mysql.connector.connect(
        host = 'localhost',
        user = 'root',
        password = 'improve@7',
        database = 'indigo'
    )
    mycursor = connector_object.cursor()
    print('Connection established')
except:
    print('Connection Error')
    
# create a database in the server 
# mycursor.execute('CREATE DATABASE indigo')
# connector_object.commit()

# create a table 
# name of airport airporot id | code |name |city
# mycursor.execute('''
#     CREATE TABLE airport(
#         airport_id INTEGER PRIMARY KEY,
#         code VARCHAR(10) NOT NULL,
#         city VARCHAR(50) NOT NULL,
#         name VARCHAR(255) NOT NULL
#     )
#                 ''')

# connector_object.commit()

# now we perform the crud operations in the table 
# cread ,retrive,update ,delelte 
# now add some airports data 

# Insert the data
# mycursor.execute('''
#     INSERT INTO  airport values
#     (1,'DEL','New Delhi','IGIA'),
#     (2 ,'CCU', 'kolkata','NSCA'),
#     (3 ,'BOM', 'Mumbai','CSMA')
#                 ''')
# connector_object.commit()

# retreive the data 
mycursor.execute('SELECT * FROM airport WHERE airport_id > 1')
data = mycursor.fetchall()
print(data)

for i in data:
    print(i[3])
    
# now aap tkinder use kareka data ko app ma display karo 
# flask use kareka website ma display karo data ko
# ya fastapi use karka kisi api ma 
# ya streamlit use karka ksi website par

# %% [markdown]
# ## update the data

# %%
import mysql.connector

try :
    connector_object = mysql.connector.connect(
        host = 'localhost',
        user = 'root',
        password = 'improve@7',
        database = 'indigo'
    )
    mycursor = connector_object.cursor()
    print('Connection established')
except:
    print('Connection Error')
    
# create a database in the server 
# mycursor.execute('CREATE DATABASE indigo')
# connector_object.commit()

# create a table 
# name of airport airporot id | code |name |city
# mycursor.execute('''
#     CREATE TABLE airport(
#         airport_id INTEGER PRIMARY KEY,
#         code VARCHAR(10) NOT NULL,
#         city VARCHAR(50) NOT NULL,
#         name VARCHAR(255) NOT NULL
#     )
#                 ''')

# connector_object.commit()

# now we perform the crud operations in the table 
# cread ,retrive,update ,delelte 
# now add some airports data 

# Insert the data
# mycursor.execute('''
#     INSERT INTO  airport values
#     (1,'DEL','New Delhi','IGIA'),
#     (2 ,'CCU', 'kolkata','NSCA'),
#     (3 ,'BOM', 'Mumbai','CSMA')
#                 ''')
# connector_object.commit()

# retreive the data 

    
# now aap tkinder use kareka data ko app ma display karo 
# flask use kareka website ma display karo data ko
# ya fastapi use karka kisi api ma 
# ya streamlit use karka ksi website par 

#update example 
mycursor.execute('''
            UPDATE airport
            SET name = 'Bombay'
            WHERE airport_id = 3
                ''')
connector_object.commit()



# now retrive the data 
mycursor.execute('SELECT * FROM airport ')
data = mycursor.fetchall()
print(data)

for i in data:
    print(i[3])

# %% [markdown]
# ## delete the data

# %%
import mysql.connector

try :
    connector_object = mysql.connector.connect(
        host = 'localhost',
        user = 'root',
        password = 'improve@7',
        database = 'indigo'
    )
    mycursor = connector_object.cursor()
    print('Connection established')
except:
    print('Connection Error')
    
# create a database in the server 
# mycursor.execute('CREATE DATABASE indigo')
# connector_object.commit()

# create a table 
# name of airport airporot id | code |name |city
# mycursor.execute('''
#     CREATE TABLE airport(
#         airport_id INTEGER PRIMARY KEY,
#         code VARCHAR(10) NOT NULL,
#         city VARCHAR(50) NOT NULL,
#         name VARCHAR(255) NOT NULL
#     )
#                 ''')

# connector_object.commit()

# now we perform the crud operations in the table 
# cread ,retrive,update ,delelte 
# now add some airports data 

# Insert the data
# mycursor.execute('''
#     INSERT INTO  airport values
#     (1,'DEL','New Delhi','IGIA'),
#     (2 ,'CCU', 'kolkata','NSCA'),
#     (3 ,'BOM', 'Mumbai','CSMA')
#                 ''')
# connector_object.commit()

# retreive the data 

    
# now aap tkinder use kareka data ko app ma display karo 
# flask use kareka website ma display karo data ko
# ya fastapi use karka kisi api ma 
# ya streamlit use karka ksi website par 

# update example 
# mycursor.execute('''
#             UPDATE airport
#             SET name = 'Bombay'
#             WHERE airport_id = 3
#                 ''')
# connector_object.commit()


    
# delelte the bombay airport 
mycursor.execute('''
            DELETE FROM airport WHERE airport_id = 3
                ''')

# now retrive the data 
mycursor.execute('SELECT * FROM airport ')
data = mycursor.fetchall()
print(data)

for i in data:
    print(i[3])

# %% [markdown]
# # streamlit app

# %% [markdown]
# ## Dashboard Design
# 1. Airline Piechart
# 2. Business Airport Bar chart
# 3. Daily number of flights line chart filter by airline
# 4. Flight between cities

# %% [markdown]
# first you understand the workflow apka paas database ha apna us sa ek analystics dashbaord kasa banya  it is a live dashboard . meaning database ma entry hoga ya par values change ho jayega .
#              you learn graphs kasa plot kar ho you know sql ma graphs nahi hota graphs plot karna ka liya we use the python ya tableau . apko samaj ma ayega ya communication kasa ho raha ha

# %% [markdown]
# this became a project in your portfolio. aap ek descent dataset lo us par project bano .

# %% [markdown]
# yes we are exicted and curious to learna

# %% [markdown]
# now everything is mix and used . python ,streamlit , sql

# %% [markdown]
# now we create the stcuture of the app in streamlit

# %% [markdown]
# ## sidebar page

# %%
import streamlit as st

st.sidebar.title('Flights Analystic')

st.sidebar.selectbox(label='menu',options=['Select one','Check flights','Analystics'])

# %% [markdown]
# ## select box

# %%
import streamlit as st

st.sidebar.title('Flights Analystic')

user_option= st.sidebar.selectbox(label='menu',options=['Select one','Check flights','Analytics'])

if user_option == 'Check flights':
    st.title('Check Flights')
elif user_option == 'Analytics':
    st.title('Analytics')

# %% [markdown]
# now you database and streamlit logic in different files

# %%
import streamlit as st
from dbhelper import DB
db = DB()
st.sidebar.title('Flights Analystic')

user_option= st.sidebar.selectbox(label='menu',options=['Select one','Check flights','Analytics'])

if user_option == 'Check flights':
    st.title('Check Flights')
elif user_option == 'Analytics':
    st.title('Analytics')

# %% [markdown]
# ## cities name in dropdown

# %%
import streamlit as st
from dbhelper import DB
db = DB()
st.sidebar.title('Flights Analystic')

user_option= st.sidebar.selectbox(label='menu',options=['Select one','Check flights','Analytics'])

if user_option == 'Check flights':
    st.title('Check Flights')
    
    col1,col2 = st.columns(2)
    
    with col1:
        cities_names = db.fetch_city_names()
        st.selectbox(label='Source',options= sorted(cities_names))
elif user_option == 'Analytics':
    st.title('Analytics')

# %% [markdown]
# you are just make proper website stucture

# %% [markdown]
# ## display flighest dataframe

# %%
import streamlit as st
from dbhelper import DB
db = DB()
st.sidebar.title('Flights Analystic')

user_option= st.sidebar.selectbox(label='menu',options=['Select one','Check flights','Analytics'])

if user_option == 'Check flights':
    st.title('Check Flights')
    
    col1,col2 = st.columns(2)
    
    with col1:
        cities_names = db.fetch_city_names()
        source = st.selectbox(label='Source',options= sorted(cities_names))
        
    with col2:
        cities_names = db.fetch_city_names()
        destination = st.selectbox(label='Destination',options= sorted(cities_names))
        
    if st.button('Search'):
        results = db.fetch_all_flights(source,destination)
        st.dataframe(results)
        
elif user_option == 'Analytics':
    st.title('Analytics')

# %% [markdown]
# work like a web delveloper

# %% [markdown]
# # Analyatics

# %% [markdown]
# ## airline pie chart
