# %% [markdown]
# # Measure of central tendacancy

# %% [markdown]
# ## mean

# %% [markdown]
# ### Why mean is not a good measure
# Because of outlier
# 3 people ka package ha sunddenly ek amir aadmi aa jaya

# %% [markdown]
# # Measure of Varience

# %% [markdown]
# # Graphs

# %% [markdown]
# ## Univarte Analysis

# %% [markdown]
# ### Cateogrical

# %% [markdown]
# #### Bar chart

# %% [markdown]
# #### pie chart

# %% [markdown]
# #### line chart

# %% [markdown]
# ### Numerical

# %% [markdown]
# #### Histogram

# %% [markdown]
# #### Distribution

# %% [markdown]
# #### Types of Distribution

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Numerical-Numerical

# %% [markdown]
# #### Scatter plot

# %% [markdown]
# ### Numerical-Cateogrical

# %% [markdown]
# ### Cateforical- Cateogrical
